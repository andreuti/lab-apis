# %% [markdown]
# # Lab | APIs

# %% [markdown]
# In order to use the `Spotify` API (`SpotiPy`), create an account in `Spotify` and follow [these](https://developer.spotify.com/documentation/general/guides/app-settings/) steps.

# %% [markdown]
# ## Authentication and initializing the API

# %% [markdown]
# Save your client ID and your client secret in your preferred way, and read it or load it into the following variables:

# %%
CLIENT_ID = "2130852de0874372a2daab216c0b0820"
CLIENT_SECRET = "f9f31bd5485e4bdcaed05e26940b0202"

# %%
# If you havent done so, install the spotipy wrapper
# !pip install spotipy
# Out:
# Collecting spotipy
#   Downloading spotipy-2.25.1-py3-none-any.whl.metadata (5.1 kB)
# Collecting redis>=3.5.3 (from spotipy)
#   Downloading redis-5.2.1-py3-none-any.whl.metadata (9.1 kB)
# Requirement already satisfied: requests>=2.25.0 in c:\users\andre\documents\ironhack\venv\lib\site-packages (from spotipy) (2.32.3)
# Requirement already satisfied: urllib3>=1.26.0 in c:\users\andre\documents\ironhack\venv\lib\site-packages (from spotipy) (2.4.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\andre\documents\ironhack\venv\lib\site-packages (from requests>=2.25.0->spotipy) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\andre\documents\ironhack\venv\lib\site-packages (from requests>=2.25.0->spotipy) (3.10)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\andre\documents\ironhack\venv\lib\site-packages (from requests>=2.25.0->spotipy) (2025.1.31)
# Downloading spotipy-2.25.1-py3-none-any.whl (31 kB)
# Downloading redis-5.2.1-py3-none-any.whl (261 kB)
# Installing collected packages: redis, spotipy
# Successfully installed redis-5.2.1 spotipy-2.25.1
# [notice] A new release of pip is available: 24.3.1 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# Once you have done it, we will start initializing the API.

# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials

#Initialize SpotiPy with user credentials
sp = spotipy.Spotify(auth_manager=SpotifyClientCredentials(client_id=CLIENT_ID,
                                                           client_secret=CLIENT_SECRET))

# %% [markdown]
# ## Using the search method

# %% [markdown]
# Now, let's use the search method by introducing a "query". For example, let's try searching for "Lady Gaga":

# %%
results = sp.search(q='Lady Gaga', limit=50)
results
# Out:
# {'tracks': {'href': 'https://api.spotify.com/v1/search?offset=0&limit=50&query=Lady%20Gaga&type=track',
#   'limit': 50,
#   'next': 'https://api.spotify.com/v1/search?offset=50&limit=50&query=Lady%20Gaga&type=track',
#   'offset': 0,
#   'previous': None,
#   'total': 128,
#   'items': [{'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1HY2Jd0NmPuamShAr6KMms'},
#        'href': 'https://api.spotify.com/v1/artists/1HY2Jd0NmPuamShAr6KMms',
#        'id': '1HY2Jd0NmPuamShAr6KMms',
#        'name': 'Lady Gaga',
#        'type': 'artist',
#        'uri': 'spotify:artist:1HY2Jd0NmPuamShAr6KMms'}],
#      'available_markets': ['AR',
#       'AU',
#       'AT',
#       'BE',
#       'BO',
#       'BR',
#       'BG',
#       'CA',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DK',
#       'DO',
#       'DE',
#       'EC',
#       'EE',
#       'SV',
#       'FI',
#       'FR',
#       'GR',
#       'GT',
#       'HN',
#       'HK',
#       'HU',
#       'IS',
#       'IE',
#       'IT',
#       'LV',
#       'LT',
#       'LU',
#       'MY',
#       'MT',
#       'MX',
#       'NL',
#       'NZ',
#       'NI',
#       'NO',
#       'PA',
#       'PY',
#       'PE',
#       'PH',
#       'PL',
#       'PT',
#       'SG',
#       'SK',
#       'ES',
#       'CH',
#       'TW',
#       'TR',
#       'UY',
#       'US',
#       'GB',
#       'AD',
#       'LI',
#       'MC',
#       'ID',
#       'JP',
#       'TH',
#       'VN',
#       'RO',
#       'IL',
#       'ZA',
#       'SA',
#       'AE',
#       'BH',
#       'QA',
#       'OM',
#       'KW',
#       'EG',
#       'MA',
#       'DZ',
#       'TN',
#       'LB',
#       'JO',
#       'PS',
#       'IN',
#       'KZ',
#       'MD',
#       'UA',
#       'AL',
#       'BA',
#       'HR',
#       'ME',
#       'MK',
#       'RS',
#       'SI',
#       'KR',
#       'BD',
#       'PK',
#       'LK',
#       'GH',
#       'KE',
#       'NG',
#       'TZ',
#       'UG',
#       'AG',
#       'AM',
#       'BS',
#       'BB',
#       'BZ',
#       'BT',
#       'BW',
#       'BF',
#       'CV',
#       'CW',
#       'DM',
#       'FJ',
#       'GM',
#       'GE',
#       'GD',
#       'GW',
#       'GY',
#       'HT',
#       'JM',
#       'KI',
#       'LS',
#       'LR',
#       'MW',
#       'MV',
#       'ML',
#       'MH',
#       'FM',
#       'NA',
#       'NR',
#       'NE',
#       'PW',
#       'PG',
#       'WS',
#       'SM',
#       'ST',
#       'SN',
#       'SC',
#       'SL',
#       'SB',
#       'KN',
#       'LC',
#       'VC',
#       'SR',
#       'TL',
#       'TO',
#       'TT',
#       'TV',
#       'VU',
#       'AZ',
#       'BN',
#       'BI',
#       'KH',
#       'CM',
#       'TD',
#       'KM',
#       'GQ',
#       'SZ',
#       'GA',
#       'GN',
#       'KG',
#       'LA',
#       'MO',
#       'MR',
#       'MN',
#       'NP',
#       'RW',
#       'TG',
#       'UZ',
#       'ZW',
#       'BJ',
#       'MG',
#       'MU',
#       'MZ',
#       'AO',
#       'CI',
#       'DJ',
#       'ZM',
#       'CD',
#       'CG',
#       'IQ',
#       'LY',
#       'TJ',
#       'VE',
#       'ET',
#       'XK'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/2I6LyArz82waG94e9V5B9d'},
#      'href': 'https://api.spotify.com/v1/albums/2I6LyArz82waG94e9V5B9d',
#      'id': '2I6LyArz82waG94e9V5B9d',
#      'images': [{'height': 640,
#        'width': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b27325304f6dc9dea023ce4b985c'},
#       {'height': 300,
#        'width': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e0225304f6dc9dea023ce4b985c'},
#       {'height': 64,
#        'width': 64,
#        'url': 'https://i.scdn.co/image/ab67616d0000485125304f6dc9dea023ce4b985c'}],
#      'is_playable': True,
#      'name': 'Abracadabra',
#      'release_date': '2025-02-03',
#      'release_date_precision': 'day',
#      'total_tracks': 1,
#      'type': 'album',
#      'uri': 'spotify:album:2I6LyArz82waG94e9V5B9d'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1HY2Jd0NmPuamShAr6KMms'},
#       'href': 'https://api.spotify.com/v1/artists/1HY2Jd0NmPuamShAr6KMms',
#       'id': '1HY2Jd0NmPuamShAr6KMms',
#       'name': 'Lady Gaga',
#       'type': 'artist',
#       'uri': 'spotify:artist:1HY2Jd0NmPuamShAr6KMms'}],
#     'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'SG',
#      'SK',
#      'ES',
#      'CH',
#      'TW',
#      'TR',
#      'UY',
#      'US',
#      'GB',
#      'AD',
#      'LI',
#      'MC',
#      'ID',
#      'JP',
#      'TH',
#      'VN',
#      'RO',
#      'IL',
#      'ZA',
#      'SA',
#      'AE',
#      'BH',
#      'QA',
#      'OM',
#      'KW',
#      'EG',
#      'MA',
#      'DZ',
#      'TN',
#      'LB',
#      'JO',
#      'PS',
#      'IN',
#      'KZ',
#      'MD',
#      'UA',
#      'AL',
#      'BA',
#      'HR',
#      'ME',
#      'MK',
#      'RS',
#      'SI',
#      'KR',
#      'BD',
#      'PK',
#      'LK',
#      'GH',
#      'KE',
#      'NG',
#      'TZ',
#      'UG',
#      'AG',
#      'AM',
#      'BS',
#      'BB',
#      'BZ',
#      'BT',
#      'BW',
#      'BF',
#      'CV',
#      'CW',
#      'DM',
#      'FJ',
#      'GM',
#      'GE',
#      'GD',
#      'GW',
#      'GY',
#      'HT',
#      'JM',
#      'KI',
#      'LS',
#      'LR',
#      'MW',
#      'MV',
#      'ML',
#      'MH',
#      'FM',
#      'NA',
#      'NR',
#      'NE',
#      'PW',
#      'PG',
#      'WS',
#      'SM',
#      'ST',
#      'SN',
#      'SC',
#      'SL',
#      'SB',
#      'KN',
#      'LC',
#      'VC',
#      'SR',
#      'TL',
#      'TO',
#      'TT',
#      'TV',
#      'VU',
#      'AZ',
#      'BN',
#      'BI',
#      'KH',
#      'CM',
#      'TD',
#      'KM',
#      'GQ',
#      'SZ',
#      'GA',
#      'GN',
#      'KG',
#      'LA',
#      'MO',
#      'MR',
#      'MN',
#      'NP',
#      'RW',
#      'TG',
#      'UZ',
#      'ZW',
#      'BJ',
#      'MG',
#      'MU',
#      'MZ',
#      'AO',
#      'CI',
#      'DJ',
#      'ZM',
#      'CD',
#      'CG',
#      'IQ',
#      'LY',
#      'TJ',
#      'VE',
#      'ET',
#      'XK'],
#     'disc_number': 1,
#     'duration_ms': 223398,
#     'explicit': False,
#     'external_ids': {'isrc': 'USUM72412581'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/5ZLUm9eab8y3tqQ1OhQSHI'},
#     'href': 'https://api.spotify.com/v1/tracks/5ZLUm9eab8y3tqQ1OhQSHI',
#     'id': '5ZLUm9eab8y3tqQ1OhQSHI',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'Abracadabra',
#     'popularity': 92,
#     'preview_url': None,
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:5ZLUm9eab8y3tqQ1OhQSHI'},
#    {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1HY2Jd0NmPuamShAr6KMms'},
#        'href': 'https://api.spotify.com/v1/artists/1HY2Jd0NmPuamShAr6KMms',
#        'id': '1HY2Jd0NmPuamShAr6KMms',
#        'name': 'Lady Gaga',
#        'type': 'artist',
#        'uri': 'spotify:artist:1HY2Jd0NmPuamShAr6KMms'},
#       {'external_urls': {'spotify': 'https://open.spotify.com/artist/0du5cEVh5yTK9QJze8zA0C'},
#        'href': 'https://api.spotify.com/v1/artists/0du5cEVh5yTK9QJze8zA0C',
#        'id': '0du5cEVh5yTK9QJze8zA0C',
#        'name': 'Bruno Mars',
#        'type': 'artist',
#        'uri': 'spotify:artist:0du5cEVh5yTK9QJze8zA0C'}],
#      'available_markets': ['AR',
#       'AU',
#       'AT',
#       'BE',
#       'BO',
#       'BR',
#       'BG',
#       'CA',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DK',
#       'DO',
#       'DE',
#       'EC',
#       'EE',
#       'SV',
#       'FI',
#       'FR',
#       'GR',
#       'GT',
#       'HN',
#       'HK',
#       'HU',
#       'IS',
#       'IE',
#       'IT',
#       'LV',
#       'LT',
#       'LU',
#       'MY',
#       'MT',
#       'MX',
#       'NL',
#       'NZ',
#       'NI',
#       'NO',
#       'PA',
#       'PY',
#       'PE',
#       'PH',
#       'PL',
#       'PT',
#       'SG',
#       'SK',
#       'ES',
#       'SE',
#       'CH',
#       'TW',
#       'TR',
#       'UY',
#       'US',
#       'GB',
#       'AD',
#       'LI',
#       'MC',
#       'ID',
#       'JP',
#       'TH',
#       'VN',
#       'RO',
#       'IL',
#       'ZA',
#       'SA',
#       'AE',
#       'BH',
#       'QA',
#       'OM',
#       'KW',
#       'EG',
#       'MA',
#       'DZ',
#       'TN',
#       'LB',
#       'JO',
#       'PS',
#       'IN',
#       'KZ',
#       'MD',
#       'UA',
#       'AL',
#       'BA',
#       'HR',
#       'ME',
#       'MK',
#       'RS',
#       'SI',
#       'KR',
#       'BD',
#       'PK',
#       'LK',
#       'GH',
#       'KE',
#       'NG',
#       'TZ',
#       'UG',
#       'AG',
#       'AM',
#       'BS',
#       'BB',
#       'BZ',
#       'BT',
#       'BW',
#       'BF',
#       'CV',
#       'CW',
#       'DM',
#       'FJ',
#       'GM',
#       'GE',
#       'GD',
#       'GW',
#       'GY',
#       'HT',
#       'JM',
#       'KI',
#       'LS',
#       'LR',
#       'MW',
#       'MV',
#       'ML',
#       'MH',
#       'FM',
#       'NA',
#       'NR',
#       'NE',
#       'PW',
#       'PG',
#       'WS',
#       'SM',
#       'ST',
#       'SN',
#       'SC',
#       'SL',
#       'SB',
#       'KN',
#       'LC',
#       'VC',
#       'SR',
#       'TL',
#       'TO',
#       'TT',
#       'TV',
#       'VU',
#       'AZ',
#       'BN',
#       'BI',
#       'KH',
#       'CM',
#       'TD',
#       'KM',
#       'GQ',
#       'SZ',
#       'GA',
#       'GN',
#       'KG',
#       'LA',
#       'MO',
#       'MR',
#       'MN',
#       'NP',
#       'RW',
#       'TG',
#       'UZ',
#       'ZW',
#       'BJ',
#       'MG',
#       'MU',
#       'MZ',
#       'AO',
#       'CI',
#       'DJ',
#       'ZM',
#       'CD',
#       'CG',
#       'IQ',
#       'LY',
#       'TJ',
#       'VE',
#       'ET',
#       'XK'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/10FLjwfpbxLmW8c25Xyc2N'},
#      'href': 'https://api.spotify.com/v1/albums/10FLjwfpbxLmW8c25Xyc2N',
#      'id': '10FLjwfpbxLmW8c25Xyc2N',
#      'images': [{'height': 640,
#        'width': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b27382ea2e9e1858aa012c57cd45'},
#       {'height': 300,
#        'width': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e0282ea2e9e1858aa012c57cd45'},
#       {'height': 64,
#        'width': 64,
#        'url': 'https://i.scdn.co/image/ab67616d0000485182ea2e9e1858aa012c57cd45'}],
#      'is_playable': True,
#      'name': 'Die With A Smile',
#      'release_date': '2024-08-16',
#      'release_date_precision': 'day',
#      'total_tracks': 1,
#      'type': 'album',
#      'uri': 'spotify:album:10FLjwfpbxLmW8c25Xyc2N'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1HY2Jd0NmPuamShAr6KMms'},
#       'href': 'https://api.spotify.com/v1/artists/1HY2Jd0NmPuamShAr6KMms',
#       'id': '1HY2Jd0NmPuamShAr6KMms',
#       'name': 'Lady Gaga',
#       'type': 'artist',
#       'uri': 'spotify:artist:1HY2Jd0NmPuamShAr6KMms'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/0du5cEVh5yTK9QJze8zA0C'},
#       'href': 'https://api.spotify.com/v1/artists/0du5cEVh5yTK9QJze8zA0C',
#       'id': '0du5cEVh5yTK9QJze8zA0C',
#       'name': 'Bruno Mars',
#       'type': 'artist',
#       'uri': 'spotify:artist:0du5cEVh5yTK9QJze8zA0C'}],
#     'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'SG',
#      'SK',
#      'ES',
#      'SE',
#      'CH',
#      'TW',
#      'TR',
#      'UY',
#      'US',
#      'GB',
#      'AD',
#      'LI',
#      'MC',
#      'ID',
#      'JP',
#      'TH',
#      'VN',
#      'RO',
#      'IL',
#      'ZA',
#      'SA',
#      'AE',
#      'BH',
#      'QA',
#      'OM',
#      'KW',
#      'EG',
#      'MA',
#      'DZ',
#      'TN',
#      'LB',
#      'JO',
#      'PS',
#      'IN',
#      'KZ',
#      'MD',
#      'UA',
#      'AL',
#      'BA',
#      'HR',
#      'ME',
#      'MK',
#      'RS',
#      'SI',
#      'KR',
#      'BD',
#      'PK',
#      'LK',
#      'GH',
#      'KE',
#      'NG',
#      'TZ',
#      'UG',
#      'AG',
#      'AM',
#      'BS',
#      'BB',
#      'BZ',
#      'BT',
#      'BW',
#      'BF',
#      'CV',
#      'CW',
#      'DM',
#      'FJ',
#      'GM',
#      'GE',
#      'GD',
#      'GW',
#      'GY',
#      'HT',
#      'JM',
#      'KI',
#      'LS',
#      'LR',
#      'MW',
#      'MV',
#      'ML',
#      'MH',
#      'FM',
#      'NA',
#      'NR',
#      'NE',
#      'PW',
#      'PG',
#      'WS',
#      'SM',
#      'ST',
#      'SN',
#      'SC',
#      'SL',
#      'SB',
#      'KN',
#      'LC',
#      'VC',
#      'SR',
#      'TL',
#      'TO',
#      'TT',
#      'TV',
#      'VU',
#      'AZ',
#      'BN',
#      'BI',
#      'KH',
#      'CM',
#      'TD',
#      'KM',
#      'GQ',
#      'SZ',
#      'GA',
#      'GN',
#      'KG',
#      'LA',
#      'MO',
#      'MR',
#      'MN',
#      'NP',
#      'RW',
#      'TG',
#      'UZ',
#      'ZW',
#      'BJ',
#      'MG',
#      'MU',
#      'MZ',
#      'AO',
#      'CI',
#      'DJ',
#      'ZM',
#      'CD',
#      'CG',
#      'IQ',
#      'LY',
#      'TJ',
#      'VE',
#      'ET',
#      'XK'],
#     'disc_number': 1,
#     'duration_ms': 251667,
#     'explicit': False,
#     'external_ids': {'isrc': 'USUM72409273'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/2plbrEY59IikOBgBGLjaoe'},
#     'href': 'https://api.spotify.com/v1/tracks/2plbrEY59IikOBgBGLjaoe',
#     'id': '2plbrEY59IikOBgBGLjaoe',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'Die With A Smile',
#     'popularity': 99,
#     'preview_url': None,
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:2plbrEY59IikOBgBGLjaoe'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1HY2Jd0NmPuamShAr6KMms'},
#        'href': 'https://api.spotify.com/v1/artists/1HY2Jd0NmPuamShAr6KMms',
#        'id': '1HY2Jd0NmPuamShAr6KMms',
#        'name': 'Lady Gaga',
#        'type': 'artist',
#        'uri': 'spotify:artist:1HY2Jd0NmPuamShAr6KMms'},
#       {'external_urls': {'spotify': 'https://open.spotify.com/artist/4VIvfOurcf0vuLRxLkGnIG'},
#        'href': 'https://api.spotify.com/v1/artists/4VIvfOurcf0vuLRxLkGnIG',
#        'id': '4VIvfOurcf0vuLRxLkGnIG',
#        'name': 'Bradley Cooper',
#        'type': 'artist',
#        'uri': 'spotify:artist:4VIvfOurcf0vuLRxLkGnIG'}],
#      'available_markets': ['AR',
#       'AU',
#       'AT',
#       'BE',
#       'BO',
#       'BR',
#       'BG',
#       'CA',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DK',
#       'DO',
#       'DE',
#       'EC',
#       'EE',
#       'SV',
#       'FI',
#       'FR',
#       'GR',
#       'GT',
#       'HN',
#       'HK',
#       'HU',
#       'IS',
#       'IE',
#       'IT',
#       'LV',
#       'LT',
#       'LU',
#       'MY',
#       'MT',
#       'MX',
#       'NL',
#       'NZ',
#       'NI',
#       'NO',
#       'PA',
#       'PY',
#       'PE',
#       'PH',
#       'PL',
#       'PT',
#       'SG',
#       'SK',
#       'ES',
#       'SE',
#       'CH',
#       'TW',
#       'TR',
#       'UY',
#       'US',
#       'GB',
#       'AD',
#       'LI',
#       'MC',
#       'ID',
#       'JP',
#       'TH',
#       'VN',
#       'RO',
#       'IL',
#       'ZA',
#       'SA',
#       'AE',
#       'BH',
#       'QA',
#       'OM',
#       'KW',
#       'EG',
#       'MA',
#       'DZ',
#       'TN',
#       'LB',
#       'JO',
#       'PS',
#       'IN',
#       'BY',
#       'KZ',
#       'MD',
#       'UA',
#       'AL',
#       'BA',
#       'HR',
#       'ME',
#       'MK',
#       'RS',
#       'SI',
#       'KR',
#       'BD',
#       'PK',
#       'LK',
#       'GH',
#       'KE',
#       'NG',
#       'TZ',
#       'UG',
#       'AG',
#       'AM',
#       'BS',
#       'BB',
#       'BZ',
#       'BT',
#       'BW',
#       'BF',
#       'CV',
#       'CW',
#       'DM',
#       'FJ',
#       'GM',
#       'GE',
#       'GD',
#       'GW',
#       'GY',
#       'HT',
#       'JM',
#       'KI',
#       'LS',
#       'LR',
#       'MW',
#       'MV',
#       'ML',
#       'MH',
#       'FM',
#       'NA',
#       'NR',
#       'NE',
#       'PW',
#       'PG',
#       'WS',
#       'SM',
#       'ST',
#       'SN',
#       'SC',
#       'SL',
#       'SB',
#       'KN',
#       'LC',
#       'VC',
#       'SR',
#       'TL',
#       'TO',
#       'TT',
#       'TV',
#       'VU',
#       'AZ',
#       'BN',
#       'BI',
#       'KH',
#       'CM',
#       'TD',
#       'KM',
#       'GQ',
#       'SZ',
#       'GA',
#       'GN',
#       'KG',
#       'LA',
#       'MO',
#       'MR',
#       'MN',
#       'NP',
#       'RW',
#       'TG',
#       'UZ',
#       'ZW',
#       'BJ',
#       'MG',
#       'MU',
#       'MZ',
#       'AO',
#       'CI',
#       'DJ',
#       'ZM',
#       'CD',
#       'CG',
#       'IQ',
#       'LY',
#       'TJ',
#       'VE',
#       'ET',
#       'XK'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/3edjzMAVB9RYRd4UcZBchx'},
#      'href': 'https://api.spotify.com/v1/albums/3edjzMAVB9RYRd4UcZBchx',
#      'id': '3edjzMAVB9RYRd4UcZBchx',
#      'images': [{'height': 640,
#        'width': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273b5d4b4ed17ec86c4b3944af2'},
#       {'height': 300,
#        'width': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02b5d4b4ed17ec86c4b3944af2'},
#       {'height': 64,
#        'width': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851b5d4b4ed17ec86c4b3944af2'}],
#      'is_playable': True,
#      'name': 'A Star Is Born Soundtrack (Without Dialogue)',
#      'release_date': '2018-10-05',
#      'release_date_precision': 'day',
#      'total_tracks': 19,
#      'type': 'album',
#      'uri': 'spotify:album:3edjzMAVB9RYRd4UcZBchx'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1HY2Jd0NmPuamShAr6KMms'},
#       'href': 'https://api.spotify.com/v1/artists/1HY2Jd0NmPuamShAr6KMms',
#       'id': '1HY2Jd0NmPuamShAr6KMms',
#       'name': 'Lady Gaga',
#       'type': 'artist',
#       'uri': 'spotify:artist:1HY2Jd0NmPuamShAr6KMms'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/4VIvfOurcf0vuLRxLkGnIG'},
#       'href': 'https://api.spotify.com/v1/artists/4VIvfOurcf0vuLRxLkGnIG',
#       'id': '4VIvfOurcf0vuLRxLkGnIG',
#       'name': 'Bradley Cooper',
#       'type': 'artist',
#       'uri': 'spotify:artist:4VIvfOurcf0vuLRxLkGnIG'}],
#     'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'SG',
#      'SK',
#      'ES',
#      'SE',
#      'CH',
#      'TW',
#      'TR',
#      'UY',
#      'US',
#      'GB',
#      'AD',
#      'LI',
#      'MC',
#      'ID',
#      'JP',
#      'TH',
#      'VN',
#      'RO',
#      'IL',
#      'ZA',
#      'SA',
#      'AE',
#      'BH',
#      'QA',
#      'OM',
#      'KW',
#      'EG',
#      'MA',
#      'DZ',
#      'TN',
#      'LB',
#      'JO',
#      'PS',
#      'IN',
#      'BY',
#      'KZ',
#      'MD',
#      'UA',
#      'AL',
#      'BA',
#      'HR',
#      'ME',
#      'MK',
#      'RS',
#      'SI',
#      'KR',
#      'BD',
#      'PK',
#      'LK',
#      'GH',
#      'KE',
#      'NG',
#      'TZ',
#      'UG',
#      'AG',
#      'AM',
#      'BS',
#      'BB',
#      'BZ',
#      'BT',
#      'BW',
#      'BF',
#      'CV',
#      'CW',
#      'DM',
#      'FJ',
#      'GM',
#      'GE',
#      'GD',
#      'GW',
#      'GY',
#      'HT',
#      'JM',
#      'KI',
#      'LS',
#      'LR',
#      'MW',
#      'MV',
#      'ML',
#      'MH',
#      'FM',
#      'NA',
#      'NR',
#      'NE',
#      'PW',
#      'PG',
#      'WS',
#      'SM',
#      'ST',
#      'SN',
#      'SC',
#      'SL',
#      'SB',
#      'KN',
#      'LC',
#      'VC',
#      'SR',
#      'TL',
#      'TO',
#      'TT',
#      'TV',
#      'VU',
#      'AZ',
#      'BN',
#      'BI',
#      'KH',
#      'CM',
#      'TD',
#      'KM',
#      'GQ',
#      'SZ',
#      'GA',
#      'GN',
#      'KG',
#      'LA',
#      'MO',
#      'MR',
#      'MN',
#      'NP',
#      'RW',
#      'TG',
#      'UZ',
#      'ZW',
#      'BJ',
#      'MG',
#      'MU',
#      'MZ',
#      'AO',
#      'CI',
#      'DJ',
#      'ZM',
#      'CD',
#      'CG',
#      'IQ',
#      'LY',
#      'TJ',
#      'VE',
#      'ET',
#      'XK'],
#     'disc_number': 1,
#     'duration_ms': 217212,
#     'explicit': False,
#     'external_ids': {'isrc': 'USUM71815945'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/6QfS2wq5sSC1xAJCQsTSlj'},
#     'href': 'https://api.spotify.com/v1/tracks/6QfS2wq5sSC1xAJCQsTSlj',
#     'id': '6QfS2wq5sSC1xAJCQsTSlj',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'Shallow - Radio Edit',
#     'popularity': 73,
#     'preview_url': None,
#     'track_number': 6,
#     'type': 'track',
#     'uri': 'spotify:track:6QfS2wq5sSC1xAJCQsTSlj'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1HY2Jd0NmPuamShAr6KMms'},
#        'href': 'https://api.spotify.com/v1/artists/1HY2Jd0NmPuamShAr6KMms',
#        'id': '1HY2Jd0NmPuamShAr6KMms',
#        'name': 'Lady Gaga',
#        'type': 'artist',
#        'uri': 'spotify:artist:1HY2Jd0NmPuamShAr6KMms'}],
#      'available_markets': ['AR',
#       'AU',
#       'AT',
#       'BE',
#       'BO',
#       'BR',
#       'BG',
#       'CA',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DK',
#       'DO',
#       'DE',
#       'EC',
#       'EE',
#       'SV',
#       'FI',
#       'FR',
#       'GR',
#       'GT',
#       'HN',
#       'HK',
#       'HU',
#       'IS',
#       'IE',
#       'IT',
#       'LV',
#       'LT',
#       'LU',
#       'MY',
#       'MT',
#       'MX',
#       'NL',
#       'NZ',
#       'NI',
#       'NO',
#       'PA',
#       'PY',
#       'PE',
#       'PH',
#       'PL',
#       'PT',
#       'SG',
#       'SK',
#       'ES',
#       'SE',
#       'CH',
#       'TW',
#       'TR',
#       'UY',
#       'US',
#       'GB',
#       'AD',
#       'LI',
#       'MC',
#       'ID',
#       'JP',
#       'TH',
#       'VN',
#       'RO',
#       'IL',
#       'ZA',
#       'SA',
#       'AE',
#       'BH',
#       'QA',
#       'OM',
#       'KW',
#       'EG',
#       'MA',
#       'DZ',
#       'TN',
#       'LB',
#       'JO',
#       'PS',
#       'IN',
#       'KZ',
#       'MD',
#       'UA',
#       'AL',
#       'BA',
#       'HR',
#       'ME',
#       'MK',
#       'RS',
#       'SI',
#       'KR',
#       'BD',
#       'PK',
#       'LK',
#       'GH',
#       'KE',
#       'NG',
#       'TZ',
#       'UG',
#       'AG',
#       'AM',
#       'BS',
#       'BB',
#       'BZ',
#       'BT',
#       'BW',
#       'BF',
#       'CV',
#       'CW',
#       'DM',
#       'FJ',
#       'GM',
#       'GE',
#       'GD',
#       'GW',
#       'GY',
#       'HT',
#       'JM',
#       'KI',
#       'LS',
#       'LR',
#       'MW',
#       'MV',
#       'ML',
#       'MH',
#       'FM',
#       'NA',
#       'NR',
#       'NE',
#       'PW',
#       'PG',
#       'WS',
#       'SM',
#       'ST',
#       'SN',
#       'SC',
#       'SL',
#       'SB',
#       'KN',
#       'LC',
#       'VC',
#       'SR',
#       'TL',
#       'TO',
#       'TT',
#       'TV',
#       'VU',
#       'AZ',
#       'BN',
#       'BI',
#       'KH',
#       'CM',
#       'TD',
#       'KM',
#       'GQ',
#       'SZ',
#       'GA',
#       'GN',
#       'KG',
#       'LA',
#       'MO',
#       'MR',
#       'MN',
#       'NP',
#       'RW',
#       'TG',
#       'UZ',
#       'ZW',
#       'BJ',
#       'MG',
#       'MU',
#       'MZ',
#       'AO',
#       'CI',
#       'DJ',
#       'ZM',
#       'CD',
#       'CG',
#       'IQ',
#       'LY',
#       'TJ',
#       'VE',
#       'ET',
#       'XK'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/6rePArBMb5nLWEaY9aQqL4'},
#      'href': 'https://api.spotify.com/v1/albums/6rePArBMb5nLWEaY9aQqL4',
#      'id': '6rePArBMb5nLWEaY9aQqL4',
#      'images': [{'height': 640,
#        'width': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2735c9890c0456a3719eeecd8aa'},
#       {'height': 300,
#        'width': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e025c9890c0456a3719eeecd8aa'},
#       {'height': 64,
#        'width': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048515c9890c0456a3719eeecd8aa'}],
#      'is_playable': True,
#      'name': 'The Fame Monster (Deluxe Edition)',
#      'release_date': '2009-11-05',
#      'release_date_precision': 'day',
#      'total_tracks': 23,
#      'type': 'album',
#      'uri': 'spotify:album:6rePArBMb5nLWEaY9aQqL4'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1HY2Jd0NmPuamShAr6KMms'},
#       'href': 'https://api.spotify.com/v1/artists/1HY2Jd0NmPuamShAr6KMms',
#       'id': '1HY2Jd0NmPuamShAr6KMms',
#       'name': 'Lady Gaga',
#       'type': 'artist',
#       'uri': 'spotify:artist:1HY2Jd0NmPuamShAr6KMms'}],
#     'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'SG',
#      'SK',
#      'ES',
#      'SE',
#      'CH',
#      'TW',
#      'TR',
#      'UY',
#      'US',
#      'GB',
#      'AD',
#      'LI',
#      'MC',
#      'ID',
#      'JP',
#      'TH',
#      'VN',
#      'RO',
#      'IL',
#      'ZA',
#      'SA',
#      'AE',
#      'BH',
#      'QA',
#      'OM',
#      'KW',
#      'EG',
#      'MA',
#      'DZ',
#      'TN',
#      'LB',
#      'JO',
#      'PS',
#      'IN',
#      'KZ',
#      'MD',
#      'UA',
#      'AL',
#      'BA',
#      'HR',
#      'ME',
#      'MK',
#      'RS',
#      'SI',
#      'KR',
#      'BD',
#      'PK',
#      'LK',
#      'GH',
#      'KE',
#      'NG',
#      'TZ',
#      'UG',
#      'AG',
#      'AM',
#      'BS',
#      'BB',
#      'BZ',
#      'BT',
#      'BW',
#      'BF',
#      'CV',
#      'CW',
#      'DM',
#      'FJ',
#      'GM',
#      'GE',
#      'GD',
#      'GW',
#      'GY',
#      'HT',
#      'JM',
#      'KI',
#      'LS',
#      'LR',
#      'MW',
#      'MV',
#      'ML',
#      'MH',
#      'FM',
#      'NA',
#      'NR',
#      'NE',
#      'PW',
#      'PG',
#      'WS',
#      'SM',
#      'ST',
#      'SN',
#      'SC',
#      'SL',
#      'SB',
#      'KN',
#      'LC',
#      'VC',
#      'SR',
#      'TL',
#      'TO',
#      'TT',
#      'TV',
#      'VU',
#      'AZ',
#      'BN',
#      'BI',
#      'KH',
#      'CM',
#      'TD',
#      'KM',
#      'GQ',
#      'SZ',
#      'GA',
#      'GN',
#      'KG',
#      'LA',
#      'MO',
#      'MR',
#      'MN',
#      'NP',
#      'RW',
#      'TG',
#      'UZ',
#      'ZW',
#      'BJ',
#      'MG',
#      'MU',
#      'MZ',
#      'AO',
#      'CI',
#      'DJ',
#      'ZM',
#      'CD',
#      'CG',
#      'IQ',
#      'LY',
#      'TJ',
#      'VE',
#      'ET',
#      'XK'],
#     'disc_number': 1,
#     'duration_ms': 294573,
#     'explicit': True,
#     'external_ids': {'isrc': 'USUM70918596'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/0SiywuOBRcynK0uKGWdCnn'},
#     'href': 'https://api.spotify.com/v1/tracks/0SiywuOBRcynK0uKGWdCnn',
#     'id': '0SiywuOBRcynK0uKGWdCnn',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'Bad Romance',
#     'popularity': 88,
#     'preview_url': None,
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:0SiywuOBRcynK0uKGWdCnn'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/12GqGscKJx3aE4t07u7eVZ'},
#        'href': 'https://api.spotify.com/v1/artists/12GqGscKJx3aE4t07u7eVZ',
#        'id': '12GqGscKJx3aE4t07u7eVZ',
#        'name': 'Peso Pluma',
#        'type': 'artist',
#        'uri': 'spotify:artist:12GqGscKJx3aE4t07u7eVZ'}],
#      'available_markets': ['AR',
#       'AU',
#       'AT',
#       'BE',
#       'BO',
#       'BR',
#       'BG',
#       'CA',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DK',
#       'DO',
#       'DE',
#       'EC',
#       'EE',
#       'SV',
#       'FI',
#       'FR',
#       'GR',
#       'GT',
#       'HN',
#       'HK',
#       'HU',
#       'IS',
#       'IE',
#       'IT',
#       'LV',
#       'LT',
#       'LU',
#       'MY',
#       'MT',
#       'MX',
#       'NL',
#       'NZ',
#       'NI',
#       'NO',
#       'PA',
#       'PY',
#       'PE',
#       'PH',
#       'PL',
#       'PT',
#       'SG',
#       'SK',
#       'ES',
#       'SE',
#       'CH',
#       'TW',
#       'TR',
#       'UY',
#       'US',
#       'GB',
#       'AD',
#       'LI',
#       'MC',
#       'ID',
#       'JP',
#       'TH',
#       'VN',
#       'RO',
#       'IL',
#       'ZA',
#       'SA',
#       'AE',
#       'BH',
#       'QA',
#       'OM',
#       'KW',
#       'EG',
#       'MA',
#       'DZ',
#       'TN',
#       'LB',
#       'JO',
#       'PS',
#       'IN',
#       'BY',
#       'KZ',
#       'MD',
#       'UA',
#       'AL',
#       'BA',
#       'HR',
#       'ME',
#       'MK',
#       'RS',
#       'SI',
#       'KR',
#       'BD',
#       'PK',
#       'LK',
#       'GH',
#       'KE',
#       'NG',
#       'TZ',
#       'UG',
#       'AG',
#       'AM',
#       'BS',
#       'BB',
#       'BZ',
#       'BT',
#       'BW',
#       'BF',
#       'CV',
#       'CW',
#       'DM',
#       'FJ',
#       'GM',
#       'GE',
#       'GD',
#       'GW',
#       'GY',
#       'HT',
#       'JM',
#       'KI',
#       'LS',
#       'LR',
#       'MW',
#       'MV',
#       'ML',
#       'MH',
#       'FM',
#       'NA',
#       'NR',
#       'NE',
#       'PW',
#       'PG',
#       'PR',
#       'WS',
#       'SM',
#       'ST',
#       'SN',
#       'SC',
#       'SL',
#       'SB',
#       'KN',
#       'LC',
#       'VC',
#       'SR',
#       'TL',
#       'TO',
#       'TT',
#       'TV',
#       'VU',
#       'AZ',
#       'BN',
#       'BI',
#       'KH',
#       'CM',
#       'TD',
#       'KM',
#       'GQ',
#       'SZ',
#       'GA',
#       'GN',
#       'KG',
#       'LA',
#       'MO',
#       'MR',
#       'MN',
#       'NP',
#       'RW',
#       'TG',
#       'UZ',
#       'ZW',
#       'BJ',
#       'MG',
#       'MU',
#       'MZ',
#       'AO',
#       'CI',
#       'DJ',
#       'ZM',
#       'CD',
#       'CG',
#       'IQ',
#       'LY',
#       'TJ',
#       'VE',
#       'ET',
#       'XK'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/4jox3ip1I39DFC2B7R5qLH'},
#      'href': 'https://api.spotify.com/v1/albums/4jox3ip1I39DFC2B7R5qLH',
#      'id': '4jox3ip1I39DFC2B7R5qLH',
#      'images': [{'height': 640,
#        'width': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2732fb583ed96f8f35cbf2897ba'},
#       {'height': 300,
#        'width': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e022fb583ed96f8f35cbf2897ba'},
#       {'height': 64,
#        'width': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048512fb583ed96f8f35cbf2897ba'}],
#      'is_playable': True,
#      'name': 'GÉNESIS',
#      'release_date': '2023-06-29',
#      'release_date_precision': 'day',
#      'total_tracks': 17,
#      'type': 'album',
#      'uri': 'spotify:album:4jox3ip1I39DFC2B7R5qLH'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/12GqGscKJx3aE4t07u7eVZ'},
#       'href': 'https://api.spotify.com/v1/artists/12GqGscKJx3aE4t07u7eVZ',
#       'id': '12GqGscKJx3aE4t07u7eVZ',
#       'name': 'Peso Pluma',
#       'type': 'artist',
#       'uri': 'spotify:artist:12GqGscKJx3aE4t07u7eVZ'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/6Sbl0NT50roqWvy746MfVf'},
#       'href': 'https://api.spotify.com/v1/artists/6Sbl0NT50roqWvy746MfVf',
#       'id': '6Sbl0NT50roqWvy746MfVf',
#       'name': 'Gabito Ballesteros',
#       'type': 'artist',
#       'uri': 'spotify:artist:6Sbl0NT50roqWvy746MfVf'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/7Gi6gjaWy3DxyilpF1a8Is'},
#       'href': 'https://api.spotify.com/v1/artists/7Gi6gjaWy3DxyilpF1a8Is',
#       'id': '7Gi6gjaWy3DxyilpF1a8Is',
#       'name': 'Junior H',
#       'type': 'artist',
#       'uri': 'spotify:artist:7Gi6gjaWy3DxyilpF1a8Is'}],
#     'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'SG',
#      'SK',
#      'ES',
#      'SE',
#      'CH',
#      'TW',
#      'TR',
#      'UY',
#      'US',
#      'GB',
#      'AD',
#      'LI',
#      'MC',
#      'ID',
#      'JP',
#      'TH',
#      'VN',
#      'RO',
#      'IL',
#      'ZA',
#      'SA',
#      'AE',
#      'BH',
#      'QA',
#      'OM',
#      'KW',
#      'EG',
#      'MA',
#      'DZ',
#      'TN',
#      'LB',
#      'JO',
#      'PS',
#      'IN',
#      'BY',
#      'KZ',
#      'MD',
#      'UA',
#      'AL',
#      'BA',
#      'HR',
#      'ME',
#      'MK',
#      'RS',
#      'SI',
#      'KR',
#      'BD',
#      'PK',
#      'LK',
#      'GH',
#      'KE',
#      'NG',
#      'TZ',
#      'UG',
#      'AG',
#      'AM',
#      'BS',
#      'BB',
#      'BZ',
#      'BT',
#      'BW',
#      'BF',
#      'CV',
#      'CW',
#      'DM',
#      'FJ',
#      'GM',
#      'GE',
#      'GD',
#      'GW',
#      'GY',
#      'HT',
#      'JM',
#      'KI',
#      'LS',
#      'LR',
#      'MW',
#      'MV',
#      'ML',
#      'MH',
#      'FM',
#      'NA',
#      'NR',
#      'NE',
#      'PW',
#      'PG',
#      'PR',
#      'WS',
#      'SM',
#      'ST',
#      'SN',
#      'SC',
#      'SL',
#      'SB',
#      'KN',
#      'LC',
#      'VC',
#      'SR',
#      'TL',
#      'TO',
#      'TT',
#      'TV',
#      'VU',
#      'AZ',
#      'BN',
#      'BI',
#      'KH',
#      'CM',
#      'TD',
#      'KM',
#      'GQ',
#      'SZ',
#      'GA',
#      'GN',
#      'KG',
#      'LA',
#      'MO',
#      'MR',
#      'MN',
#      'NP',
#      'RW',
#      'TG',
#      'UZ',
#      'ZW',
#      'BJ',
#      'MG',
#      'MU',
#      'MZ',
#      'AO',
#      'CI',
#      'DJ',
#      'ZM',
#      'CD',
#      'CG',
#      'IQ',
#      'LY',
#      'TJ',
#      'VE',
#      'ET',
#      'XK'],
#     'disc_number': 1,
#     'duration_ms': 212878,
#     'explicit': True,
#     'external_ids': {'isrc': 'QM7282306246'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/7mXuWTczZNxG5EDcjFEuJR'},
#     'href': 'https://api.spotify.com/v1/tracks/7mXuWTczZNxG5EDcjFEuJR',
#     'id': '7mXuWTczZNxG5EDcjFEuJR',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'LADY GAGA',
#     'popularity': 81,
#     'preview_url': None,
#     'track_number': 10,
#     'type': 'track',
#     'uri': 'spotify:track:7mXuWTczZNxG5EDcjFEuJR'},
#    {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1HY2Jd0NmPuamShAr6KMms'},
#        'href': 'https://api.spotify.com/v1/artists/1HY2Jd0NmPuamShAr6KMms',
#        'id': '1HY2Jd0NmPuamShAr6KMms',
#        'name': 'Lady Gaga',
#        'type': 'artist',
#        'uri': 'spotify:artist:1HY2Jd0NmPuamShAr6KMms'}],
#      'available_markets': ['AR',
#       'AU',
#       'AT',
#       'BE',
#       'BO',
#       'BR',
#       'BG',
#       'CA',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DK',
#       'DO',
#       'DE',
#       'EC',
#       'EE',
#       'SV',
#       'FI',
#       'FR',
#       'GR',
#       'GT',
#       'HN',
#       'HK',
#       'HU',
#       'IS',
#       'IE',
#       'IT',
#       'LV',
#       'LT',
#       'LU',
#       'MY',
#       'MT',
#       'MX',
#       'NL',
#       'NZ',
#       'NI',
#       'NO',
#       'PA',
#       'PY',
#       'PE',
#       'PH',
#       'PL',
#       'PT',
#       'SG',
#       'SK',
#       'ES',
#       'SE',
#       'CH',
#       'TW',
#       'TR',
#       'UY',
#       'US',
#       'GB',
#       'AD',
#       'LI',
#       'MC',
#       'ID',
#       'JP',
#       'TH',
#       'VN',
#       'RO',
#       'IL',
#       'ZA',
#       'SA',
#       'AE',
#       'BH',
#       'QA',
#       'OM',
#       'KW',
#       'EG',
#       'MA',
#       'DZ',
#       'TN',
#       'LB',
#       'JO',
#       'PS',
#       'IN',
#       'KZ',
#       'MD',
#       'UA',
#       'AL',
#       'BA',
#       'HR',
#       'ME',
#       'MK',
#       'RS',
#       'SI',
#       'KR',
#       'BD',
#       'PK',
#       'LK',
#       'GH',
#       'KE',
#       'NG',
#       'TZ',
#       'UG',
#       'AG',
#       'AM',
#       'BS',
#       'BB',
#       'BZ',
#       'BT',
#       'BW',
#       'BF',
#       'CV',
#       'CW',
#       'DM',
#       'FJ',
#       'GM',
#       'GE',
#       'GD',
#       'GW',
#       'GY',
#       'HT',
#       'JM',
#       'KI',
#       'LS',
#       'LR',
#       'MW',
#       'MV',
#       'ML',
#       'MH',
#       'FM',
#       'NA',
#       'NR',
#       'NE',
#       'PW',
#       'PG',
#       'WS',
#       'SM',
#       'ST',
#       'SN',
#       'SC',
#       'SL',
#       'SB',
#       'KN',
#       'LC',
#       'VC',
#       'SR',
#       'TL',
#       'TO',
#       'TT',
#       'TV',
#       'VU',
#       'AZ',
#       'BN',
#       'BI',
#       'KH',
#       'CM',
#       'TD',
#       'KM',
#       'GQ',
#       'SZ',
#       'GA',
#       'GN',
#       'KG',
#       'LA',
#       'MO',
#       'MR',
#       'MN',
#       'NP',
#       'RW',
#       'TG',
#       'UZ',
#       'ZW',
#       'BJ',
#       'MG',
#       'MU',
#       'MZ',
#       'AO',
#       'CI',
#       'DJ',
#       'ZM',
#       'CD',
#       'CG',
#       'IQ',
#       'LY',
#       'TJ',
#       'VE',
#       'ET',
#       'XK'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/52BWvTRMsPqjHzrbQomgwP'},
#      'href': 'https://api.spotify.com/v1/albums/52BWvTRMsPqjHzrbQomgwP',
#      'id': '52BWvTRMsPqjHzrbQomgwP',
#      'images': [{'height': 640,
#        'width': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273465e58cfc2ee480a7d0ae59d'},
#       {'height': 300,
#        'width': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02465e58cfc2ee480a7d0ae59d'},
#       {'height': 64,
#        'width': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851465e58cfc2ee480a7d0ae59d'}],
#      'is_playable': True,
#      'name': 'Disease',
#      'release_date': '2024-10-25',
#      'release_date_precision': 'day',
#      'total_tracks': 1,
#      'type': 'album',
#      'uri': 'spotify:album:52BWvTRMsPqjHzrbQomgwP'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1HY2Jd0NmPuamShAr6KMms'},
#       'href': 'https://api.spotify.com/v1/artists/1HY2Jd0NmPuamShAr6KMms',
#       'id': '1HY2Jd0NmPuamShAr6KMms',
#       'name': 'Lady Gaga',
#       'type': 'artist',
#       'uri': 'spotify:artist:1HY2Jd0NmPuamShAr6KMms'}],
#     'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'SG',
#      'SK',
#      'ES',
#      'SE',
#      'CH',
#      'TW',
#      'TR',
#      'UY',
#      'US',
#      'GB',
#      'AD',
#      'LI',
#      'MC',
#      'ID',
#      'JP',
#      'TH',
#      'VN',
#      'RO',
#      'IL',
#      'ZA',
#      'SA',
#      'AE',
#      'BH',
#      'QA',
#      'OM',
#      'KW',
#      'EG',
#      'MA',
#      'DZ',
#      'TN',
#      'LB',
#      'JO',
#      'PS',
#      'IN',
#      'KZ',
#      'MD',
#      'UA',
#      'AL',
#      'BA',
#      'HR',
#      'ME',
#      'MK',
#      'RS',
#      'SI',
#      'KR',
#      'BD',
#      'PK',
#      'LK',
#      'GH',
#      'KE',
#      'NG',
#      'TZ',
#      'UG',
#      'AG',
#      'AM',
#      'BS',
#      'BB',
#      'BZ',
#      'BT',
#      'BW',
#      'BF',
#      'CV',
#      'CW',
#      'DM',
#      'FJ',
#      'GM',
#      'GE',
#      'GD',
#      'GW',
#      'GY',
#      'HT',
#      'JM',
#      'KI',
#      'LS',
#      'LR',
#      'MW',
#      'MV',
#      'ML',
#      'MH',
#      'FM',
#      'NA',
#      'NR',
#      'NE',
#      'PW',
#      'PG',
#      'WS',
#      'SM',
#      'ST',
#      'SN',
#      'SC',
#      'SL',
#      'SB',
#      'KN',
#      'LC',
#      'VC',
#      'SR',
#      'TL',
#      'TO',
#      'TT',
#      'TV',
#      'VU',
#      'AZ',
#      'BN',
#      'BI',
#      'KH',
#      'CM',
#      'TD',
#      'KM',
#      'GQ',
#      'SZ',
#      'GA',
#      'GN',
#      'KG',
#      'LA',
#      'MO',
#      'MR',
#      'MN',
#      'NP',
#      'RW',
#      'TG',
#      'UZ',
#      'ZW',
#      'BJ',
#      'MG',
#      'MU',
#      'MZ',
#      'AO',
#      'CI',
#      'DJ',
#      'ZM',
#      'CD',
#      'CG',
#      'IQ',
#      'LY',
#      'TJ',
#      'VE',
#      'ET',
#      'XK'],
#     'disc_number': 1,
#     'duration_ms': 229997,
#     'explicit': False,
#     'external_ids': {'isrc': 'USUM72407015'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/19KlZwqlT3fguP2BeHF1Q1'},
#     'href': 'https://api.spotify.com/v1/tracks/19KlZwqlT3fguP2BeHF1Q1',
#     'id': '19KlZwqlT3fguP2BeHF1Q1',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'Disease',
#     'popularity': 80,
#     'preview_url': None,
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:19KlZwqlT3fguP2BeHF1Q1'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1HY2Jd0NmPuamShAr6KMms'},
#        'href': 'https://api.spotify.com/v1/artists/1HY2Jd0NmPuamShAr6KMms',
#        'id': '1HY2Jd0NmPuamShAr6KMms',
#        'name': 'Lady Gaga',
#        'type': 'artist',
#        'uri': 'spotify:artist:1HY2Jd0NmPuamShAr6KMms'}],
#      'available_markets': ['AR',
#       'AU',
#       'AT',
#       'BE',
#       'BO',
#       'BR',
#       'BG',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DK',
#       'DO',
#       'DE',
#       'EC',
#       'EE',
#       'SV',
#       'FI',
#       'FR',
#       'GR',
#       'GT',
#       'HN',
#       'HK',
#       'HU',
#       'IS',
#       'IE',
#       'IT',
#       'LV',
#       'LT',
#       'LU',
#       'MY',
#       'MT',
#       'NL',
#       'NZ',
#       'NI',
#       'NO',
#       'PA',
#       'PY',
#       'PE',
#       'PH',
#       'PL',
#       'PT',
#       'SG',
#       'SK',
#       'ES',
#       'CH',
#       'TW',
#       'TR',
#       'UY',
#       'GB',
#       'AD',
#       'LI',
#       'MC',
#       'ID',
#       'JP',
#       'TH',
#       'VN',
#       'RO',
#       'IL',
#       'ZA',
#       'SA',
#       'AE',
#       'BH',
#       'QA',
#       'OM',
#       'KW',
#       'EG',
#       'MA',
#       'DZ',
#       'TN',
#       'LB',
#       'JO',
#       'PS',
#       'IN',
#       'BY',
#       'KZ',
#       'MD',
#       'UA',
#       'AL',
#       'BA',
#       'HR',
#       'ME',
#       'MK',
#       'RS',
#       'SI',
#       'KR',
#       'BD',
#       'PK',
#       'LK',
#       'GH',
#       'KE',
#       'NG',
#       'TZ',
#       'UG',
#       'AG',
#       'AM',
#       'BS',
#       'BB',
#       'BZ',
#       'BT',
#       'BW',
#       'BF',
#       'CV',
#       'CW',
#       'DM',
#       'FJ',
#       'GM',
#       'GD',
#       'GW',
#       'GY',
#       'HT',
#       'JM',
#       'KI',
#       'LS',
#       'LR',
#       'MW',
#       'MV',
#       'ML',
#       'MH',
#       'FM',
#       'NA',
#       'NR',
#       'NE',
#       'PW',
#       'PG',
#       'WS',
#       'ST',
#       'SN',
#       'SC',
#       'SL',
#       'SB',
#       'KN',
#       'LC',
#       'VC',
#       'SR',
#       'TL',
#       'TO',
#       'TT',
#       'TV',
#       'AZ',
#       'BN',
#       'BI',
#       'KH',
#       'CM',
#       'TD',
#       'KM',
#       'GQ',
#       'SZ',
#       'GA',
#       'GN',
#       'KG',
#       'LA',
#       'MO',
#       'MR',
#       'MN',
#       'NP',
#       'RW',
#       'TG',
#       'UZ',
#       'ZW',
#       'BJ',
#       'MG',
#       'MU',
#       'MZ',
#       'AO',
#       'CI',
#       'DJ',
#       'ZM',
#       'CD',
#       'CG',
#       'IQ',
#       'LY',
#       'TJ',
#       'VE',
#       'XK'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/1qwlxZTNLe1jq3b0iidlue'},
#      'href': 'https://api.spotify.com/v1/albums/1qwlxZTNLe1jq3b0iidlue',
#      'id': '1qwlxZTNLe1jq3b0iidlue',
#      'images': [{'height': 640,
#        'width': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273e691217483df8798445c82e2'},
#       {'height': 300,
#        'width': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02e691217483df8798445c82e2'},
#       {'height': 64,
#        'width': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851e691217483df8798445c82e2'}],
#      'is_playable': True,
#      'name': 'The Fame',
#      'release_date': '2008-01-01',
#      'release_date_precision': 'day',
#      'total_tracks': 15,
#      'type': 'album',
#      'uri': 'spotify:album:1qwlxZTNLe1jq3b0iidlue'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1HY2Jd0NmPuamShAr6KMms'},
#       'href': 'https://api.spotify.com/v1/artists/1HY2Jd0NmPuamShAr6KMms',
#       'id': '1HY2Jd0NmPuamShAr6KMms',
#       'name': 'Lady Gaga',
#       'type': 'artist',
#       'uri': 'spotify:artist:1HY2Jd0NmPuamShAr6KMms'}],
#     'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'SG',
#      'SK',
#      'ES',
#      'CH',
#      'TW',
#      'TR',
#      'UY',
#      'GB',
#      'AD',
#      'LI',
#      'MC',
#      'ID',
#      'JP',
#      'TH',
#      'VN',
#      'RO',
#      'IL',
#      'ZA',
#      'SA',
#      'AE',
#      'BH',
#      'QA',
#      'OM',
#      'KW',
#      'EG',
#      'MA',
#      'DZ',
#      'TN',
#      'LB',
#      'JO',
#      'PS',
#      'IN',
#      'BY',
#      'KZ',
#      'MD',
#      'UA',
#      'AL',
#      'BA',
#      'HR',
#      'ME',
#      'MK',
#      'RS',
#      'SI',
#      'KR',
#      'BD',
#      'PK',
#      'LK',
#      'GH',
#      'KE',
#      'NG',
#      'TZ',
#      'UG',
#      'AG',
#      'AM',
#      'BS',
#      'BB',
#      'BZ',
#      'BT',
#      'BW',
#      'BF',
#      'CV',
#      'CW',
#      'DM',
#      'FJ',
#      'GM',
#      'GD',
#      'GW',
#      'GY',
#      'HT',
#      'JM',
#      'KI',
#      'LS',
#      'LR',
#      'MW',
#      'MV',
#      'ML',
#      'MH',
#      'FM',
#      'NA',
#      'NR',
#      'NE',
#      'PW',
#      'PG',
#      'WS',
#      'ST',
#      'SN',
#      'SC',
#      'SL',
#      'SB',
#      'KN',
#      'LC',
#      'VC',
#      'SR',
#      'TL',
#      'TO',
#      'TT',
#      'TV',
#      'AZ',
#      'BN',
#      'BI',
#      'KH',
#      'CM',
#      'TD',
#      'KM',
#      'GQ',
#      'SZ',
#      'GA',
#      'GN',
#      'KG',
#      'LA',
#      'MO',
#      'MR',
#      'MN',
#      'NP',
#      'RW',
#      'TG',
#      'UZ',
#      'ZW',
#      'BJ',
#      'MG',
#      'MU',
#      'MZ',
#      'AO',
#      'CI',
#      'DJ',
#      'ZM',
#      'CD',
#      'CG',
#      'IQ',
#      'LY',
#      'TJ',
#      'VE',
#      'XK'],
#     'disc_number': 1,
#     'duration_ms': 237200,
#     'explicit': True,
#     'external_ids': {'isrc': 'USUM70824409'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/1QV6tiMFM6fSOKOGLMHYYg'},
#     'href': 'https://api.spotify.com/v1/tracks/1QV6tiMFM6fSOKOGLMHYYg',
#     'id': '1QV6tiMFM6fSOKOGLMHYYg',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'Poker Face',
#     'popularity': 87,
#     'preview_url': None,
#     'track_number': 4,
#     'type': 'track',
#     'uri': 'spotify:track:1QV6tiMFM6fSOKOGLMHYYg'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1HY2Jd0NmPuamShAr6KMms'},
#        'href': 'https://api.spotify.com/v1/artists/1HY2Jd0NmPuamShAr6KMms',
#        'id': '1HY2Jd0NmPuamShAr6KMms',
#        'name': 'Lady Gaga',
#        'type': 'artist',
#        'uri': 'spotify:artist:1HY2Jd0NmPuamShAr6KMms'}],
#      'available_markets': ['AR',
#       'AU',
#       'AT',
#       'BE',
#       'BO',
#       'BR',
#       'BG',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DK',
#       'DO',
#       'DE',
#       'EC',
#       'EE',
#       'SV',
#       'FI',
#       'FR',
#       'GR',
#       'GT',
#       'HN',
#       'HK',
#       'HU',
#       'IS',
#       'IE',
#       'IT',
#       'LV',
#       'LT',
#       'LU',
#       'MY',
#       'MT',
#       'MX',
#       'NL',
#       'NZ',
#       'NI',
#       'NO',
#       'PA',
#       'PY',
#       'PE',
#       'PH',
#       'PL',
#       'PT',
#       'SG',
#       'SK',
#       'ES',
#       'SE',
#       'CH',
#       'TW',
#       'TR',
#       'UY',
#       'GB',
#       'AD',
#       'LI',
#       'MC',
#       'ID',
#       'TH',
#       'VN',
#       'RO',
#       'IL',
#       'ZA',
#       'SA',
#       'AE',
#       'BH',
#       'QA',
#       'OM',
#       'KW',
#       'EG',
#       'MA',
#       'DZ',
#       'TN',
#       'LB',
#       'JO',
#       'PS',
#       'IN',
#       'BY',
#       'KZ',
#       'MD',
#       'UA',
#       'AL',
#       'BA',
#       'HR',
#       'ME',
#       'MK',
#       'RS',
#       'SI',
#       'KR',
#       'BD',
#       'PK',
#       'LK',
#       'GH',
#       'KE',
#       'NG',
#       'TZ',
#       'UG',
#       'AG',
#       'AM',
#       'BS',
#       'BB',
#       'BZ',
#       'BT',
#       'BW',
#       'BF',
#       'CV',
#       'CW',
#       'DM',
#       'FJ',
#       'GM',
#       'GD',
#       'GW',
#       'GY',
#       'HT',
#       'JM',
#       'KI',
#       'LS',
#       'LR',
# ...
#       'SN',
#       'SC',
#       'SL',
#       'SB',
#       'KN',
#       'LC',
#       'VC',
#       'SR',
#       'TL',
#       'TO',
#       'TT',
#       'TV',
#       'VU',
#       'AZ',
#       'BN',
#       'BI',
#       'KH',
#       'CM',
#       'TD',
#       'KM',
#       'GQ',
#       'SZ',
#       'GA',
#       'GN',
#       'KG',
#       'LA',
#       'MO',
#       'MR',
#       'MN',
#       'NP',
#       'RW',
#       'TG',
#       'UZ',
#       'ZW',
#       'BJ',
#       'MG',
#       'MU',
#       'MZ',
#       'AO',
#       'CI',
#       'DJ',
#       'ZM',
#       'CD',
#       'CG',
#       'IQ',
#       'LY',
#       'TJ',
#       'VE',
#       'ET',
#       'XK'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/0nfk8ZUr3ufktOOaiIGFB9'},
#      'href': 'https://api.spotify.com/v1/albums/0nfk8ZUr3ufktOOaiIGFB9',
#      'id': '0nfk8ZUr3ufktOOaiIGFB9',
#      'images': [{'height': 640,
#        'width': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273b8afbf7c075525002309111f'},
#       {'height': 300,
#        'width': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02b8afbf7c075525002309111f'},
#       {'height': 64,
#        'width': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851b8afbf7c075525002309111f'}],
#      'is_playable': True,
#      'name': 'Madrid Nuclear - En Directo',
#      'release_date': '2020-11-20',
#      'release_date_precision': 'day',
#      'total_tracks': 22,
#      'type': 'album',
#      'uri': 'spotify:album:0nfk8ZUr3ufktOOaiIGFB9'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5Hsv8dUHHOdnn72q4XIVz7'},
#       'href': 'https://api.spotify.com/v1/artists/5Hsv8dUHHOdnn72q4XIVz7',
#       'id': '5Hsv8dUHHOdnn72q4XIVz7',
#       'name': 'Leiva',
#       'type': 'artist',
#       'uri': 'spotify:artist:5Hsv8dUHHOdnn72q4XIVz7'}],
#     'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'SG',
#      'SK',
#      'ES',
#      'SE',
#      'CH',
#      'TW',
#      'TR',
#      'UY',
#      'US',
#      'GB',
#      'AD',
#      'LI',
#      'MC',
#      'ID',
#      'JP',
#      'TH',
#      'VN',
#      'RO',
#      'IL',
#      'ZA',
#      'SA',
#      'AE',
#      'BH',
#      'QA',
#      'OM',
#      'KW',
#      'EG',
#      'MA',
#      'DZ',
#      'TN',
#      'LB',
#      'JO',
#      'PS',
#      'IN',
#      'BY',
#      'KZ',
#      'MD',
#      'UA',
#      'AL',
#      'BA',
#      'HR',
#      'ME',
#      'MK',
#      'RS',
#      'SI',
#      'KR',
#      'BD',
#      'PK',
#      'LK',
#      'GH',
#      'KE',
#      'NG',
#      'TZ',
#      'UG',
#      'AG',
#      'AM',
#      'BS',
#      'BB',
#      'BZ',
#      'BT',
#      'BW',
#      'BF',
#      'CV',
#      'CW',
#      'DM',
#      'FJ',
#      'GM',
#      'GE',
#      'GD',
#      'GW',
#      'GY',
#      'HT',
#      'JM',
#      'KI',
#      'LS',
#      'LR',
#      'MW',
#      'MV',
#      'ML',
#      'MH',
#      'FM',
#      'NA',
#      'NR',
#      'NE',
#      'PW',
#      'PG',
#      'PR',
#      'WS',
#      'SM',
#      'ST',
#      'SN',
#      'SC',
#      'SL',
#      'SB',
#      'KN',
#      'LC',
#      'VC',
#      'SR',
#      'TL',
#      'TO',
#      'TT',
#      'TV',
#      'VU',
#      'AZ',
#      'BN',
#      'BI',
#      'KH',
#      'CM',
#      'TD',
#      'KM',
#      'GQ',
#      'SZ',
#      'GA',
#      'GN',
#      'KG',
#      'LA',
#      'MO',
#      'MR',
#      'MN',
#      'NP',
#      'RW',
#      'TG',
#      'UZ',
#      'ZW',
#      'BJ',
#      'MG',
#      'MU',
#      'MZ',
#      'AO',
#      'CI',
#      'DJ',
#      'ZM',
#      'CD',
#      'CG',
#      'IQ',
#      'LY',
#      'TJ',
#      'VE',
#      'ET',
#      'XK'],
#     'disc_number': 1,
#     'duration_ms': 288848,
#     'explicit': False,
#     'external_ids': {'isrc': 'ES5022000606'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/29ioGonb03ycTvJPDVJcfJ'},
#     'href': 'https://api.spotify.com/v1/tracks/29ioGonb03ycTvJPDVJcfJ',
#     'id': '29ioGonb03ycTvJPDVJcfJ',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'Lady Madrid - Madrid Nuclear - En Directo',
#     'popularity': 36,
#     'preview_url': None,
#     'track_number': 22,
#     'type': 'track',
#     'uri': 'spotify:track:29ioGonb03ycTvJPDVJcfJ'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3xig6nxehGHX2tJVfjMdtZ'},
#        'href': 'https://api.spotify.com/v1/artists/3xig6nxehGHX2tJVfjMdtZ',
#        'id': '3xig6nxehGHX2tJVfjMdtZ',
#        'name': 'Piano Sueños',
#        'type': 'artist',
#        'uri': 'spotify:artist:3xig6nxehGHX2tJVfjMdtZ'}],
#      'available_markets': ['AR',
#       'AU',
#       'AT',
#       'BE',
#       'BO',
#       'BR',
#       'BG',
#       'CA',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DK',
#       'DO',
#       'DE',
#       'EC',
#       'EE',
#       'SV',
#       'FI',
#       'FR',
#       'GR',
#       'GT',
#       'HN',
#       'HK',
#       'HU',
#       'IS',
#       'IE',
#       'IT',
#       'LV',
#       'LT',
#       'LU',
#       'MY',
#       'MT',
#       'MX',
#       'NL',
#       'NZ',
#       'NI',
#       'NO',
#       'PA',
#       'PY',
#       'PE',
#       'PH',
#       'PL',
#       'PT',
#       'SG',
#       'SK',
#       'ES',
#       'SE',
#       'CH',
#       'TW',
#       'TR',
#       'UY',
#       'US',
#       'GB',
#       'AD',
#       'LI',
#       'MC',
#       'ID',
#       'JP',
#       'TH',
#       'VN',
#       'RO',
#       'IL',
#       'ZA',
#       'SA',
#       'AE',
#       'BH',
#       'QA',
#       'OM',
#       'KW',
#       'EG',
#       'MA',
#       'DZ',
#       'TN',
#       'LB',
#       'JO',
#       'PS',
#       'IN',
#       'BY',
#       'KZ',
#       'MD',
#       'UA',
#       'AL',
#       'BA',
#       'HR',
#       'ME',
#       'MK',
#       'RS',
#       'SI',
#       'KR',
#       'BD',
#       'PK',
#       'LK',
#       'GH',
#       'KE',
#       'NG',
#       'TZ',
#       'UG',
#       'AG',
#       'AM',
#       'BS',
#       'BB',
#       'BZ',
#       'BT',
#       'BW',
#       'BF',
#       'CV',
#       'CW',
#       'DM',
#       'FJ',
#       'GM',
#       'GE',
#       'GD',
#       'GW',
#       'GY',
#       'HT',
#       'JM',
#       'KI',
#       'LS',
#       'LR',
#       'MW',
#       'MV',
#       'ML',
#       'MH',
#       'FM',
#       'NA',
#       'NR',
#       'NE',
#       'PW',
#       'PG',
#       'PR',
#       'WS',
#       'SM',
#       'ST',
#       'SN',
#       'SC',
#       'SL',
#       'SB',
#       'KN',
#       'LC',
#       'VC',
#       'SR',
#       'TL',
#       'TO',
#       'TT',
#       'TV',
#       'VU',
#       'AZ',
#       'BN',
#       'BI',
#       'KH',
#       'CM',
#       'TD',
#       'KM',
#       'GQ',
#       'SZ',
#       'GA',
#       'GN',
#       'KG',
#       'LA',
#       'MO',
#       'MR',
#       'MN',
#       'NP',
#       'RW',
#       'TG',
#       'UZ',
#       'ZW',
#       'BJ',
#       'MG',
#       'MU',
#       'MZ',
#       'AO',
#       'CI',
#       'DJ',
#       'ZM',
#       'CD',
#       'CG',
#       'IQ',
#       'LY',
#       'TJ',
#       'VE',
#       'ET',
#       'XK'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/1fk1eIjQwYlVNKvbbBSZxY'},
#      'href': 'https://api.spotify.com/v1/albums/1fk1eIjQwYlVNKvbbBSZxY',
#      'id': '1fk1eIjQwYlVNKvbbBSZxY',
#      'images': [{'height': 640,
#        'width': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273b553c8b38ba75a2ecec6cfa4'},
#       {'height': 300,
#        'width': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02b553c8b38ba75a2ecec6cfa4'},
#       {'height': 64,
#        'width': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851b553c8b38ba75a2ecec6cfa4'}],
#      'is_playable': True,
#      'name': 'Éxitos En Versión Piano, Vol. 5',
#      'release_date': '2024-05-07',
#      'release_date_precision': 'day',
#      'total_tracks': 8,
#      'type': 'album',
#      'uri': 'spotify:album:1fk1eIjQwYlVNKvbbBSZxY'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3xig6nxehGHX2tJVfjMdtZ'},
#       'href': 'https://api.spotify.com/v1/artists/3xig6nxehGHX2tJVfjMdtZ',
#       'id': '3xig6nxehGHX2tJVfjMdtZ',
#       'name': 'Piano Sueños',
#       'type': 'artist',
#       'uri': 'spotify:artist:3xig6nxehGHX2tJVfjMdtZ'}],
#     'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'SG',
#      'SK',
#      'ES',
#      'SE',
#      'CH',
#      'TW',
#      'TR',
#      'UY',
#      'US',
#      'GB',
#      'AD',
#      'LI',
#      'MC',
#      'ID',
#      'JP',
#      'TH',
#      'VN',
#      'RO',
#      'IL',
#      'ZA',
#      'SA',
#      'AE',
#      'BH',
#      'QA',
#      'OM',
#      'KW',
#      'EG',
#      'MA',
#      'DZ',
#      'TN',
#      'LB',
#      'JO',
#      'PS',
#      'IN',
#      'BY',
#      'KZ',
#      'MD',
#      'UA',
#      'AL',
#      'BA',
#      'HR',
#      'ME',
#      'MK',
#      'RS',
#      'SI',
#      'KR',
#      'BD',
#      'PK',
#      'LK',
#      'GH',
#      'KE',
#      'NG',
#      'TZ',
#      'UG',
#      'AG',
#      'AM',
#      'BS',
#      'BB',
#      'BZ',
#      'BT',
#      'BW',
#      'BF',
#      'CV',
#      'CW',
#      'DM',
#      'FJ',
#      'GM',
#      'GE',
#      'GD',
#      'GW',
#      'GY',
#      'HT',
#      'JM',
#      'KI',
#      'LS',
#      'LR',
#      'MW',
#      'MV',
#      'ML',
#      'MH',
#      'FM',
#      'NA',
#      'NR',
#      'NE',
#      'PW',
#      'PG',
#      'PR',
#      'WS',
#      'SM',
#      'ST',
#      'SN',
#      'SC',
#      'SL',
#      'SB',
#      'KN',
#      'LC',
#      'VC',
#      'SR',
#      'TL',
#      'TO',
#      'TT',
#      'TV',
#      'VU',
#      'AZ',
#      'BN',
#      'BI',
#      'KH',
#      'CM',
#      'TD',
#      'KM',
#      'GQ',
#      'SZ',
#      'GA',
#      'GN',
#      'KG',
#      'LA',
#      'MO',
#      'MR',
#      'MN',
#      'NP',
#      'RW',
#      'TG',
#      'UZ',
#      'ZW',
#      'BJ',
#      'MG',
#      'MU',
#      'MZ',
#      'AO',
#      'CI',
#      'DJ',
#      'ZM',
#      'CD',
#      'CG',
#      'IQ',
#      'LY',
#      'TJ',
#      'VE',
#      'ET',
#      'XK'],
#     'disc_number': 1,
#     'duration_ms': 130279,
#     'explicit': False,
#     'external_ids': {'isrc': 'TCAIF2481458'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/48nIniJQUdY6on2hb3IHaP'},
#     'href': 'https://api.spotify.com/v1/tracks/48nIniJQUdY6on2hb3IHaP',
#     'id': '48nIniJQUdY6on2hb3IHaP',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'Lady Gaga',
#     'popularity': 14,
#     'preview_url': None,
#     'track_number': 4,
#     'type': 'track',
#     'uri': 'spotify:track:48nIniJQUdY6on2hb3IHaP'},
#    {'album': {'album_type': 'compilation',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0LyfQWJT6nXafLPZqxe9Of'},
#        'href': 'https://api.spotify.com/v1/artists/0LyfQWJT6nXafLPZqxe9Of',
#        'id': '0LyfQWJT6nXafLPZqxe9Of',
#        'name': 'Various Artists',
#        'type': 'artist',
#        'uri': 'spotify:artist:0LyfQWJT6nXafLPZqxe9Of'}],
#      'available_markets': ['AR',
#       'AU',
#       'AT',
#       'BE',
#       'BO',
#       'BR',
#       'BG',
#       'CA',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DK',
#       'DO',
#       'DE',
#       'EC',
#       'EE',
#       'SV',
#       'FI',
#       'FR',
#       'GR',
#       'GT',
#       'HN',
#       'HK',
#       'HU',
#       'IS',
#       'IE',
#       'IT',
#       'LV',
#       'LT',
#       'LU',
#       'MY',
#       'MT',
#       'MX',
#       'NL',
#       'NZ',
#       'NI',
#       'NO',
#       'PA',
#       'PY',
#       'PE',
#       'PH',
#       'PL',
#       'PT',
#       'SG',
#       'SK',
#       'ES',
#       'SE',
#       'CH',
#       'TW',
#       'TR',
#       'UY',
#       'US',
#       'GB',
#       'ID',
#       'JP',
#       'TH',
#       'VN',
#       'RO',
#       'IL',
#       'ZA',
#       'SA',
#       'AE',
#       'BH',
#       'QA',
#       'OM',
#       'KW',
#       'EG',
#       'MA',
#       'DZ',
#       'TN',
#       'LB',
#       'JO',
#       'PS',
#       'IN',
#       'UA',
#       'AL',
#       'BA',
#       'HR',
#       'ME',
#       'MK',
#       'RS',
#       'SI',
#       'KR',
#       'LK',
#       'GH',
#       'KE',
#       'NG',
#       'TZ',
#       'UG',
#       'BW',
#       'BF',
#       'CV',
#       'CW',
#       'GM',
#       'GW',
#       'LS',
#       'LR',
#       'MW',
#       'ML',
#       'NA',
#       'NE',
#       'ST',
#       'SN',
#       'SC',
#       'SL',
#       'TT',
#       'BI',
#       'KH',
#       'CM',
#       'TD',
#       'KM',
#       'GQ',
#       'SZ',
#       'GA',
#       'GN',
#       'MR',
#       'RW',
#       'TG',
#       'ZW',
#       'BJ',
#       'MG',
#       'MU',
#       'MZ',
#       'AO',
#       'CI',
#       'DJ',
#       'ZM',
#       'CD',
#       'CG',
#       'IQ',
#       'LY',
#       'VE',
#       'ET',
#       'XK'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/3E5hy15kBWv5bxvHyHzFiI'},
#      'href': 'https://api.spotify.com/v1/albums/3E5hy15kBWv5bxvHyHzFiI',
#      'id': '3E5hy15kBWv5bxvHyHzFiI',
#      'images': [{'height': 640,
#        'width': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273def60d42b0408301ac14d455'},
#       {'height': 300,
#        'width': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02def60d42b0408301ac14d455'},
#       {'height': 64,
#        'width': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851def60d42b0408301ac14d455'}],
#      'is_playable': True,
#      'name': "Grandes Temazos de los 2000's",
#      'release_date': '2023-09-29',
#      'release_date_precision': 'day',
#      'total_tracks': 46,
#      'type': 'album',
#      'uri': 'spotify:album:3E5hy15kBWv5bxvHyHzFiI'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1HY2Jd0NmPuamShAr6KMms'},
#       'href': 'https://api.spotify.com/v1/artists/1HY2Jd0NmPuamShAr6KMms',
#       'id': '1HY2Jd0NmPuamShAr6KMms',
#       'name': 'Lady Gaga',
#       'type': 'artist',
#       'uri': 'spotify:artist:1HY2Jd0NmPuamShAr6KMms'}],
#     'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'SG',
#      'SK',
#      'ES',
#      'SE',
#      'CH',
#      'TW',
#      'TR',
#      'UY',
#      'US',
#      'GB',
#      'ID',
#      'JP',
#      'TH',
#      'VN',
#      'RO',
#      'IL',
#      'ZA',
#      'SA',
#      'AE',
#      'BH',
#      'QA',
#      'OM',
#      'KW',
#      'EG',
#      'MA',
#      'DZ',
#      'TN',
#      'LB',
#      'JO',
#      'PS',
#      'IN',
#      'UA',
#      'AL',
#      'BA',
#      'HR',
#      'ME',
#      'MK',
#      'RS',
#      'SI',
#      'KR',
#      'LK',
#      'GH',
#      'KE',
#      'NG',
#      'TZ',
#      'UG',
#      'BW',
#      'BF',
#      'CV',
#      'CW',
#      'GM',
#      'GW',
#      'LS',
#      'LR',
#      'MW',
#      'ML',
#      'NA',
#      'NE',
#      'ST',
#      'SN',
#      'SC',
#      'SL',
#      'TT',
#      'BI',
#      'KH',
#      'CM',
#      'TD',
#      'KM',
#      'GQ',
#      'SZ',
#      'GA',
#      'GN',
#      'MR',
#      'RW',
#      'TG',
#      'ZW',
#      'BJ',
#      'MG',
#      'MU',
#      'MZ',
#      'AO',
#      'CI',
#      'DJ',
#      'ZM',
#      'CD',
#      'CG',
#      'IQ',
#      'LY',
#      'VE',
#      'ET',
#      'XK'],
#     'disc_number': 1,
#     'duration_ms': 294573,
#     'explicit': True,
#     'external_ids': {'isrc': 'USUM70918596'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/29heGwGQ9GZr1KtmD68JwH'},
#     'href': 'https://api.spotify.com/v1/tracks/29heGwGQ9GZr1KtmD68JwH',
#     'id': '29heGwGQ9GZr1KtmD68JwH',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'Bad Romance',
#     'popularity': 12,
#     'preview_url': None,
#     'track_number': 3,
#     'type': 'track',
#     'uri': 'spotify:track:29heGwGQ9GZr1KtmD68JwH'}]}}

# %%
results = sp.search(q='pignoise', limit=50, type="artist")
results
# Out:
# {'artists': {'href': 'https://api.spotify.com/v1/search?offset=0&limit=50&query=pignoise&type=artist',
#   'limit': 50,
#   'next': 'https://api.spotify.com/v1/search?offset=50&limit=50&query=pignoise&type=artist',
#   'offset': 0,
#   'previous': None,
#   'total': 809,
#   'items': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/21ttsUKZ3y2Hm6nduyvbAw'},
#     'followers': {'href': None, 'total': 223646},
#     'genres': [],
#     'href': 'https://api.spotify.com/v1/artists/21ttsUKZ3y2Hm6nduyvbAw',
#     'id': '21ttsUKZ3y2Hm6nduyvbAw',
#     'images': [{'url': 'https://i.scdn.co/image/ab6761610000e5eb122fb2710ca2041ab1e501b5',
#       'height': 640,
#       'width': 640},
#      {'url': 'https://i.scdn.co/image/ab67616100005174122fb2710ca2041ab1e501b5',
#       'height': 320,
#       'width': 320},
#      {'url': 'https://i.scdn.co/image/ab6761610000f178122fb2710ca2041ab1e501b5',
#       'height': 160,
#       'width': 160}],
#     'name': 'Pignoise',
#     'popularity': 58,
#     'type': 'artist',
#     'uri': 'spotify:artist:21ttsUKZ3y2Hm6nduyvbAw'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/0ndlPDlxgSChUM9bNexLBU'},
#     'followers': {'href': None, 'total': 3523},
#     'genres': [],
#     'href': 'https://api.spotify.com/v1/artists/0ndlPDlxgSChUM9bNexLBU',
#     'id': '0ndlPDlxgSChUM9bNexLBU',
#     'images': [{'url': 'https://i.scdn.co/image/ab6761610000e5ebdfad763081adacc788452c97',
#       'height': 640,
#       'width': 640},
#      {'url': 'https://i.scdn.co/image/ab67616100005174dfad763081adacc788452c97',
#       'height': 320,
#       'width': 320},
#      {'url': 'https://i.scdn.co/image/ab6761610000f178dfad763081adacc788452c97',
#       'height': 160,
#       'width': 160}],
#     'name': 'Chicle',
#     'popularity': 31,
#     'type': 'artist',
#     'uri': 'spotify:artist:0ndlPDlxgSChUM9bNexLBU'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/2uSiDktppOzxVhyf3G3jFp'},
#     'followers': {'href': None, 'total': 721},
#     'genres': [],
#     'href': 'https://api.spotify.com/v1/artists/2uSiDktppOzxVhyf3G3jFp',
#     'id': '2uSiDktppOzxVhyf3G3jFp',
#     'images': [{'url': 'https://i.scdn.co/image/ab67616d0000b273a0eedb97e1b534a8aecbd378',
#       'height': 640,
#       'width': 640},
#      {'url': 'https://i.scdn.co/image/ab67616d00001e02a0eedb97e1b534a8aecbd378',
#       'height': 300,
#       'width': 300},
#      {'url': 'https://i.scdn.co/image/ab67616d00004851a0eedb97e1b534a8aecbd378',
#       'height': 64,
#       'width': 64}],
#     'name': 'Michel Pignolet de Montéclair',
#     'popularity': 13,
#     'type': 'artist',
#     'uri': 'spotify:artist:2uSiDktppOzxVhyf3G3jFp'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/5Hsv8dUHHOdnn72q4XIVz7'},
#     'followers': {'href': None, 'total': 814272},
#     'genres': [],
#     'href': 'https://api.spotify.com/v1/artists/5Hsv8dUHHOdnn72q4XIVz7',
#     'id': '5Hsv8dUHHOdnn72q4XIVz7',
#     'images': [{'url': 'https://i.scdn.co/image/ab6761610000e5ebdc1e8822bc0aa6ebdaa977d8',
#       'height': 640,
#       'width': 640},
#      {'url': 'https://i.scdn.co/image/ab67616100005174dc1e8822bc0aa6ebdaa977d8',
#       'height': 320,
#       'width': 320},
#      {'url': 'https://i.scdn.co/image/ab6761610000f178dc1e8822bc0aa6ebdaa977d8',
#       'height': 160,
#       'width': 160}],
#     'name': 'Leiva',
#     'popularity': 71,
#     'type': 'artist',
#     'uri': 'spotify:artist:5Hsv8dUHHOdnn72q4XIVz7'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/0QE9iXPzgSaBq34OqIZ4n2'},
#     'followers': {'href': None, 'total': 254716},
#     'genres': [],
#     'href': 'https://api.spotify.com/v1/artists/0QE9iXPzgSaBq34OqIZ4n2',
#     'id': '0QE9iXPzgSaBq34OqIZ4n2',
#     'images': [{'url': 'https://i.scdn.co/image/ab6761610000e5eba7d2b195a2dd7dd2829d50d9',
#       'height': 640,
#       'width': 640},
#      {'url': 'https://i.scdn.co/image/ab67616100005174a7d2b195a2dd7dd2829d50d9',
#       'height': 320,
#       'width': 320},
#      {'url': 'https://i.scdn.co/image/ab6761610000f178a7d2b195a2dd7dd2829d50d9',
#       'height': 160,
#       'width': 160}],
#     'name': 'Despistaos',
#     'popularity': 56,
#     'type': 'artist',
#     'uri': 'spotify:artist:0QE9iXPzgSaBq34OqIZ4n2'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/4bWHA8fMNjzfGPQqnh5D6y'},
#     'followers': {'href': None, 'total': 244658},
#     'genres': [],
#     'href': 'https://api.spotify.com/v1/artists/4bWHA8fMNjzfGPQqnh5D6y',
#     'id': '4bWHA8fMNjzfGPQqnh5D6y',
#     'images': [{'url': 'https://i.scdn.co/image/ab6761610000e5ebcfcfe13867ed6653dbca4211',
#       'height': 640,
#       'width': 640},
#      {'url': 'https://i.scdn.co/image/ab67616100005174cfcfe13867ed6653dbca4211',
#       'height': 320,
#       'width': 320},
#      {'url': 'https://i.scdn.co/image/ab6761610000f178cfcfe13867ed6653dbca4211',
#       'height': 160,
#       'width': 160}],
#     'name': 'Recycled J',
#     'popularity': 65,
#     'type': 'artist',
#     'uri': 'spotify:artist:4bWHA8fMNjzfGPQqnh5D6y'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/5RK6c1tyaKpwcDpbgCGNgj'},
#     'followers': {'href': None, 'total': 1125411},
#     'genres': [],
#     'href': 'https://api.spotify.com/v1/artists/5RK6c1tyaKpwcDpbgCGNgj',
#     'id': '5RK6c1tyaKpwcDpbgCGNgj',
#     'images': [{'url': 'https://i.scdn.co/image/ab6761610000e5eb5f251e3951c253901cf172c0',
#       'height': 640,
#       'width': 640},
#      {'url': 'https://i.scdn.co/image/ab676161000051745f251e3951c253901cf172c0',
#       'height': 320,
#       'width': 320},
#      {'url': 'https://i.scdn.co/image/ab6761610000f1785f251e3951c253901cf172c0',
#       'height': 160,
#       'width': 160}],
#     'name': 'El Canto Del Loco',
#     'popularity': 64,
#     'type': 'artist',
#     'uri': 'spotify:artist:5RK6c1tyaKpwcDpbgCGNgj'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/2Wwiu1wnq1W8AMYbWuRFDH'},
#     'followers': {'href': None, 'total': 300182},
#     'genres': ['indie'],
#     'href': 'https://api.spotify.com/v1/artists/2Wwiu1wnq1W8AMYbWuRFDH',
#     'id': '2Wwiu1wnq1W8AMYbWuRFDH',
#     'images': [{'url': 'https://i.scdn.co/image/ab6761610000e5ebb0e5a5d40c435714859d315c',
#       'height': 640,
#       'width': 640},
#      {'url': 'https://i.scdn.co/image/ab67616100005174b0e5a5d40c435714859d315c',
#       'height': 320,
#       'width': 320},
#      {'url': 'https://i.scdn.co/image/ab6761610000f178b0e5a5d40c435714859d315c',
#       'height': 160,
#       'width': 160}],
#     'name': 'Arde Bogotá',
#     'popularity': 65,
#     'type': 'artist',
#     'uri': 'spotify:artist:2Wwiu1wnq1W8AMYbWuRFDH'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/6mfK6Q2tzLMEchAr0e9Uzu'},
#     'followers': {'href': None, 'total': 499885},
#     'genres': [],
#     'href': 'https://api.spotify.com/v1/artists/6mfK6Q2tzLMEchAr0e9Uzu',
#     'id': '6mfK6Q2tzLMEchAr0e9Uzu',
#     'images': [{'url': 'https://i.scdn.co/image/05162685f73db49dd2b446818cfd03a848f67415',
#       'height': 1000,
#       'width': 1000},
#      {'url': 'https://i.scdn.co/image/1a7afe906835d259955b2ffe52d615e9749a8966',
#       'height': 640,
#       'width': 640},
#      {'url': 'https://i.scdn.co/image/dd58615afa1e6191c3852030912c6a8ac2558ea9',
#       'height': 200,
#       'width': 200},
#      {'url': 'https://i.scdn.co/image/3906132ea1b69ed3b59477e44362be491cff55bd',
#       'height': 64,
#       'width': 64}],
#     'name': 'Pereza',
#     'popularity': 58,
#     'type': 'artist',
#     'uri': 'spotify:artist:6mfK6Q2tzLMEchAr0e9Uzu'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/2hazSY4Ef3aB9ATXW7F5w3'},
#     'followers': {'href': None, 'total': 663355},
#     'genres': ['indie'],
#     'href': 'https://api.spotify.com/v1/artists/2hazSY4Ef3aB9ATXW7F5w3',
#     'id': '2hazSY4Ef3aB9ATXW7F5w3',
#     'images': [{'url': 'https://i.scdn.co/image/ab6761610000e5eb6f45d6973fc2dbf17612b8cc',
#       'height': 640,
#       'width': 640},
#      {'url': 'https://i.scdn.co/image/ab676161000051746f45d6973fc2dbf17612b8cc',
#       'height': 320,
#       'width': 320},
#      {'url': 'https://i.scdn.co/image/ab6761610000f1786f45d6973fc2dbf17612b8cc',
#       'height': 160,
#       'width': 160}],
#     'name': 'IZAL',
#     'popularity': 61,
#     'type': 'artist',
#     'uri': 'spotify:artist:2hazSY4Ef3aB9ATXW7F5w3'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/1EXjXQpDx2pROygh8zvHs4'},
#     'followers': {'href': None, 'total': 4410703},
#     'genres': ['flamenco', 'flamenco pop'],
#     'href': 'https://api.spotify.com/v1/artists/1EXjXQpDx2pROygh8zvHs4',
#     'id': '1EXjXQpDx2pROygh8zvHs4',
#     'images': [{'url': 'https://i.scdn.co/image/ab6761610000e5eb69b92908b14aa8f0b4cd175d',
#       'height': 640,
#       'width': 640},
#      {'url': 'https://i.scdn.co/image/ab6761610000517469b92908b14aa8f0b4cd175d',
#       'height': 320,
#       'width': 320},
#      {'url': 'https://i.scdn.co/image/ab6761610000f17869b92908b14aa8f0b4cd175d',
#       'height': 160,
#       'width': 160}],
#     'name': 'Melendi',
#     'popularity': 76,
#     'type': 'artist',
#     'uri': 'spotify:artist:1EXjXQpDx2pROygh8zvHs4'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/57s0ep3eNSg81D7ZxiuHbC'},
#     'followers': {'href': None, 'total': 197156},
#     'genres': ['indie'],
#     'href': 'https://api.spotify.com/v1/artists/57s0ep3eNSg81D7ZxiuHbC',
#     'id': '57s0ep3eNSg81D7ZxiuHbC',
#     'images': [{'url': 'https://i.scdn.co/image/ab6761610000e5eb4c12fc727c2d1a1b0f10214a',
#       'height': 640,
#       'width': 640},
#      {'url': 'https://i.scdn.co/image/ab676161000051744c12fc727c2d1a1b0f10214a',
#       'height': 320,
#       'width': 320},
#      {'url': 'https://i.scdn.co/image/ab6761610000f1784c12fc727c2d1a1b0f10214a',
#       'height': 160,
#       'width': 160}],
#     'name': 'Viva Suecia',
#     'popularity': 65,
#     'type': 'artist',
#     'uri': 'spotify:artist:57s0ep3eNSg81D7ZxiuHbC'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/5Q30fhTc0Sl0Q4C5dOjhhQ'},
#     'followers': {'href': None, 'total': 170920},
#     'genres': [],
#     'href': 'https://api.spotify.com/v1/artists/5Q30fhTc0Sl0Q4C5dOjhhQ',
#     'id': '5Q30fhTc0Sl0Q4C5dOjhhQ',
#     'images': [{'url': 'https://i.scdn.co/image/ab6761610000e5eb96c3b75abfb6b8cd7e03e2be',
#       'height': 640,
#       'width': 640},
#      {'url': 'https://i.scdn.co/image/ab6761610000517496c3b75abfb6b8cd7e03e2be',
#       'height': 320,
#       'width': 320},
#      {'url': 'https://i.scdn.co/image/ab6761610000f17896c3b75abfb6b8cd7e03e2be',
#       'height': 160,
#       'width': 160}],
#     'name': 'La La Love You',
#     'popularity': 65,
#     'type': 'artist',
#     'uri': 'spotify:artist:5Q30fhTc0Sl0Q4C5dOjhhQ'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/5q3atpVIFpXkHlcOKyK0H4'},
#     'followers': {'href': None, 'total': 89222},
#     'genres': ['indie'],
#     'href': 'https://api.spotify.com/v1/artists/5q3atpVIFpXkHlcOKyK0H4',
#     'id': '5q3atpVIFpXkHlcOKyK0H4',
#     'images': [{'url': 'https://i.scdn.co/image/ab6761610000e5ebde9c36c6a54845a3cdb129b5',
#       'height': 640,
#       'width': 640},
#      {'url': 'https://i.scdn.co/image/ab67616100005174de9c36c6a54845a3cdb129b5',
#       'height': 320,
#       'width': 320},
#      {'url': 'https://i.scdn.co/image/ab6761610000f178de9c36c6a54845a3cdb129b5',
#       'height': 160,
#       'width': 160}],
#     'name': 'Siloé',
#     'popularity': 61,
#     'type': 'artist',
#     'uri': 'spotify:artist:5q3atpVIFpXkHlcOKyK0H4'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/6i0h6wBrfNkdf3eTUoelpP'},
#     'followers': {'href': None, 'total': 41853},
#     'genres': [],
#     'href': 'https://api.spotify.com/v1/artists/6i0h6wBrfNkdf3eTUoelpP',
#     'id': '6i0h6wBrfNkdf3eTUoelpP',
#     'images': [{'url': 'https://i.scdn.co/image/ab6761610000e5eb28ed335e967eab5b7010adb5',
#       'height': 640,
#       'width': 640},
#      {'url': 'https://i.scdn.co/image/ab6761610000517428ed335e967eab5b7010adb5',
#       'height': 320,
#       'width': 320},
#      {'url': 'https://i.scdn.co/image/ab6761610000f17828ed335e967eab5b7010adb5',
#       'height': 160,
#       'width': 160}],
#     'name': 'Malmö 040',
#     'popularity': 58,
#     'type': 'artist',
#     'uri': 'spotify:artist:6i0h6wBrfNkdf3eTUoelpP'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/3WQRkINylwwkw1Ya07ToRK'},
#     'followers': {'href': None, 'total': 240124},
#     'genres': [],
#     'href': 'https://api.spotify.com/v1/artists/3WQRkINylwwkw1Ya07ToRK',
#     'id': '3WQRkINylwwkw1Ya07ToRK',
#     'images': [{'url': 'https://i.scdn.co/image/ab6761610000e5ebfc4aaacf4b09c75cc2144730',
#       'height': 640,
#       'width': 640},
#      {'url': 'https://i.scdn.co/image/ab67616100005174fc4aaacf4b09c75cc2144730',
#       'height': 320,
#       'width': 320},
#      {'url': 'https://i.scdn.co/image/ab6761610000f178fc4aaacf4b09c75cc2144730',
#       'height': 160,
#       'width': 160}],
#     'name': 'Robe',
#     'popularity': 62,
#     'type': 'artist',
#     'uri': 'spotify:artist:3WQRkINylwwkw1Ya07ToRK'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/5ZqnEfVdEGmoPxtELhN7ai'},
#     'followers': {'href': None, 'total': 2292943},
#     'genres': ['flamenco', 'flamenco pop'],
#     'href': 'https://api.spotify.com/v1/artists/5ZqnEfVdEGmoPxtELhN7ai',
#     'id': '5ZqnEfVdEGmoPxtELhN7ai',
#     'images': [{'url': 'https://i.scdn.co/image/ab6761610000e5ebfc35d983d1fd3469013ee1ab',
#       'height': 640,
#       'width': 640},
#      {'url': 'https://i.scdn.co/image/ab67616100005174fc35d983d1fd3469013ee1ab',
#       'height': 320,
#       'width': 320},
#      {'url': 'https://i.scdn.co/image/ab6761610000f178fc35d983d1fd3469013ee1ab',
#       'height': 160,
#       'width': 160}],
#     'name': 'Estopa',
#     'popularity': 71,
#     'type': 'artist',
#     'uri': 'spotify:artist:5ZqnEfVdEGmoPxtELhN7ai'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/6dhhE0bRngFuvKe3vnzdKn'},
#     'followers': {'href': None, 'total': 21374},
#     'genres': [],
#     'href': 'https://api.spotify.com/v1/artists/6dhhE0bRngFuvKe3vnzdKn',
#     'id': '6dhhE0bRngFuvKe3vnzdKn',
#     'images': [{'url': 'https://i.scdn.co/image/ab6761610000e5ebad3f08042dec96771546a74c',
#       'height': 640,
#       'width': 640},
#      {'url': 'https://i.scdn.co/image/ab67616100005174ad3f08042dec96771546a74c',
#       'height': 320,
#       'width': 320},
#      {'url': 'https://i.scdn.co/image/ab6761610000f178ad3f08042dec96771546a74c',
#       'height': 160,
#       'width': 160}],
#     'name': 'Yapi',
#     'popularity': 63,
#     'type': 'artist',
#     'uri': 'spotify:artist:6dhhE0bRngFuvKe3vnzdKn'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/3heR1it0slFXjaa7E62zpw'},
#     'followers': {'href': None, 'total': 612868},
#     'genres': [],
#     'href': 'https://api.spotify.com/v1/artists/3heR1it0slFXjaa7E62zpw',
#     'id': '3heR1it0slFXjaa7E62zpw',
#     'images': [{'url': 'https://i.scdn.co/image/ab6761610000e5eb501a7e548e27006fb0292e1c',
#       'height': 640,
#       'width': 640},
#      {'url': 'https://i.scdn.co/image/ab67616100005174501a7e548e27006fb0292e1c',
#       'height': 320,
#       'width': 320},
#      {'url': 'https://i.scdn.co/image/ab6761610000f178501a7e548e27006fb0292e1c',
#       'height': 160,
#       'width': 160}],
#     'name': 'Maldita Nerea',
#     'popularity': 55,
#     'type': 'artist',
#     'uri': 'spotify:artist:3heR1it0slFXjaa7E62zpw'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/1WLEfsQjvgtFSGkrHonzFX'},
#     'followers': {'href': None, 'total': 355094},
#     'genres': [],
#     'href': 'https://api.spotify.com/v1/artists/1WLEfsQjvgtFSGkrHonzFX',
#     'id': '1WLEfsQjvgtFSGkrHonzFX',
#     'images': [{'url': 'https://i.scdn.co/image/ab6761610000e5ebd8c27cf88071ec8df272ac50',
#       'height': 640,
#       'width': 640},
#      {'url': 'https://i.scdn.co/image/ab67616100005174d8c27cf88071ec8df272ac50',
#       'height': 320,
#       'width': 320},
#      {'url': 'https://i.scdn.co/image/ab6761610000f178d8c27cf88071ec8df272ac50',
#       'height': 160,
#       'width': 160}],
#     'name': 'Amaia',
#     'popularity': 60,
#     'type': 'artist',
#     'uri': 'spotify:artist:1WLEfsQjvgtFSGkrHonzFX'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/2enhM5DK9oTxWiCVpFIDv3'},
#     'followers': {'href': None, 'total': 70406},
#     'genres': [],
#     'href': 'https://api.spotify.com/v1/artists/2enhM5DK9oTxWiCVpFIDv3',
#     'id': '2enhM5DK9oTxWiCVpFIDv3',
#     'images': [{'url': 'https://i.scdn.co/image/ab6761610000e5ebcdf26d94f82d8f61d66a9d6b',
#       'height': 640,
#       'width': 640},
#      {'url': 'https://i.scdn.co/image/ab67616100005174cdf26d94f82d8f61d66a9d6b',
#       'height': 320,
#       'width': 320},
#      {'url': 'https://i.scdn.co/image/ab6761610000f178cdf26d94f82d8f61d66a9d6b',
#       'height': 160,
#       'width': 160}],
#     'name': 'Figa Flawas',
#     'popularity': 58,
#     'type': 'artist',
#     'uri': 'spotify:artist:2enhM5DK9oTxWiCVpFIDv3'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/2X11x8C63wCzAf1WwsIuLg'},
#     'followers': {'href': None, 'total': 262107},
#     'genres': [],
#     'href': 'https://api.spotify.com/v1/artists/2X11x8C63wCzAf1WwsIuLg',
#     'id': '2X11x8C63wCzAf1WwsIuLg',
#     'images': [{'url': 'https://i.scdn.co/image/ab6761610000e5eb277f8bdb28960238dae52128',
#       'height': 640,
#       'width': 640},
#      {'url': 'https://i.scdn.co/image/ab67616100005174277f8bdb28960238dae52128',
#       'height': 320,
#       'width': 320},
#      {'url': 'https://i.scdn.co/image/ab6761610000f178277f8bdb28960238dae52128',
#       'height': 160,
#       'width': 160}],
#     'name': 'Kaze',
#     'popularity': 58,
#     'type': 'artist',
#     'uri': 'spotify:artist:2X11x8C63wCzAf1WwsIuLg'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/7D62OQfwvslnxJn9DkZm2F'},
#     'followers': {'href': None, 'total': 182526},
#     'genres': [],
#     'href': 'https://api.spotify.com/v1/artists/7D62OQfwvslnxJn9DkZm2F',
#     'id': '7D62OQfwvslnxJn9DkZm2F',
#     'images': [{'url': 'https://i.scdn.co/image/ab6761610000e5eb8f5b61e3b06b4f6ec3766913',
#       'height': 640,
#       'width': 640},
#      {'url': 'https://i.scdn.co/image/ab676161000051748f5b61e3b06b4f6ec3766913',
#       'height': 320,
#       'width': 320},
#      {'url': 'https://i.scdn.co/image/ab6761610000f1788f5b61e3b06b4f6ec3766913',
#       'height': 160,
#       'width': 160}],
#     'name': 'Pole.',
#     'popularity': 55,
#     'type': 'artist',
#     'uri': 'spotify:artist:7D62OQfwvslnxJn9DkZm2F'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/1x8mAhfvCw7JXRX7Ild0lF'},
#     'followers': {'href': None, 'total': 28741},
#     'genres': [],
#     'href': 'https://api.spotify.com/v1/artists/1x8mAhfvCw7JXRX7Ild0lF',
#     'id': '1x8mAhfvCw7JXRX7Ild0lF',
#     'images': [{'url': 'https://i.scdn.co/image/ab6761610000e5ebf48f918c99f85b02cf43b6bc',
#       'height': 640,
#       'width': 640},
#      {'url': 'https://i.scdn.co/image/ab67616100005174f48f918c99f85b02cf43b6bc',
#       'height': 320,
#       'width': 320},
#      {'url': 'https://i.scdn.co/image/ab6761610000f178f48f918c99f85b02cf43b6bc',
#       'height': 160,
#       'width': 160}],
#     'name': 'Hey Kid',
#     'popularity': 59,
#     'type': 'artist',
#     'uri': 'spotify:artist:1x8mAhfvCw7JXRX7Ild0lF'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/6WCTfR8dIuTqWrFrzt2yl0'},
#     'followers': {'href': None, 'total': 47386},
#     'genres': [],
#     'href': 'https://api.spotify.com/v1/artists/6WCTfR8dIuTqWrFrzt2yl0',
#     'id': '6WCTfR8dIuTqWrFrzt2yl0',
#     'images': [{'url': 'https://i.scdn.co/image/ab6761610000e5ebffc3d0acfa836722752a397d',
#       'height': 640,
#       'width': 640},
#      {'url': 'https://i.scdn.co/image/ab67616100005174ffc3d0acfa836722752a397d',
#       'height': 320,
#       'width': 320},
#      {'url': 'https://i.scdn.co/image/ab6761610000f178ffc3d0acfa836722752a397d',
#       'height': 160,
#       'width': 160}],
#     'name': 'mvrk',
#     'popularity': 58,
#     'type': 'artist',
#     'uri': 'spotify:artist:6WCTfR8dIuTqWrFrzt2yl0'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/7eH1UUCyxL8Wf9PztvvPJ6'},
#     'followers': {'href': None, 'total': 375049},
#     'genres': [],
#     'href': 'https://api.spotify.com/v1/artists/7eH1UUCyxL8Wf9PztvvPJ6',
#     'id': '7eH1UUCyxL8Wf9PztvvPJ6',
#     'images': [{'url': 'https://i.scdn.co/image/ab6761610000e5eb12a46f4c57418cbea452e729',
#       'height': 640,
#       'width': 640},
#      {'url': 'https://i.scdn.co/image/ab6761610000517412a46f4c57418cbea452e729',
#       'height': 320,
#       'width': 320},
#      {'url': 'https://i.scdn.co/image/ab6761610000f17812a46f4c57418cbea452e729',
#       'height': 160,
#       'width': 160}],
#     'name': 'Arce',
#     'popularity': 57,
#     'type': 'artist',
#     'uri': 'spotify:artist:7eH1UUCyxL8Wf9PztvvPJ6'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/5AiFFE0KopBkOzEZeDbSaH'},
#     'followers': {'href': None, 'total': 31326},
#     'genres': [],
#     'href': 'https://api.spotify.com/v1/artists/5AiFFE0KopBkOzEZeDbSaH',
#     'id': '5AiFFE0KopBkOzEZeDbSaH',
#     'images': [{'url': 'https://i.scdn.co/image/ab6761610000e5ebc0729d1e0f9bede70c8d7e05',
#       'height': 640,
#       'width': 640},
#      {'url': 'https://i.scdn.co/image/ab67616100005174c0729d1e0f9bede70c8d7e05',
#       'height': 320,
#       'width': 320},
#      {'url': 'https://i.scdn.co/image/ab6761610000f178c0729d1e0f9bede70c8d7e05',
#       'height': 160,
#       'width': 160}],
#     'name': 'céro',
#     'popularity': 56,
#     'type': 'artist',
#     'uri': 'spotify:artist:5AiFFE0KopBkOzEZeDbSaH'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/5f7z2thkqWrA4vp5Hh476O'},
#     'followers': {'href': None, 'total': 43170},
#     'genres': [],
#     'href': 'https://api.spotify.com/v1/artists/5f7z2thkqWrA4vp5Hh476O',
#     'id': '5f7z2thkqWrA4vp5Hh476O',
#     'images': [{'url': 'https://i.scdn.co/image/ab6761610000e5ebf94c02383244a018f75191ce',
#       'height': 640,
#       'width': 640},
#      {'url': 'https://i.scdn.co/image/ab67616100005174f94c02383244a018f75191ce',
#       'height': 320,
#       'width': 320},
#      {'url': 'https://i.scdn.co/image/ab6761610000f178f94c02383244a018f75191ce',
#       'height': 160,
#       'width': 160}],
#     'name': 'Enol',
#     'popularity': 54,
#     'type': 'artist',
#     'uri': 'spotify:artist:5f7z2thkqWrA4vp5Hh476O'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/7BdgXLhynRQk78pKkhAsAR'},
#     'followers': {'href': None, 'total': 99814},
#     'genres': [],
#     'href': 'https://api.spotify.com/v1/artists/7BdgXLhynRQk78pKkhAsAR',
#     'id': '7BdgXLhynRQk78pKkhAsAR',
#     'images': [{'url': 'https://i.scdn.co/image/ab6761610000e5ebd48d49799b84c8db071b4a6c',
#       'height': 640,
#       'width': 640},
#      {'url': 'https://i.scdn.co/image/ab67616100005174d48d49799b84c8db071b4a6c',
#       'height': 320,
#       'width': 320},
#      {'url': 'https://i.scdn.co/image/ab6761610000f178d48d49799b84c8db071b4a6c',
#       'height': 160,
#       'width': 160}],
#     'name': 'Buhos',
#     'popularity': 52,
#     'type': 'artist',
#     'uri': 'spotify:artist:7BdgXLhynRQk78pKkhAsAR'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/6c4WWQ2PYJlgnxtkQKqI5s'},
#     'followers': {'href': None, 'total': 134813},
#     'genres': ['flamenco', 'flamenco urbano', 'flamenco pop'],
#     'href': 'https://api.spotify.com/v1/artists/6c4WWQ2PYJlgnxtkQKqI5s',
#     'id': '6c4WWQ2PYJlgnxtkQKqI5s',
#     'images': [{'url': 'https://i.scdn.co/image/ab6761610000e5eb91ba42d2cee643f6186de9de',
#       'height': 640,
#       'width': 640},
#      {'url': 'https://i.scdn.co/image/ab6761610000517491ba42d2cee643f6186de9de',
#       'height': 320,
#       'width': 320},
#      {'url': 'https://i.scdn.co/image/ab6761610000f17891ba42d2cee643f6186de9de',
#       'height': 160,
#       'width': 160}],
#     'name': 'Haze',
#     'popularity': 55,
#     'type': 'artist',
#     'uri': 'spotify:artist:6c4WWQ2PYJlgnxtkQKqI5s'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/6rRTrEHzGSDqhmFJQrNFMO'},
#     'followers': {'href': None, 'total': 94888},
#     'genres': ['indie'],
#     'href': 'https://api.spotify.com/v1/artists/6rRTrEHzGSDqhmFJQrNFMO',
#     'id': '6rRTrEHzGSDqhmFJQrNFMO',
#     'images': [{'url': 'https://i.scdn.co/image/ab6761610000e5eb47c7be3b80adc31e625ef572',
#       'height': 640,
#       'width': 640},
#      {'url': 'https://i.scdn.co/image/ab6761610000517447c7be3b80adc31e625ef572',
#       'height': 320,
#       'width': 320},
#      {'url': 'https://i.scdn.co/image/ab6761610000f17847c7be3b80adc31e625ef572',
#       'height': 160,
#       'width': 160}],
#     'name': 'Shinova',
#     'popularity': 56,
#     'type': 'artist',
#     'uri': 'spotify:artist:6rRTrEHzGSDqhmFJQrNFMO'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/4H3BAAfpEcLHQkaQKfvoW8'},
#     'followers': {'href': None, 'total': 87011},
#     'genres': ['indie'],
#     'href': 'https://api.spotify.com/v1/artists/4H3BAAfpEcLHQkaQKfvoW8',
#     'id': '4H3BAAfpEcLHQkaQKfvoW8',
#     'images': [{'url': 'https://i.scdn.co/image/ab6761610000e5eb7181daa668d0807ddb8f83d7',
#       'height': 640,
#       'width': 640},
#      {'url': 'https://i.scdn.co/image/ab676161000051747181daa668d0807ddb8f83d7',
#       'height': 320,
#       'width': 320},
#      {'url': 'https://i.scdn.co/image/ab6761610000f1787181daa668d0807ddb8f83d7',
#       'height': 160,
#       'width': 160}],
#     'name': 'Mikel Izal',
#     'popularity': 56,
#     'type': 'artist',
#     'uri': 'spotify:artist:4H3BAAfpEcLHQkaQKfvoW8'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/6goQbtqjPhPns8RVRXTyp7'},
#     'followers': {'href': None, 'total': 37069},
#     'genres': ['hyperpop'],
#     'href': 'https://api.spotify.com/v1/artists/6goQbtqjPhPns8RVRXTyp7',
#     'id': '6goQbtqjPhPns8RVRXTyp7',
#     'images': [{'url': 'https://i.scdn.co/image/ab6761610000e5ebc19dbbdc36c4812e6a861532',
#       'height': 640,
#       'width': 640},
#      {'url': 'https://i.scdn.co/image/ab67616100005174c19dbbdc36c4812e6a861532',
#       'height': 320,
#       'width': 320},
#      {'url': 'https://i.scdn.co/image/ab6761610000f178c19dbbdc36c4812e6a861532',
#       'height': 160,
#       'width': 160}],
#     'name': 'Mda',
#     'popularity': 52,
#     'type': 'artist',
#     'uri': 'spotify:artist:6goQbtqjPhPns8RVRXTyp7'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/3iY9PS7LxPnCVcCP7BjJOK'},
#     'followers': {'href': None, 'total': 106650},
#     'genres': [],
#     'href': 'https://api.spotify.com/v1/artists/3iY9PS7LxPnCVcCP7BjJOK',
#     'id': '3iY9PS7LxPnCVcCP7BjJOK',
#     'images': [{'url': 'https://i.scdn.co/image/ab6761610000e5ebafe4c6dd93f23a44e71d1327',
#       'height': 640,
#       'width': 640},
#      {'url': 'https://i.scdn.co/image/ab67616100005174afe4c6dd93f23a44e71d1327',
#       'height': 320,
#       'width': 320},
#      {'url': 'https://i.scdn.co/image/ab6761610000f178afe4c6dd93f23a44e71d1327',
#       'height': 160,
#       'width': 160}],
#     'name': 'Hens',
#     'popularity': 53,
#     'type': 'artist',
#     'uri': 'spotify:artist:3iY9PS7LxPnCVcCP7BjJOK'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/5ZCfjramRRGj3D72drnyxK'},
#     'followers': {'href': None, 'total': 5228},
#     'genres': [],
#     'href': 'https://api.spotify.com/v1/artists/5ZCfjramRRGj3D72drnyxK',
#     'id': '5ZCfjramRRGj3D72drnyxK',
#     'images': [{'url': 'https://i.scdn.co/image/ab6761610000e5ebd1bedfe56531fdca74c79e82',
#       'height': 640,
#       'width': 640},
#      {'url': 'https://i.scdn.co/image/ab67616100005174d1bedfe56531fdca74c79e82',
#       'height': 320,
#       'width': 320},
#      {'url': 'https://i.scdn.co/image/ab6761610000f178d1bedfe56531fdca74c79e82',
#       'height': 160,
#       'width': 160}],
#     'name': 'PMP',
#     'popularity': 54,
#     'type': 'artist',
#     'uri': 'spotify:artist:5ZCfjramRRGj3D72drnyxK'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/2k60o7SVpOKmzpuTEAG3L8'},
#     'followers': {'href': None, 'total': 48085},
#     'genres': ['indie'],
#     'href': 'https://api.spotify.com/v1/artists/2k60o7SVpOKmzpuTEAG3L8',
#     'id': '2k60o7SVpOKmzpuTEAG3L8',
#     'images': [{'url': 'https://i.scdn.co/image/ab6761610000e5eb81cf62f84778c645a2902fe2',
#       'height': 640,
#       'width': 640},
#      {'url': 'https://i.scdn.co/image/ab6761610000517481cf62f84778c645a2902fe2',
#       'height': 320,
#       'width': 320},
#      {'url': 'https://i.scdn.co/image/ab6761610000f17881cf62f84778c645a2902fe2',
#       'height': 160,
#       'width': 160}],
#     'name': 'Veintiuno',
#     'popularity': 54,
#     'type': 'artist',
#     'uri': 'spotify:artist:2k60o7SVpOKmzpuTEAG3L8'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/2z1MpPojFcvxYcEAx0lT6w'},
#     'followers': {'href': None, 'total': 125199},
#     'genres': [],
#     'href': 'https://api.spotify.com/v1/artists/2z1MpPojFcvxYcEAx0lT6w',
#     'id': '2z1MpPojFcvxYcEAx0lT6w',
#     'images': [{'url': 'https://i.scdn.co/image/ab6761610000e5eb6230315d35c6867a0ca6223c',
#       'height': 640,
#       'width': 640},
#      {'url': 'https://i.scdn.co/image/ab676161000051746230315d35c6867a0ca6223c',
#       'height': 320,
#       'width': 320},
#      {'url': 'https://i.scdn.co/image/ab6761610000f1786230315d35c6867a0ca6223c',
#       'height': 160,
#       'width': 160}],
#     'name': 'Vicco',
#     'popularity': 57,
#     'type': 'artist',
#     'uri': 'spotify:artist:2z1MpPojFcvxYcEAx0lT6w'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/1DiDa1DfTjldKJQeonyP33'},
#     'followers': {'href': None, 'total': 43932},
#     'genres': [],
#     'href': 'https://api.spotify.com/v1/artists/1DiDa1DfTjldKJQeonyP33',
#     'id': '1DiDa1DfTjldKJQeonyP33',
#     'images': [{'url': 'https://i.scdn.co/image/ab6761610000e5eb10b50bcb6eec2e2e1fe26f45',
#       'height': 640,
#       'width': 640},
#      {'url': 'https://i.scdn.co/image/ab6761610000517410b50bcb6eec2e2e1fe26f45',
#       'height': 320,
#       'width': 320},
#      {'url': 'https://i.scdn.co/image/ab6761610000f17810b50bcb6eec2e2e1fe26f45',
#       'height': 160,
#       'width': 160}],
#     'name': 'shego',
#     'popularity': 49,
#     'type': 'artist',
#     'uri': 'spotify:artist:1DiDa1DfTjldKJQeonyP33'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/7a3ryRcO3alwbqaX4RagzM'},
#     'followers': {'href': None, 'total': 137644},
#     'genres': [],
#     'href': 'https://api.spotify.com/v1/artists/7a3ryRcO3alwbqaX4RagzM',
#     'id': '7a3ryRcO3alwbqaX4RagzM',
#     'images': [{'url': 'https://i.scdn.co/image/ab6761610000e5ebd70ccdaaf310d5d99aab8845',
#       'height': 640,
#       'width': 640},
#      {'url': 'https://i.scdn.co/image/ab67616100005174d70ccdaaf310d5d99aab8845',
#       'height': 320,
#       'width': 320},
#      {'url': 'https://i.scdn.co/image/ab6761610000f178d70ccdaaf310d5d99aab8845',
#       'height': 160,
#       'width': 160}],
#     'name': 'ZOO',
#     'popularity': 53,
#     'type': 'artist',
#     'uri': 'spotify:artist:7a3ryRcO3alwbqaX4RagzM'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/1TYjm48WP4AXoXMModkcNg'},
#     'followers': {'href': None, 'total': 2105},
#     'genres': [],
#     'href': 'https://api.spotify.com/v1/artists/1TYjm48WP4AXoXMModkcNg',
#     'id': '1TYjm48WP4AXoXMModkcNg',
#     'images': [{'url': 'https://i.scdn.co/image/ab6761610000e5eb2e1ca2f5943d3b80f79ecf10',
#       'height': 640,
#       'width': 640},
#      {'url': 'https://i.scdn.co/image/ab676161000051742e1ca2f5943d3b80f79ecf10',
#       'height': 320,
#       'width': 320},
#      {'url': 'https://i.scdn.co/image/ab6761610000f1782e1ca2f5943d3b80f79ecf10',
#       'height': 160,
#       'width': 160}],
#     'name': 'Bexnil',
#     'popularity': 53,
#     'type': 'artist',
#     'uri': 'spotify:artist:1TYjm48WP4AXoXMModkcNg'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/5kdLOinhQnlSk4su7U6lyW'},
#     'followers': {'href': None, 'total': 125207},
#     'genres': [],
#     'href': 'https://api.spotify.com/v1/artists/5kdLOinhQnlSk4su7U6lyW',
#     'id': '5kdLOinhQnlSk4su7U6lyW',
#     'images': [{'url': 'https://i.scdn.co/image/ab67616d0000b273adf033dfc19dc1d205106d11',
#       'height': 640,
#       'width': 640},
#      {'url': 'https://i.scdn.co/image/ab67616d00001e02adf033dfc19dc1d205106d11',
#       'height': 300,
#       'width': 300},
#      {'url': 'https://i.scdn.co/image/ab67616d00004851adf033dfc19dc1d205106d11',
#       'height': 64,
#       'width': 64}],
#     'name': 'Dover',
#     'popularity': 49,
#     'type': 'artist',
#     'uri': 'spotify:artist:5kdLOinhQnlSk4su7U6lyW'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/3Rk6ZWHH97W7zdoehmzt5G'},
#     'followers': {'href': None, 'total': 18903},
#     'genres': ['flamenco pop', 'flamenco', 'flamenco urbano'],
#     'href': 'https://api.spotify.com/v1/artists/3Rk6ZWHH97W7zdoehmzt5G',
#     'id': '3Rk6ZWHH97W7zdoehmzt5G',
#     'images': [{'url': 'https://i.scdn.co/image/ab6761610000e5ebe814537341f0a934c578cb66',
#       'height': 640,
#       'width': 640},
#      {'url': 'https://i.scdn.co/image/ab67616100005174e814537341f0a934c578cb66',
#       'height': 320,
#       'width': 320},
#      {'url': 'https://i.scdn.co/image/ab6761610000f178e814537341f0a934c578cb66',
#       'height': 160,
#       'width': 160}],
#     'name': 'Pikeras',
#     'popularity': 47,
#     'type': 'artist',
#     'uri': 'spotify:artist:3Rk6ZWHH97W7zdoehmzt5G'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/77NuLmVgB5nIh0HEe6tmqX'},
#     'followers': {'href': None, 'total': 121951},
#     'genres': [],
#     'href': 'https://api.spotify.com/v1/artists/77NuLmVgB5nIh0HEe6tmqX',
#     'id': '77NuLmVgB5nIh0HEe6tmqX',
#     'images': [{'url': 'https://i.scdn.co/image/ab6761610000e5eb63de4798a51287babacf8e3f',
#       'height': 640,
#       'width': 640},
#      {'url': 'https://i.scdn.co/image/ab6761610000517463de4798a51287babacf8e3f',
#       'height': 320,
#       'width': 320},
#      {'url': 'https://i.scdn.co/image/ab6761610000f17863de4798a51287babacf8e3f',
#       'height': 160,
#       'width': 160}],
#     'name': 'Pecos',
#     'popularity': 50,
#     'type': 'artist',
#     'uri': 'spotify:artist:77NuLmVgB5nIh0HEe6tmqX'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/5FQJWdcKPAijmEi4uroZ4h'},
#     'followers': {'href': None, 'total': 59573},
#     'genres': [],
#     'href': 'https://api.spotify.com/v1/artists/5FQJWdcKPAijmEi4uroZ4h',
#     'id': '5FQJWdcKPAijmEi4uroZ4h',
#     'images': [{'url': 'https://i.scdn.co/image/ab6761610000e5eb107dd4582f0c1cdc09b86b2a',
#       'height': 640,
#       'width': 640},
#      {'url': 'https://i.scdn.co/image/ab67616100005174107dd4582f0c1cdc09b86b2a',
#       'height': 320,
#       'width': 320},
#      {'url': 'https://i.scdn.co/image/ab6761610000f178107dd4582f0c1cdc09b86b2a',
#       'height': 160,
#       'width': 160}],
#     'name': 'LEÏTI',
#     'popularity': 50,
#     'type': 'artist',
#     'uri': 'spotify:artist:5FQJWdcKPAijmEi4uroZ4h'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/1DzHYzxnMTpElJgNoq1bEH'},
#     'followers': {'href': None, 'total': 1184},
#     'genres': [],
#     'href': 'https://api.spotify.com/v1/artists/1DzHYzxnMTpElJgNoq1bEH',
#     'id': '1DzHYzxnMTpElJgNoq1bEH',
#     'images': [{'url': 'https://i.scdn.co/image/ab6761610000e5eb4b7a810a75336a94c7fe951c',
#       'height': 640,
#       'width': 640},
#      {'url': 'https://i.scdn.co/image/ab676161000051744b7a810a75336a94c7fe951c',
#       'height': 320,
#       'width': 320},
#      {'url': 'https://i.scdn.co/image/ab6761610000f1784b7a810a75336a94c7fe951c',
#       'height': 160,
#       'width': 160}],
#     'name': 'GIO',
#     'popularity': 50,
#     'type': 'artist',
#     'uri': 'spotify:artist:1DzHYzxnMTpElJgNoq1bEH'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/4ckWVaYN8j0EZrNFRHmxZx'},
#     'followers': {'href': None, 'total': 33976},
#     'genres': [],
#     'href': 'https://api.spotify.com/v1/artists/4ckWVaYN8j0EZrNFRHmxZx',
#     'id': '4ckWVaYN8j0EZrNFRHmxZx',
#     'images': [{'url': 'https://i.scdn.co/image/ab6761610000e5eb77d8fdc8d6ce3f497d88a6b4',
#       'height': 640,
#       'width': 640},
#      {'url': 'https://i.scdn.co/image/ab6761610000517477d8fdc8d6ce3f497d88a6b4',
#       'height': 320,
#       'width': 320},
#      {'url': 'https://i.scdn.co/image/ab6761610000f17877d8fdc8d6ce3f497d88a6b4',
#       'height': 160,
#       'width': 160}],
#     'name': 'Marmi',
#     'popularity': 50,
#     'type': 'artist',
#     'uri': 'spotify:artist:4ckWVaYN8j0EZrNFRHmxZx'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/7He3EH9c66ZwBtIMHGdyIA'},
#     'followers': {'href': None, 'total': 59338},
#     'genres': [],
#     'href': 'https://api.spotify.com/v1/artists/7He3EH9c66ZwBtIMHGdyIA',
#     'id': '7He3EH9c66ZwBtIMHGdyIA',
#     'images': [{'url': 'https://i.scdn.co/image/ab6761610000e5eb111be6b06743b8f31ed24a9d',
#       'height': 640,
#       'width': 640},
#      {'url': 'https://i.scdn.co/image/ab67616100005174111be6b06743b8f31ed24a9d',
#       'height': 320,
#       'width': 320},
#      {'url': 'https://i.scdn.co/image/ab6761610000f178111be6b06743b8f31ed24a9d',
#       'height': 160,
#       'width': 160}],
#     'name': 'Suu',
#     'popularity': 49,
#     'type': 'artist',
#     'uri': 'spotify:artist:7He3EH9c66ZwBtIMHGdyIA'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/4SYGE81cAEHaS3sx5h8qFj'},
#     'followers': {'href': None, 'total': 44831},
#     'genres': [],
#     'href': 'https://api.spotify.com/v1/artists/4SYGE81cAEHaS3sx5h8qFj',
#     'id': '4SYGE81cAEHaS3sx5h8qFj',
#     'images': [{'url': 'https://i.scdn.co/image/ab6761610000e5eb76de06f6ac67245bf9dcf15d',
#       'height': 640,
#       'width': 640},
#      {'url': 'https://i.scdn.co/image/ab6761610000517476de06f6ac67245bf9dcf15d',
#       'height': 320,
#       'width': 320},
#      {'url': 'https://i.scdn.co/image/ab6761610000f17876de06f6ac67245bf9dcf15d',
#       'height': 160,
#       'width': 160}],
#     'name': 'KHEIS',
#     'popularity': 49,
#     'type': 'artist',
#     'uri': 'spotify:artist:4SYGE81cAEHaS3sx5h8qFj'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/1cMiNxpdh0mP5WFnPvr4xf'},
#     'followers': {'href': None, 'total': 77796},
#     'genres': ['tekno',
#      'techno',
#      'hardcore techno',
#      'hardcore',
#      'hard techno'],
#     'href': 'https://api.spotify.com/v1/artists/1cMiNxpdh0mP5WFnPvr4xf',
#     'id': '1cMiNxpdh0mP5WFnPvr4xf',
#     'images': [{'url': 'https://i.scdn.co/image/ab6761610000e5ebb7f22c7299f8d203b57579cd',
#       'height': 640,
#       'width': 640},
#      {'url': 'https://i.scdn.co/image/ab67616100005174b7f22c7299f8d203b57579cd',
#       'height': 320,
#       'width': 320},
#      {'url': 'https://i.scdn.co/image/ab6761610000f178b7f22c7299f8d203b57579cd',
#       'height': 160,
#       'width': 160}],
#     'name': 'Parkineos',
#     'popularity': 49,
#     'type': 'artist',
#     'uri': 'spotify:artist:1cMiNxpdh0mP5WFnPvr4xf'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/0aA3vWOE6EWwJH8hDImZdv'},
#     'followers': {'href': None, 'total': 66467},
#     'genres': [],
#     'href': 'https://api.spotify.com/v1/artists/0aA3vWOE6EWwJH8hDImZdv',
#     'id': '0aA3vWOE6EWwJH8hDImZdv',
#     'images': [{'url': 'https://i.scdn.co/image/ab6761610000e5eb7888f66bbd72d328e76231a0',
#       'height': 640,
#       'width': 640},
#      {'url': 'https://i.scdn.co/image/ab676161000051747888f66bbd72d328e76231a0',
#       'height': 320,
#       'width': 320},
#      {'url': 'https://i.scdn.co/image/ab6761610000f1787888f66bbd72d328e76231a0',
#       'height': 160,
#       'width': 160}],
#     'name': 'Paul Thin',
#     'popularity': 49,
#     'type': 'artist',
#     'uri': 'spotify:artist:0aA3vWOE6EWwJH8hDImZdv'}]}}

# %%
results.keys() # We can see that we only have tracks
# Out:
# dict_keys(['artists'])

# %%
results["artists"]["items"][0]
# Out:
# {'external_urls': {'spotify': 'https://open.spotify.com/artist/21ttsUKZ3y2Hm6nduyvbAw'},
#  'followers': {'href': None, 'total': 223646},
#  'genres': [],
#  'href': 'https://api.spotify.com/v1/artists/21ttsUKZ3y2Hm6nduyvbAw',
#  'id': '21ttsUKZ3y2Hm6nduyvbAw',
#  'images': [{'url': 'https://i.scdn.co/image/ab6761610000e5eb122fb2710ca2041ab1e501b5',
#    'height': 640,
#    'width': 640},
#   {'url': 'https://i.scdn.co/image/ab67616100005174122fb2710ca2041ab1e501b5',
#    'height': 320,
#    'width': 320},
#   {'url': 'https://i.scdn.co/image/ab6761610000f178122fb2710ca2041ab1e501b5',
#    'height': 160,
#    'width': 160}],
#  'name': 'Pignoise',
#  'popularity': 58,
#  'type': 'artist',
#  'uri': 'spotify:artist:21ttsUKZ3y2Hm6nduyvbAw'}

# %%
results["tracks"].keys() # Let's check the values
# Out:
# dict_keys(['href', 'limit', 'next', 'offset', 'previous', 'total', 'items'])

# %%
results["tracks"]["href"] # Query we have searched
# Out:
# 'https://api.spotify.com/v1/search?offset=0&limit=50&query=Lady%20Gaga&type=track'

# %%
results["tracks"]["items"] #items (actual tracks)
# Out:
# [{'album': {'album_type': 'single',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1HY2Jd0NmPuamShAr6KMms'},
#      'href': 'https://api.spotify.com/v1/artists/1HY2Jd0NmPuamShAr6KMms',
#      'id': '1HY2Jd0NmPuamShAr6KMms',
#      'name': 'Lady Gaga',
#      'type': 'artist',
#      'uri': 'spotify:artist:1HY2Jd0NmPuamShAr6KMms'}],
#    'available_markets': ['AR',
#     'AU',
#     'AT',
#     'BE',
#     'BO',
#     'BR',
#     'BG',
#     'CA',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DK',
#     'DO',
#     'DE',
#     'EC',
#     'EE',
#     'SV',
#     'FI',
#     'FR',
#     'GR',
#     'GT',
#     'HN',
#     'HK',
#     'HU',
#     'IS',
#     'IE',
#     'IT',
#     'LV',
#     'LT',
#     'LU',
#     'MY',
#     'MT',
#     'MX',
#     'NL',
#     'NZ',
#     'NI',
#     'NO',
#     'PA',
#     'PY',
#     'PE',
#     'PH',
#     'PL',
#     'PT',
#     'SG',
#     'SK',
#     'ES',
#     'CH',
#     'TW',
#     'TR',
#     'UY',
#     'US',
#     'GB',
#     'AD',
#     'LI',
#     'MC',
#     'ID',
#     'JP',
#     'TH',
#     'VN',
#     'RO',
#     'IL',
#     'ZA',
#     'SA',
#     'AE',
#     'BH',
#     'QA',
#     'OM',
#     'KW',
#     'EG',
#     'MA',
#     'DZ',
#     'TN',
#     'LB',
#     'JO',
#     'PS',
#     'IN',
#     'KZ',
#     'MD',
#     'UA',
#     'AL',
#     'BA',
#     'HR',
#     'ME',
#     'MK',
#     'RS',
#     'SI',
#     'KR',
#     'BD',
#     'PK',
#     'LK',
#     'GH',
#     'KE',
#     'NG',
#     'TZ',
#     'UG',
#     'AG',
#     'AM',
#     'BS',
#     'BB',
#     'BZ',
#     'BT',
#     'BW',
#     'BF',
#     'CV',
#     'CW',
#     'DM',
#     'FJ',
#     'GM',
#     'GE',
#     'GD',
#     'GW',
#     'GY',
#     'HT',
#     'JM',
#     'KI',
#     'LS',
#     'LR',
#     'MW',
#     'MV',
#     'ML',
#     'MH',
#     'FM',
#     'NA',
#     'NR',
#     'NE',
#     'PW',
#     'PG',
#     'WS',
#     'SM',
#     'ST',
#     'SN',
#     'SC',
#     'SL',
#     'SB',
#     'KN',
#     'LC',
#     'VC',
#     'SR',
#     'TL',
#     'TO',
#     'TT',
#     'TV',
#     'VU',
#     'AZ',
#     'BN',
#     'BI',
#     'KH',
#     'CM',
#     'TD',
#     'KM',
#     'GQ',
#     'SZ',
#     'GA',
#     'GN',
#     'KG',
#     'LA',
#     'MO',
#     'MR',
#     'MN',
#     'NP',
#     'RW',
#     'TG',
#     'UZ',
#     'ZW',
#     'BJ',
#     'MG',
#     'MU',
#     'MZ',
#     'AO',
#     'CI',
#     'DJ',
#     'ZM',
#     'CD',
#     'CG',
#     'IQ',
#     'LY',
#     'TJ',
#     'VE',
#     'ET',
#     'XK'],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/2I6LyArz82waG94e9V5B9d'},
#    'href': 'https://api.spotify.com/v1/albums/2I6LyArz82waG94e9V5B9d',
#    'id': '2I6LyArz82waG94e9V5B9d',
#    'images': [{'height': 640,
#      'width': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b27325304f6dc9dea023ce4b985c'},
#     {'height': 300,
#      'width': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e0225304f6dc9dea023ce4b985c'},
#     {'height': 64,
#      'width': 64,
#      'url': 'https://i.scdn.co/image/ab67616d0000485125304f6dc9dea023ce4b985c'}],
#    'is_playable': True,
#    'name': 'Abracadabra',
#    'release_date': '2025-02-03',
#    'release_date_precision': 'day',
#    'total_tracks': 1,
#    'type': 'album',
#    'uri': 'spotify:album:2I6LyArz82waG94e9V5B9d'},
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1HY2Jd0NmPuamShAr6KMms'},
#     'href': 'https://api.spotify.com/v1/artists/1HY2Jd0NmPuamShAr6KMms',
#     'id': '1HY2Jd0NmPuamShAr6KMms',
#     'name': 'Lady Gaga',
#     'type': 'artist',
#     'uri': 'spotify:artist:1HY2Jd0NmPuamShAr6KMms'}],
#   'available_markets': ['AR',
#    'AU',
#    'AT',
#    'BE',
#    'BO',
#    'BR',
#    'BG',
#    'CA',
#    'CL',
#    'CO',
#    'CR',
#    'CY',
#    'CZ',
#    'DK',
#    'DO',
#    'DE',
#    'EC',
#    'EE',
#    'SV',
#    'FI',
#    'FR',
#    'GR',
#    'GT',
#    'HN',
#    'HK',
#    'HU',
#    'IS',
#    'IE',
#    'IT',
#    'LV',
#    'LT',
#    'LU',
#    'MY',
#    'MT',
#    'MX',
#    'NL',
#    'NZ',
#    'NI',
#    'NO',
#    'PA',
#    'PY',
#    'PE',
#    'PH',
#    'PL',
#    'PT',
#    'SG',
#    'SK',
#    'ES',
#    'CH',
#    'TW',
#    'TR',
#    'UY',
#    'US',
#    'GB',
#    'AD',
#    'LI',
#    'MC',
#    'ID',
#    'JP',
#    'TH',
#    'VN',
#    'RO',
#    'IL',
#    'ZA',
#    'SA',
#    'AE',
#    'BH',
#    'QA',
#    'OM',
#    'KW',
#    'EG',
#    'MA',
#    'DZ',
#    'TN',
#    'LB',
#    'JO',
#    'PS',
#    'IN',
#    'KZ',
#    'MD',
#    'UA',
#    'AL',
#    'BA',
#    'HR',
#    'ME',
#    'MK',
#    'RS',
#    'SI',
#    'KR',
#    'BD',
#    'PK',
#    'LK',
#    'GH',
#    'KE',
#    'NG',
#    'TZ',
#    'UG',
#    'AG',
#    'AM',
#    'BS',
#    'BB',
#    'BZ',
#    'BT',
#    'BW',
#    'BF',
#    'CV',
#    'CW',
#    'DM',
#    'FJ',
#    'GM',
#    'GE',
#    'GD',
#    'GW',
#    'GY',
#    'HT',
#    'JM',
#    'KI',
#    'LS',
#    'LR',
#    'MW',
#    'MV',
#    'ML',
#    'MH',
#    'FM',
#    'NA',
#    'NR',
#    'NE',
#    'PW',
#    'PG',
#    'WS',
#    'SM',
#    'ST',
#    'SN',
#    'SC',
#    'SL',
#    'SB',
#    'KN',
#    'LC',
#    'VC',
#    'SR',
#    'TL',
#    'TO',
#    'TT',
#    'TV',
#    'VU',
#    'AZ',
#    'BN',
#    'BI',
#    'KH',
#    'CM',
#    'TD',
#    'KM',
#    'GQ',
#    'SZ',
#    'GA',
#    'GN',
#    'KG',
#    'LA',
#    'MO',
#    'MR',
#    'MN',
#    'NP',
#    'RW',
#    'TG',
#    'UZ',
#    'ZW',
#    'BJ',
#    'MG',
#    'MU',
#    'MZ',
#    'AO',
#    'CI',
#    'DJ',
#    'ZM',
#    'CD',
#    'CG',
#    'IQ',
#    'LY',
#    'TJ',
#    'VE',
#    'ET',
#    'XK'],
#   'disc_number': 1,
#   'duration_ms': 223398,
#   'explicit': False,
#   'external_ids': {'isrc': 'USUM72412581'},
#   'external_urls': {'spotify': 'https://open.spotify.com/track/5ZLUm9eab8y3tqQ1OhQSHI'},
#   'href': 'https://api.spotify.com/v1/tracks/5ZLUm9eab8y3tqQ1OhQSHI',
#   'id': '5ZLUm9eab8y3tqQ1OhQSHI',
#   'is_local': False,
#   'is_playable': True,
#   'name': 'Abracadabra',
#   'popularity': 92,
#   'preview_url': None,
#   'track_number': 1,
#   'type': 'track',
#   'uri': 'spotify:track:5ZLUm9eab8y3tqQ1OhQSHI'},
#  {'album': {'album_type': 'single',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1HY2Jd0NmPuamShAr6KMms'},
#      'href': 'https://api.spotify.com/v1/artists/1HY2Jd0NmPuamShAr6KMms',
#      'id': '1HY2Jd0NmPuamShAr6KMms',
#      'name': 'Lady Gaga',
#      'type': 'artist',
#      'uri': 'spotify:artist:1HY2Jd0NmPuamShAr6KMms'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/0du5cEVh5yTK9QJze8zA0C'},
#      'href': 'https://api.spotify.com/v1/artists/0du5cEVh5yTK9QJze8zA0C',
#      'id': '0du5cEVh5yTK9QJze8zA0C',
#      'name': 'Bruno Mars',
#      'type': 'artist',
#      'uri': 'spotify:artist:0du5cEVh5yTK9QJze8zA0C'}],
#    'available_markets': ['AR',
#     'AU',
#     'AT',
#     'BE',
#     'BO',
#     'BR',
#     'BG',
#     'CA',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DK',
#     'DO',
#     'DE',
#     'EC',
#     'EE',
#     'SV',
#     'FI',
#     'FR',
#     'GR',
#     'GT',
#     'HN',
#     'HK',
#     'HU',
#     'IS',
#     'IE',
#     'IT',
#     'LV',
#     'LT',
#     'LU',
#     'MY',
#     'MT',
#     'MX',
#     'NL',
#     'NZ',
#     'NI',
#     'NO',
#     'PA',
#     'PY',
#     'PE',
#     'PH',
#     'PL',
#     'PT',
#     'SG',
#     'SK',
#     'ES',
#     'SE',
#     'CH',
#     'TW',
#     'TR',
#     'UY',
#     'US',
#     'GB',
#     'AD',
#     'LI',
#     'MC',
#     'ID',
#     'JP',
#     'TH',
#     'VN',
#     'RO',
#     'IL',
#     'ZA',
#     'SA',
#     'AE',
#     'BH',
#     'QA',
#     'OM',
#     'KW',
#     'EG',
#     'MA',
#     'DZ',
#     'TN',
#     'LB',
#     'JO',
#     'PS',
#     'IN',
#     'KZ',
#     'MD',
#     'UA',
#     'AL',
#     'BA',
#     'HR',
#     'ME',
#     'MK',
#     'RS',
#     'SI',
#     'KR',
#     'BD',
#     'PK',
#     'LK',
#     'GH',
#     'KE',
#     'NG',
#     'TZ',
#     'UG',
#     'AG',
#     'AM',
#     'BS',
#     'BB',
#     'BZ',
#     'BT',
#     'BW',
#     'BF',
#     'CV',
#     'CW',
#     'DM',
#     'FJ',
#     'GM',
#     'GE',
#     'GD',
#     'GW',
#     'GY',
#     'HT',
#     'JM',
#     'KI',
#     'LS',
#     'LR',
#     'MW',
#     'MV',
#     'ML',
#     'MH',
#     'FM',
#     'NA',
#     'NR',
#     'NE',
#     'PW',
#     'PG',
#     'WS',
#     'SM',
#     'ST',
#     'SN',
#     'SC',
#     'SL',
#     'SB',
#     'KN',
#     'LC',
#     'VC',
#     'SR',
#     'TL',
#     'TO',
#     'TT',
#     'TV',
#     'VU',
#     'AZ',
#     'BN',
#     'BI',
#     'KH',
#     'CM',
#     'TD',
#     'KM',
#     'GQ',
#     'SZ',
#     'GA',
#     'GN',
#     'KG',
#     'LA',
#     'MO',
#     'MR',
#     'MN',
#     'NP',
#     'RW',
#     'TG',
#     'UZ',
#     'ZW',
#     'BJ',
#     'MG',
#     'MU',
#     'MZ',
#     'AO',
#     'CI',
#     'DJ',
#     'ZM',
#     'CD',
#     'CG',
#     'IQ',
#     'LY',
#     'TJ',
#     'VE',
#     'ET',
#     'XK'],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/10FLjwfpbxLmW8c25Xyc2N'},
#    'href': 'https://api.spotify.com/v1/albums/10FLjwfpbxLmW8c25Xyc2N',
#    'id': '10FLjwfpbxLmW8c25Xyc2N',
#    'images': [{'height': 640,
#      'width': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b27382ea2e9e1858aa012c57cd45'},
#     {'height': 300,
#      'width': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e0282ea2e9e1858aa012c57cd45'},
#     {'height': 64,
#      'width': 64,
#      'url': 'https://i.scdn.co/image/ab67616d0000485182ea2e9e1858aa012c57cd45'}],
#    'is_playable': True,
#    'name': 'Die With A Smile',
#    'release_date': '2024-08-16',
#    'release_date_precision': 'day',
#    'total_tracks': 1,
#    'type': 'album',
#    'uri': 'spotify:album:10FLjwfpbxLmW8c25Xyc2N'},
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1HY2Jd0NmPuamShAr6KMms'},
#     'href': 'https://api.spotify.com/v1/artists/1HY2Jd0NmPuamShAr6KMms',
#     'id': '1HY2Jd0NmPuamShAr6KMms',
#     'name': 'Lady Gaga',
#     'type': 'artist',
#     'uri': 'spotify:artist:1HY2Jd0NmPuamShAr6KMms'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/0du5cEVh5yTK9QJze8zA0C'},
#     'href': 'https://api.spotify.com/v1/artists/0du5cEVh5yTK9QJze8zA0C',
#     'id': '0du5cEVh5yTK9QJze8zA0C',
#     'name': 'Bruno Mars',
#     'type': 'artist',
#     'uri': 'spotify:artist:0du5cEVh5yTK9QJze8zA0C'}],
#   'available_markets': ['AR',
#    'AU',
#    'AT',
#    'BE',
#    'BO',
#    'BR',
#    'BG',
#    'CA',
#    'CL',
#    'CO',
#    'CR',
#    'CY',
#    'CZ',
#    'DK',
#    'DO',
#    'DE',
#    'EC',
#    'EE',
#    'SV',
#    'FI',
#    'FR',
#    'GR',
#    'GT',
#    'HN',
#    'HK',
#    'HU',
#    'IS',
#    'IE',
#    'IT',
#    'LV',
#    'LT',
#    'LU',
#    'MY',
#    'MT',
#    'MX',
#    'NL',
#    'NZ',
#    'NI',
#    'NO',
#    'PA',
#    'PY',
#    'PE',
#    'PH',
#    'PL',
#    'PT',
#    'SG',
#    'SK',
#    'ES',
#    'SE',
#    'CH',
#    'TW',
#    'TR',
#    'UY',
#    'US',
#    'GB',
#    'AD',
#    'LI',
#    'MC',
#    'ID',
#    'JP',
#    'TH',
#    'VN',
#    'RO',
#    'IL',
#    'ZA',
#    'SA',
#    'AE',
#    'BH',
#    'QA',
#    'OM',
#    'KW',
#    'EG',
#    'MA',
#    'DZ',
#    'TN',
#    'LB',
#    'JO',
#    'PS',
#    'IN',
#    'KZ',
#    'MD',
#    'UA',
#    'AL',
#    'BA',
#    'HR',
#    'ME',
#    'MK',
#    'RS',
#    'SI',
#    'KR',
#    'BD',
#    'PK',
#    'LK',
#    'GH',
#    'KE',
#    'NG',
#    'TZ',
#    'UG',
#    'AG',
#    'AM',
#    'BS',
#    'BB',
#    'BZ',
#    'BT',
#    'BW',
#    'BF',
#    'CV',
#    'CW',
#    'DM',
#    'FJ',
#    'GM',
#    'GE',
#    'GD',
#    'GW',
#    'GY',
#    'HT',
#    'JM',
#    'KI',
#    'LS',
#    'LR',
#    'MW',
#    'MV',
#    'ML',
#    'MH',
#    'FM',
#    'NA',
#    'NR',
#    'NE',
#    'PW',
#    'PG',
#    'WS',
#    'SM',
#    'ST',
#    'SN',
#    'SC',
#    'SL',
#    'SB',
#    'KN',
#    'LC',
#    'VC',
#    'SR',
#    'TL',
#    'TO',
#    'TT',
#    'TV',
#    'VU',
#    'AZ',
#    'BN',
#    'BI',
#    'KH',
#    'CM',
#    'TD',
#    'KM',
#    'GQ',
#    'SZ',
#    'GA',
#    'GN',
#    'KG',
#    'LA',
#    'MO',
#    'MR',
#    'MN',
#    'NP',
#    'RW',
#    'TG',
#    'UZ',
#    'ZW',
#    'BJ',
#    'MG',
#    'MU',
#    'MZ',
#    'AO',
#    'CI',
#    'DJ',
#    'ZM',
#    'CD',
#    'CG',
#    'IQ',
#    'LY',
#    'TJ',
#    'VE',
#    'ET',
#    'XK'],
#   'disc_number': 1,
#   'duration_ms': 251667,
#   'explicit': False,
#   'external_ids': {'isrc': 'USUM72409273'},
#   'external_urls': {'spotify': 'https://open.spotify.com/track/2plbrEY59IikOBgBGLjaoe'},
#   'href': 'https://api.spotify.com/v1/tracks/2plbrEY59IikOBgBGLjaoe',
#   'id': '2plbrEY59IikOBgBGLjaoe',
#   'is_local': False,
#   'is_playable': True,
#   'name': 'Die With A Smile',
#   'popularity': 99,
#   'preview_url': None,
#   'track_number': 1,
#   'type': 'track',
#   'uri': 'spotify:track:2plbrEY59IikOBgBGLjaoe'},
#  {'album': {'album_type': 'album',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1HY2Jd0NmPuamShAr6KMms'},
#      'href': 'https://api.spotify.com/v1/artists/1HY2Jd0NmPuamShAr6KMms',
#      'id': '1HY2Jd0NmPuamShAr6KMms',
#      'name': 'Lady Gaga',
#      'type': 'artist',
#      'uri': 'spotify:artist:1HY2Jd0NmPuamShAr6KMms'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/4VIvfOurcf0vuLRxLkGnIG'},
#      'href': 'https://api.spotify.com/v1/artists/4VIvfOurcf0vuLRxLkGnIG',
#      'id': '4VIvfOurcf0vuLRxLkGnIG',
#      'name': 'Bradley Cooper',
#      'type': 'artist',
#      'uri': 'spotify:artist:4VIvfOurcf0vuLRxLkGnIG'}],
#    'available_markets': ['AR',
#     'AU',
#     'AT',
#     'BE',
#     'BO',
#     'BR',
#     'BG',
#     'CA',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DK',
#     'DO',
#     'DE',
#     'EC',
#     'EE',
#     'SV',
#     'FI',
#     'FR',
#     'GR',
#     'GT',
#     'HN',
#     'HK',
#     'HU',
#     'IS',
#     'IE',
#     'IT',
#     'LV',
#     'LT',
#     'LU',
#     'MY',
#     'MT',
#     'MX',
#     'NL',
#     'NZ',
#     'NI',
#     'NO',
#     'PA',
#     'PY',
#     'PE',
#     'PH',
#     'PL',
#     'PT',
#     'SG',
#     'SK',
#     'ES',
#     'SE',
#     'CH',
#     'TW',
#     'TR',
#     'UY',
#     'US',
#     'GB',
#     'AD',
#     'LI',
#     'MC',
#     'ID',
#     'JP',
#     'TH',
#     'VN',
#     'RO',
#     'IL',
#     'ZA',
#     'SA',
#     'AE',
#     'BH',
#     'QA',
#     'OM',
#     'KW',
#     'EG',
#     'MA',
#     'DZ',
#     'TN',
#     'LB',
#     'JO',
#     'PS',
#     'IN',
#     'BY',
#     'KZ',
#     'MD',
#     'UA',
#     'AL',
#     'BA',
#     'HR',
#     'ME',
#     'MK',
#     'RS',
#     'SI',
#     'KR',
#     'BD',
#     'PK',
#     'LK',
#     'GH',
#     'KE',
#     'NG',
#     'TZ',
#     'UG',
#     'AG',
#     'AM',
#     'BS',
#     'BB',
#     'BZ',
#     'BT',
#     'BW',
#     'BF',
#     'CV',
#     'CW',
#     'DM',
#     'FJ',
#     'GM',
#     'GE',
#     'GD',
#     'GW',
#     'GY',
#     'HT',
#     'JM',
#     'KI',
#     'LS',
#     'LR',
#     'MW',
#     'MV',
#     'ML',
#     'MH',
#     'FM',
#     'NA',
#     'NR',
#     'NE',
#     'PW',
#     'PG',
#     'WS',
#     'SM',
#     'ST',
#     'SN',
#     'SC',
#     'SL',
#     'SB',
#     'KN',
#     'LC',
#     'VC',
#     'SR',
#     'TL',
#     'TO',
#     'TT',
#     'TV',
#     'VU',
#     'AZ',
#     'BN',
#     'BI',
#     'KH',
#     'CM',
#     'TD',
#     'KM',
#     'GQ',
#     'SZ',
#     'GA',
#     'GN',
#     'KG',
#     'LA',
#     'MO',
#     'MR',
#     'MN',
#     'NP',
#     'RW',
#     'TG',
#     'UZ',
#     'ZW',
#     'BJ',
#     'MG',
#     'MU',
#     'MZ',
#     'AO',
#     'CI',
#     'DJ',
#     'ZM',
#     'CD',
#     'CG',
#     'IQ',
#     'LY',
#     'TJ',
#     'VE',
#     'ET',
#     'XK'],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/3edjzMAVB9RYRd4UcZBchx'},
#    'href': 'https://api.spotify.com/v1/albums/3edjzMAVB9RYRd4UcZBchx',
#    'id': '3edjzMAVB9RYRd4UcZBchx',
#    'images': [{'height': 640,
#      'width': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b273b5d4b4ed17ec86c4b3944af2'},
#     {'height': 300,
#      'width': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e02b5d4b4ed17ec86c4b3944af2'},
#     {'height': 64,
#      'width': 64,
#      'url': 'https://i.scdn.co/image/ab67616d00004851b5d4b4ed17ec86c4b3944af2'}],
#    'is_playable': True,
#    'name': 'A Star Is Born Soundtrack (Without Dialogue)',
#    'release_date': '2018-10-05',
#    'release_date_precision': 'day',
#    'total_tracks': 19,
#    'type': 'album',
#    'uri': 'spotify:album:3edjzMAVB9RYRd4UcZBchx'},
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1HY2Jd0NmPuamShAr6KMms'},
#     'href': 'https://api.spotify.com/v1/artists/1HY2Jd0NmPuamShAr6KMms',
#     'id': '1HY2Jd0NmPuamShAr6KMms',
#     'name': 'Lady Gaga',
#     'type': 'artist',
#     'uri': 'spotify:artist:1HY2Jd0NmPuamShAr6KMms'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/4VIvfOurcf0vuLRxLkGnIG'},
#     'href': 'https://api.spotify.com/v1/artists/4VIvfOurcf0vuLRxLkGnIG',
#     'id': '4VIvfOurcf0vuLRxLkGnIG',
#     'name': 'Bradley Cooper',
#     'type': 'artist',
#     'uri': 'spotify:artist:4VIvfOurcf0vuLRxLkGnIG'}],
#   'available_markets': ['AR',
#    'AU',
#    'AT',
#    'BE',
#    'BO',
#    'BR',
#    'BG',
#    'CA',
#    'CL',
#    'CO',
#    'CR',
#    'CY',
#    'CZ',
#    'DK',
#    'DO',
#    'DE',
#    'EC',
#    'EE',
#    'SV',
#    'FI',
#    'FR',
#    'GR',
#    'GT',
#    'HN',
#    'HK',
#    'HU',
#    'IS',
#    'IE',
#    'IT',
#    'LV',
#    'LT',
#    'LU',
#    'MY',
#    'MT',
#    'MX',
#    'NL',
#    'NZ',
#    'NI',
#    'NO',
#    'PA',
#    'PY',
#    'PE',
#    'PH',
#    'PL',
#    'PT',
#    'SG',
#    'SK',
#    'ES',
#    'SE',
#    'CH',
#    'TW',
#    'TR',
#    'UY',
#    'US',
#    'GB',
#    'AD',
#    'LI',
#    'MC',
#    'ID',
#    'JP',
#    'TH',
#    'VN',
#    'RO',
#    'IL',
#    'ZA',
#    'SA',
#    'AE',
#    'BH',
#    'QA',
#    'OM',
#    'KW',
#    'EG',
#    'MA',
#    'DZ',
#    'TN',
#    'LB',
#    'JO',
#    'PS',
#    'IN',
#    'BY',
#    'KZ',
#    'MD',
#    'UA',
#    'AL',
#    'BA',
#    'HR',
#    'ME',
#    'MK',
#    'RS',
#    'SI',
#    'KR',
#    'BD',
#    'PK',
#    'LK',
#    'GH',
#    'KE',
#    'NG',
#    'TZ',
#    'UG',
#    'AG',
#    'AM',
#    'BS',
#    'BB',
#    'BZ',
#    'BT',
#    'BW',
#    'BF',
#    'CV',
#    'CW',
#    'DM',
#    'FJ',
#    'GM',
#    'GE',
#    'GD',
#    'GW',
#    'GY',
#    'HT',
#    'JM',
#    'KI',
#    'LS',
#    'LR',
#    'MW',
#    'MV',
#    'ML',
#    'MH',
#    'FM',
#    'NA',
#    'NR',
#    'NE',
#    'PW',
#    'PG',
#    'WS',
#    'SM',
#    'ST',
#    'SN',
#    'SC',
#    'SL',
#    'SB',
#    'KN',
#    'LC',
#    'VC',
#    'SR',
#    'TL',
#    'TO',
#    'TT',
#    'TV',
#    'VU',
#    'AZ',
#    'BN',
#    'BI',
#    'KH',
#    'CM',
#    'TD',
#    'KM',
#    'GQ',
#    'SZ',
#    'GA',
#    'GN',
#    'KG',
#    'LA',
#    'MO',
#    'MR',
#    'MN',
#    'NP',
#    'RW',
#    'TG',
#    'UZ',
#    'ZW',
#    'BJ',
#    'MG',
#    'MU',
#    'MZ',
#    'AO',
#    'CI',
#    'DJ',
#    'ZM',
#    'CD',
#    'CG',
#    'IQ',
#    'LY',
#    'TJ',
#    'VE',
#    'ET',
#    'XK'],
#   'disc_number': 1,
#   'duration_ms': 217212,
#   'explicit': False,
#   'external_ids': {'isrc': 'USUM71815945'},
#   'external_urls': {'spotify': 'https://open.spotify.com/track/6QfS2wq5sSC1xAJCQsTSlj'},
#   'href': 'https://api.spotify.com/v1/tracks/6QfS2wq5sSC1xAJCQsTSlj',
#   'id': '6QfS2wq5sSC1xAJCQsTSlj',
#   'is_local': False,
#   'is_playable': True,
#   'name': 'Shallow - Radio Edit',
#   'popularity': 73,
#   'preview_url': None,
#   'track_number': 6,
#   'type': 'track',
#   'uri': 'spotify:track:6QfS2wq5sSC1xAJCQsTSlj'},
#  {'album': {'album_type': 'album',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1HY2Jd0NmPuamShAr6KMms'},
#      'href': 'https://api.spotify.com/v1/artists/1HY2Jd0NmPuamShAr6KMms',
#      'id': '1HY2Jd0NmPuamShAr6KMms',
#      'name': 'Lady Gaga',
#      'type': 'artist',
#      'uri': 'spotify:artist:1HY2Jd0NmPuamShAr6KMms'}],
#    'available_markets': ['AR',
#     'AU',
#     'AT',
#     'BE',
#     'BO',
#     'BR',
#     'BG',
#     'CA',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DK',
#     'DO',
#     'DE',
#     'EC',
#     'EE',
#     'SV',
#     'FI',
#     'FR',
#     'GR',
#     'GT',
#     'HN',
#     'HK',
#     'HU',
#     'IS',
#     'IE',
#     'IT',
#     'LV',
#     'LT',
#     'LU',
#     'MY',
#     'MT',
#     'MX',
#     'NL',
#     'NZ',
#     'NI',
#     'NO',
#     'PA',
#     'PY',
#     'PE',
#     'PH',
#     'PL',
#     'PT',
#     'SG',
#     'SK',
#     'ES',
#     'SE',
#     'CH',
#     'TW',
#     'TR',
#     'UY',
#     'US',
#     'GB',
#     'AD',
#     'LI',
#     'MC',
#     'ID',
#     'JP',
#     'TH',
#     'VN',
#     'RO',
#     'IL',
#     'ZA',
#     'SA',
#     'AE',
#     'BH',
#     'QA',
#     'OM',
#     'KW',
#     'EG',
#     'MA',
#     'DZ',
#     'TN',
#     'LB',
#     'JO',
#     'PS',
#     'IN',
#     'KZ',
#     'MD',
#     'UA',
#     'AL',
#     'BA',
#     'HR',
#     'ME',
#     'MK',
#     'RS',
#     'SI',
#     'KR',
#     'BD',
#     'PK',
#     'LK',
#     'GH',
#     'KE',
#     'NG',
#     'TZ',
#     'UG',
#     'AG',
#     'AM',
#     'BS',
#     'BB',
#     'BZ',
#     'BT',
#     'BW',
#     'BF',
#     'CV',
#     'CW',
#     'DM',
#     'FJ',
#     'GM',
#     'GE',
#     'GD',
#     'GW',
#     'GY',
#     'HT',
#     'JM',
#     'KI',
#     'LS',
#     'LR',
#     'MW',
#     'MV',
#     'ML',
#     'MH',
#     'FM',
#     'NA',
#     'NR',
#     'NE',
#     'PW',
#     'PG',
#     'WS',
#     'SM',
#     'ST',
#     'SN',
#     'SC',
#     'SL',
#     'SB',
#     'KN',
#     'LC',
#     'VC',
#     'SR',
#     'TL',
#     'TO',
#     'TT',
#     'TV',
#     'VU',
#     'AZ',
#     'BN',
#     'BI',
#     'KH',
#     'CM',
#     'TD',
#     'KM',
#     'GQ',
#     'SZ',
#     'GA',
#     'GN',
#     'KG',
#     'LA',
#     'MO',
#     'MR',
#     'MN',
#     'NP',
#     'RW',
#     'TG',
#     'UZ',
#     'ZW',
#     'BJ',
#     'MG',
#     'MU',
#     'MZ',
#     'AO',
#     'CI',
#     'DJ',
#     'ZM',
#     'CD',
#     'CG',
#     'IQ',
#     'LY',
#     'TJ',
#     'VE',
#     'ET',
#     'XK'],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/6rePArBMb5nLWEaY9aQqL4'},
#    'href': 'https://api.spotify.com/v1/albums/6rePArBMb5nLWEaY9aQqL4',
#    'id': '6rePArBMb5nLWEaY9aQqL4',
#    'images': [{'height': 640,
#      'width': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b2735c9890c0456a3719eeecd8aa'},
#     {'height': 300,
#      'width': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e025c9890c0456a3719eeecd8aa'},
#     {'height': 64,
#      'width': 64,
#      'url': 'https://i.scdn.co/image/ab67616d000048515c9890c0456a3719eeecd8aa'}],
#    'is_playable': True,
#    'name': 'The Fame Monster (Deluxe Edition)',
#    'release_date': '2009-11-05',
#    'release_date_precision': 'day',
#    'total_tracks': 23,
#    'type': 'album',
#    'uri': 'spotify:album:6rePArBMb5nLWEaY9aQqL4'},
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1HY2Jd0NmPuamShAr6KMms'},
#     'href': 'https://api.spotify.com/v1/artists/1HY2Jd0NmPuamShAr6KMms',
#     'id': '1HY2Jd0NmPuamShAr6KMms',
#     'name': 'Lady Gaga',
#     'type': 'artist',
#     'uri': 'spotify:artist:1HY2Jd0NmPuamShAr6KMms'}],
#   'available_markets': ['AR',
#    'AU',
#    'AT',
#    'BE',
#    'BO',
#    'BR',
#    'BG',
#    'CA',
#    'CL',
#    'CO',
#    'CR',
#    'CY',
#    'CZ',
#    'DK',
#    'DO',
#    'DE',
#    'EC',
#    'EE',
#    'SV',
#    'FI',
#    'FR',
#    'GR',
#    'GT',
#    'HN',
#    'HK',
#    'HU',
#    'IS',
#    'IE',
#    'IT',
#    'LV',
#    'LT',
#    'LU',
#    'MY',
#    'MT',
#    'MX',
#    'NL',
#    'NZ',
#    'NI',
#    'NO',
#    'PA',
#    'PY',
#    'PE',
#    'PH',
#    'PL',
#    'PT',
#    'SG',
#    'SK',
#    'ES',
#    'SE',
#    'CH',
#    'TW',
#    'TR',
#    'UY',
#    'US',
#    'GB',
#    'AD',
#    'LI',
#    'MC',
#    'ID',
#    'JP',
#    'TH',
#    'VN',
#    'RO',
#    'IL',
#    'ZA',
#    'SA',
#    'AE',
#    'BH',
#    'QA',
#    'OM',
#    'KW',
#    'EG',
#    'MA',
#    'DZ',
#    'TN',
#    'LB',
#    'JO',
#    'PS',
#    'IN',
#    'KZ',
#    'MD',
#    'UA',
#    'AL',
#    'BA',
#    'HR',
#    'ME',
#    'MK',
#    'RS',
#    'SI',
#    'KR',
#    'BD',
#    'PK',
#    'LK',
#    'GH',
#    'KE',
#    'NG',
#    'TZ',
#    'UG',
#    'AG',
#    'AM',
#    'BS',
#    'BB',
#    'BZ',
#    'BT',
#    'BW',
#    'BF',
#    'CV',
#    'CW',
#    'DM',
#    'FJ',
#    'GM',
#    'GE',
#    'GD',
#    'GW',
#    'GY',
#    'HT',
#    'JM',
#    'KI',
#    'LS',
#    'LR',
#    'MW',
#    'MV',
#    'ML',
#    'MH',
#    'FM',
#    'NA',
#    'NR',
#    'NE',
#    'PW',
#    'PG',
#    'WS',
#    'SM',
#    'ST',
#    'SN',
#    'SC',
#    'SL',
#    'SB',
#    'KN',
#    'LC',
#    'VC',
#    'SR',
#    'TL',
#    'TO',
#    'TT',
#    'TV',
#    'VU',
#    'AZ',
#    'BN',
#    'BI',
#    'KH',
#    'CM',
#    'TD',
#    'KM',
#    'GQ',
#    'SZ',
#    'GA',
#    'GN',
#    'KG',
#    'LA',
#    'MO',
#    'MR',
#    'MN',
#    'NP',
#    'RW',
#    'TG',
#    'UZ',
#    'ZW',
#    'BJ',
#    'MG',
#    'MU',
#    'MZ',
#    'AO',
#    'CI',
#    'DJ',
#    'ZM',
#    'CD',
#    'CG',
#    'IQ',
#    'LY',
#    'TJ',
#    'VE',
#    'ET',
#    'XK'],
#   'disc_number': 1,
#   'duration_ms': 294573,
#   'explicit': True,
#   'external_ids': {'isrc': 'USUM70918596'},
#   'external_urls': {'spotify': 'https://open.spotify.com/track/0SiywuOBRcynK0uKGWdCnn'},
#   'href': 'https://api.spotify.com/v1/tracks/0SiywuOBRcynK0uKGWdCnn',
#   'id': '0SiywuOBRcynK0uKGWdCnn',
#   'is_local': False,
#   'is_playable': True,
#   'name': 'Bad Romance',
#   'popularity': 88,
#   'preview_url': None,
#   'track_number': 1,
#   'type': 'track',
#   'uri': 'spotify:track:0SiywuOBRcynK0uKGWdCnn'},
#  {'album': {'album_type': 'album',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/12GqGscKJx3aE4t07u7eVZ'},
#      'href': 'https://api.spotify.com/v1/artists/12GqGscKJx3aE4t07u7eVZ',
#      'id': '12GqGscKJx3aE4t07u7eVZ',
#      'name': 'Peso Pluma',
#      'type': 'artist',
#      'uri': 'spotify:artist:12GqGscKJx3aE4t07u7eVZ'}],
#    'available_markets': ['AR',
#     'AU',
#     'AT',
#     'BE',
#     'BO',
#     'BR',
#     'BG',
#     'CA',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DK',
#     'DO',
#     'DE',
#     'EC',
#     'EE',
#     'SV',
#     'FI',
#     'FR',
#     'GR',
#     'GT',
#     'HN',
#     'HK',
#     'HU',
#     'IS',
#     'IE',
#     'IT',
#     'LV',
#     'LT',
#     'LU',
#     'MY',
#     'MT',
#     'MX',
#     'NL',
#     'NZ',
#     'NI',
#     'NO',
#     'PA',
#     'PY',
#     'PE',
#     'PH',
#     'PL',
#     'PT',
#     'SG',
#     'SK',
#     'ES',
#     'SE',
#     'CH',
#     'TW',
#     'TR',
#     'UY',
#     'US',
#     'GB',
#     'AD',
#     'LI',
#     'MC',
#     'ID',
#     'JP',
#     'TH',
#     'VN',
#     'RO',
#     'IL',
#     'ZA',
#     'SA',
#     'AE',
#     'BH',
#     'QA',
#     'OM',
#     'KW',
#     'EG',
#     'MA',
#     'DZ',
#     'TN',
#     'LB',
#     'JO',
#     'PS',
#     'IN',
#     'BY',
#     'KZ',
#     'MD',
#     'UA',
#     'AL',
#     'BA',
#     'HR',
#     'ME',
#     'MK',
#     'RS',
#     'SI',
#     'KR',
#     'BD',
#     'PK',
#     'LK',
#     'GH',
#     'KE',
#     'NG',
#     'TZ',
#     'UG',
#     'AG',
#     'AM',
#     'BS',
#     'BB',
#     'BZ',
#     'BT',
#     'BW',
#     'BF',
#     'CV',
#     'CW',
#     'DM',
#     'FJ',
#     'GM',
#     'GE',
#     'GD',
#     'GW',
#     'GY',
#     'HT',
#     'JM',
#     'KI',
#     'LS',
#     'LR',
#     'MW',
#     'MV',
#     'ML',
#     'MH',
#     'FM',
#     'NA',
#     'NR',
#     'NE',
#     'PW',
#     'PG',
#     'PR',
#     'WS',
#     'SM',
#     'ST',
#     'SN',
#     'SC',
#     'SL',
#     'SB',
#     'KN',
#     'LC',
#     'VC',
#     'SR',
#     'TL',
#     'TO',
#     'TT',
#     'TV',
#     'VU',
#     'AZ',
#     'BN',
#     'BI',
#     'KH',
#     'CM',
#     'TD',
#     'KM',
#     'GQ',
#     'SZ',
#     'GA',
#     'GN',
#     'KG',
#     'LA',
#     'MO',
#     'MR',
#     'MN',
#     'NP',
#     'RW',
#     'TG',
#     'UZ',
#     'ZW',
#     'BJ',
#     'MG',
#     'MU',
#     'MZ',
#     'AO',
#     'CI',
#     'DJ',
#     'ZM',
#     'CD',
#     'CG',
#     'IQ',
#     'LY',
#     'TJ',
#     'VE',
#     'ET',
#     'XK'],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/4jox3ip1I39DFC2B7R5qLH'},
#    'href': 'https://api.spotify.com/v1/albums/4jox3ip1I39DFC2B7R5qLH',
#    'id': '4jox3ip1I39DFC2B7R5qLH',
#    'images': [{'height': 640,
#      'width': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b2732fb583ed96f8f35cbf2897ba'},
#     {'height': 300,
#      'width': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e022fb583ed96f8f35cbf2897ba'},
#     {'height': 64,
#      'width': 64,
#      'url': 'https://i.scdn.co/image/ab67616d000048512fb583ed96f8f35cbf2897ba'}],
#    'is_playable': True,
#    'name': 'GÉNESIS',
#    'release_date': '2023-06-29',
#    'release_date_precision': 'day',
#    'total_tracks': 17,
#    'type': 'album',
#    'uri': 'spotify:album:4jox3ip1I39DFC2B7R5qLH'},
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/12GqGscKJx3aE4t07u7eVZ'},
#     'href': 'https://api.spotify.com/v1/artists/12GqGscKJx3aE4t07u7eVZ',
#     'id': '12GqGscKJx3aE4t07u7eVZ',
#     'name': 'Peso Pluma',
#     'type': 'artist',
#     'uri': 'spotify:artist:12GqGscKJx3aE4t07u7eVZ'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/6Sbl0NT50roqWvy746MfVf'},
#     'href': 'https://api.spotify.com/v1/artists/6Sbl0NT50roqWvy746MfVf',
#     'id': '6Sbl0NT50roqWvy746MfVf',
#     'name': 'Gabito Ballesteros',
#     'type': 'artist',
#     'uri': 'spotify:artist:6Sbl0NT50roqWvy746MfVf'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/7Gi6gjaWy3DxyilpF1a8Is'},
#     'href': 'https://api.spotify.com/v1/artists/7Gi6gjaWy3DxyilpF1a8Is',
#     'id': '7Gi6gjaWy3DxyilpF1a8Is',
#     'name': 'Junior H',
#     'type': 'artist',
#     'uri': 'spotify:artist:7Gi6gjaWy3DxyilpF1a8Is'}],
#   'available_markets': ['AR',
#    'AU',
#    'AT',
#    'BE',
#    'BO',
#    'BR',
#    'BG',
#    'CA',
#    'CL',
#    'CO',
#    'CR',
#    'CY',
#    'CZ',
#    'DK',
#    'DO',
#    'DE',
#    'EC',
#    'EE',
#    'SV',
#    'FI',
#    'FR',
#    'GR',
#    'GT',
#    'HN',
#    'HK',
#    'HU',
#    'IS',
#    'IE',
#    'IT',
#    'LV',
#    'LT',
#    'LU',
#    'MY',
#    'MT',
#    'MX',
#    'NL',
#    'NZ',
#    'NI',
#    'NO',
#    'PA',
#    'PY',
#    'PE',
#    'PH',
#    'PL',
#    'PT',
#    'SG',
#    'SK',
#    'ES',
#    'SE',
#    'CH',
#    'TW',
#    'TR',
#    'UY',
#    'US',
#    'GB',
#    'AD',
#    'LI',
#    'MC',
#    'ID',
#    'JP',
#    'TH',
#    'VN',
#    'RO',
#    'IL',
#    'ZA',
#    'SA',
#    'AE',
#    'BH',
#    'QA',
#    'OM',
#    'KW',
#    'EG',
#    'MA',
#    'DZ',
#    'TN',
#    'LB',
#    'JO',
#    'PS',
#    'IN',
#    'BY',
#    'KZ',
#    'MD',
#    'UA',
#    'AL',
#    'BA',
#    'HR',
#    'ME',
#    'MK',
#    'RS',
#    'SI',
#    'KR',
#    'BD',
#    'PK',
#    'LK',
#    'GH',
#    'KE',
#    'NG',
#    'TZ',
#    'UG',
#    'AG',
#    'AM',
#    'BS',
#    'BB',
#    'BZ',
#    'BT',
#    'BW',
#    'BF',
#    'CV',
#    'CW',
#    'DM',
#    'FJ',
#    'GM',
#    'GE',
#    'GD',
#    'GW',
#    'GY',
#    'HT',
#    'JM',
#    'KI',
#    'LS',
#    'LR',
#    'MW',
#    'MV',
#    'ML',
#    'MH',
#    'FM',
#    'NA',
#    'NR',
#    'NE',
#    'PW',
#    'PG',
#    'PR',
#    'WS',
#    'SM',
#    'ST',
#    'SN',
#    'SC',
#    'SL',
#    'SB',
#    'KN',
#    'LC',
#    'VC',
#    'SR',
#    'TL',
#    'TO',
#    'TT',
#    'TV',
#    'VU',
#    'AZ',
#    'BN',
#    'BI',
#    'KH',
#    'CM',
#    'TD',
#    'KM',
#    'GQ',
#    'SZ',
#    'GA',
#    'GN',
#    'KG',
#    'LA',
#    'MO',
#    'MR',
#    'MN',
#    'NP',
#    'RW',
#    'TG',
#    'UZ',
#    'ZW',
#    'BJ',
#    'MG',
#    'MU',
#    'MZ',
#    'AO',
#    'CI',
#    'DJ',
#    'ZM',
#    'CD',
#    'CG',
#    'IQ',
#    'LY',
#    'TJ',
#    'VE',
#    'ET',
#    'XK'],
#   'disc_number': 1,
#   'duration_ms': 212878,
#   'explicit': True,
#   'external_ids': {'isrc': 'QM7282306246'},
#   'external_urls': {'spotify': 'https://open.spotify.com/track/7mXuWTczZNxG5EDcjFEuJR'},
#   'href': 'https://api.spotify.com/v1/tracks/7mXuWTczZNxG5EDcjFEuJR',
#   'id': '7mXuWTczZNxG5EDcjFEuJR',
#   'is_local': False,
#   'is_playable': True,
#   'name': 'LADY GAGA',
#   'popularity': 81,
#   'preview_url': None,
#   'track_number': 10,
#   'type': 'track',
#   'uri': 'spotify:track:7mXuWTczZNxG5EDcjFEuJR'},
#  {'album': {'album_type': 'single',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1HY2Jd0NmPuamShAr6KMms'},
#      'href': 'https://api.spotify.com/v1/artists/1HY2Jd0NmPuamShAr6KMms',
#      'id': '1HY2Jd0NmPuamShAr6KMms',
#      'name': 'Lady Gaga',
#      'type': 'artist',
#      'uri': 'spotify:artist:1HY2Jd0NmPuamShAr6KMms'}],
#    'available_markets': ['AR',
#     'AU',
#     'AT',
#     'BE',
#     'BO',
#     'BR',
#     'BG',
#     'CA',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DK',
#     'DO',
#     'DE',
#     'EC',
#     'EE',
#     'SV',
#     'FI',
#     'FR',
#     'GR',
#     'GT',
#     'HN',
#     'HK',
#     'HU',
#     'IS',
#     'IE',
#     'IT',
#     'LV',
#     'LT',
#     'LU',
#     'MY',
#     'MT',
#     'MX',
#     'NL',
#     'NZ',
#     'NI',
#     'NO',
#     'PA',
#     'PY',
#     'PE',
#     'PH',
#     'PL',
#     'PT',
#     'SG',
#     'SK',
#     'ES',
#     'SE',
#     'CH',
#     'TW',
#     'TR',
#     'UY',
#     'US',
#     'GB',
#     'AD',
#     'LI',
#     'MC',
#     'ID',
#     'JP',
#     'TH',
#     'VN',
#     'RO',
#     'IL',
#     'ZA',
#     'SA',
#     'AE',
#     'BH',
#     'QA',
#     'OM',
#     'KW',
#     'EG',
#     'MA',
#     'DZ',
#     'TN',
#     'LB',
#     'JO',
#     'PS',
#     'IN',
#     'KZ',
#     'MD',
#     'UA',
#     'AL',
#     'BA',
#     'HR',
#     'ME',
#     'MK',
#     'RS',
#     'SI',
#     'KR',
#     'BD',
#     'PK',
#     'LK',
#     'GH',
#     'KE',
#     'NG',
#     'TZ',
#     'UG',
#     'AG',
#     'AM',
#     'BS',
#     'BB',
#     'BZ',
#     'BT',
#     'BW',
#     'BF',
#     'CV',
#     'CW',
#     'DM',
#     'FJ',
#     'GM',
#     'GE',
#     'GD',
#     'GW',
#     'GY',
#     'HT',
#     'JM',
#     'KI',
#     'LS',
#     'LR',
#     'MW',
#     'MV',
#     'ML',
#     'MH',
#     'FM',
#     'NA',
#     'NR',
#     'NE',
#     'PW',
#     'PG',
#     'WS',
#     'SM',
#     'ST',
#     'SN',
#     'SC',
#     'SL',
#     'SB',
#     'KN',
#     'LC',
#     'VC',
#     'SR',
#     'TL',
#     'TO',
#     'TT',
#     'TV',
#     'VU',
#     'AZ',
#     'BN',
#     'BI',
#     'KH',
#     'CM',
#     'TD',
#     'KM',
#     'GQ',
#     'SZ',
#     'GA',
#     'GN',
#     'KG',
#     'LA',
#     'MO',
#     'MR',
#     'MN',
#     'NP',
#     'RW',
#     'TG',
#     'UZ',
#     'ZW',
#     'BJ',
#     'MG',
#     'MU',
#     'MZ',
#     'AO',
#     'CI',
#     'DJ',
#     'ZM',
#     'CD',
#     'CG',
#     'IQ',
#     'LY',
#     'TJ',
#     'VE',
#     'ET',
#     'XK'],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/52BWvTRMsPqjHzrbQomgwP'},
#    'href': 'https://api.spotify.com/v1/albums/52BWvTRMsPqjHzrbQomgwP',
#    'id': '52BWvTRMsPqjHzrbQomgwP',
#    'images': [{'height': 640,
#      'width': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b273465e58cfc2ee480a7d0ae59d'},
#     {'height': 300,
#      'width': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e02465e58cfc2ee480a7d0ae59d'},
#     {'height': 64,
#      'width': 64,
#      'url': 'https://i.scdn.co/image/ab67616d00004851465e58cfc2ee480a7d0ae59d'}],
#    'is_playable': True,
#    'name': 'Disease',
#    'release_date': '2024-10-25',
#    'release_date_precision': 'day',
#    'total_tracks': 1,
#    'type': 'album',
#    'uri': 'spotify:album:52BWvTRMsPqjHzrbQomgwP'},
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1HY2Jd0NmPuamShAr6KMms'},
#     'href': 'https://api.spotify.com/v1/artists/1HY2Jd0NmPuamShAr6KMms',
#     'id': '1HY2Jd0NmPuamShAr6KMms',
#     'name': 'Lady Gaga',
#     'type': 'artist',
#     'uri': 'spotify:artist:1HY2Jd0NmPuamShAr6KMms'}],
#   'available_markets': ['AR',
#    'AU',
#    'AT',
#    'BE',
#    'BO',
#    'BR',
#    'BG',
#    'CA',
#    'CL',
#    'CO',
#    'CR',
#    'CY',
#    'CZ',
#    'DK',
#    'DO',
#    'DE',
#    'EC',
#    'EE',
#    'SV',
#    'FI',
#    'FR',
#    'GR',
#    'GT',
#    'HN',
#    'HK',
#    'HU',
#    'IS',
#    'IE',
#    'IT',
#    'LV',
#    'LT',
#    'LU',
#    'MY',
#    'MT',
#    'MX',
#    'NL',
#    'NZ',
#    'NI',
#    'NO',
#    'PA',
#    'PY',
#    'PE',
#    'PH',
#    'PL',
#    'PT',
#    'SG',
#    'SK',
#    'ES',
#    'SE',
#    'CH',
#    'TW',
#    'TR',
#    'UY',
#    'US',
#    'GB',
#    'AD',
#    'LI',
#    'MC',
#    'ID',
#    'JP',
#    'TH',
#    'VN',
#    'RO',
#    'IL',
#    'ZA',
#    'SA',
#    'AE',
#    'BH',
#    'QA',
#    'OM',
#    'KW',
#    'EG',
#    'MA',
#    'DZ',
#    'TN',
#    'LB',
#    'JO',
#    'PS',
#    'IN',
#    'KZ',
#    'MD',
#    'UA',
#    'AL',
#    'BA',
#    'HR',
#    'ME',
#    'MK',
#    'RS',
#    'SI',
#    'KR',
#    'BD',
#    'PK',
#    'LK',
#    'GH',
#    'KE',
#    'NG',
#    'TZ',
#    'UG',
#    'AG',
#    'AM',
#    'BS',
#    'BB',
#    'BZ',
#    'BT',
#    'BW',
#    'BF',
#    'CV',
#    'CW',
#    'DM',
#    'FJ',
#    'GM',
#    'GE',
#    'GD',
#    'GW',
#    'GY',
#    'HT',
#    'JM',
#    'KI',
#    'LS',
#    'LR',
#    'MW',
#    'MV',
#    'ML',
#    'MH',
#    'FM',
#    'NA',
#    'NR',
#    'NE',
#    'PW',
#    'PG',
#    'WS',
#    'SM',
#    'ST',
#    'SN',
#    'SC',
#    'SL',
#    'SB',
#    'KN',
#    'LC',
#    'VC',
#    'SR',
#    'TL',
#    'TO',
#    'TT',
#    'TV',
#    'VU',
#    'AZ',
#    'BN',
#    'BI',
#    'KH',
#    'CM',
#    'TD',
#    'KM',
#    'GQ',
#    'SZ',
#    'GA',
#    'GN',
#    'KG',
#    'LA',
#    'MO',
#    'MR',
#    'MN',
#    'NP',
#    'RW',
#    'TG',
#    'UZ',
#    'ZW',
#    'BJ',
#    'MG',
#    'MU',
#    'MZ',
#    'AO',
#    'CI',
#    'DJ',
#    'ZM',
#    'CD',
#    'CG',
#    'IQ',
#    'LY',
#    'TJ',
#    'VE',
#    'ET',
#    'XK'],
#   'disc_number': 1,
#   'duration_ms': 229997,
#   'explicit': False,
#   'external_ids': {'isrc': 'USUM72407015'},
#   'external_urls': {'spotify': 'https://open.spotify.com/track/19KlZwqlT3fguP2BeHF1Q1'},
#   'href': 'https://api.spotify.com/v1/tracks/19KlZwqlT3fguP2BeHF1Q1',
#   'id': '19KlZwqlT3fguP2BeHF1Q1',
#   'is_local': False,
#   'is_playable': True,
#   'name': 'Disease',
#   'popularity': 80,
#   'preview_url': None,
#   'track_number': 1,
#   'type': 'track',
#   'uri': 'spotify:track:19KlZwqlT3fguP2BeHF1Q1'},
#  {'album': {'album_type': 'album',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1HY2Jd0NmPuamShAr6KMms'},
#      'href': 'https://api.spotify.com/v1/artists/1HY2Jd0NmPuamShAr6KMms',
#      'id': '1HY2Jd0NmPuamShAr6KMms',
#      'name': 'Lady Gaga',
#      'type': 'artist',
#      'uri': 'spotify:artist:1HY2Jd0NmPuamShAr6KMms'}],
#    'available_markets': ['AR',
#     'AU',
#     'AT',
#     'BE',
#     'BO',
#     'BR',
#     'BG',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DK',
#     'DO',
#     'DE',
#     'EC',
#     'EE',
#     'SV',
#     'FI',
#     'FR',
#     'GR',
#     'GT',
#     'HN',
#     'HK',
#     'HU',
#     'IS',
#     'IE',
#     'IT',
#     'LV',
#     'LT',
#     'LU',
#     'MY',
#     'MT',
#     'NL',
#     'NZ',
#     'NI',
#     'NO',
#     'PA',
#     'PY',
#     'PE',
#     'PH',
#     'PL',
#     'PT',
#     'SG',
#     'SK',
#     'ES',
#     'CH',
#     'TW',
#     'TR',
#     'UY',
#     'GB',
#     'AD',
#     'LI',
#     'MC',
#     'ID',
#     'JP',
#     'TH',
#     'VN',
#     'RO',
#     'IL',
#     'ZA',
#     'SA',
#     'AE',
#     'BH',
#     'QA',
#     'OM',
#     'KW',
#     'EG',
#     'MA',
#     'DZ',
#     'TN',
#     'LB',
#     'JO',
#     'PS',
#     'IN',
#     'BY',
#     'KZ',
#     'MD',
#     'UA',
#     'AL',
#     'BA',
#     'HR',
#     'ME',
#     'MK',
#     'RS',
#     'SI',
#     'KR',
#     'BD',
#     'PK',
#     'LK',
#     'GH',
#     'KE',
#     'NG',
#     'TZ',
#     'UG',
#     'AG',
#     'AM',
#     'BS',
#     'BB',
#     'BZ',
#     'BT',
#     'BW',
#     'BF',
#     'CV',
#     'CW',
#     'DM',
#     'FJ',
#     'GM',
#     'GD',
#     'GW',
#     'GY',
#     'HT',
#     'JM',
#     'KI',
#     'LS',
#     'LR',
#     'MW',
#     'MV',
#     'ML',
#     'MH',
#     'FM',
#     'NA',
#     'NR',
#     'NE',
#     'PW',
#     'PG',
#     'WS',
#     'ST',
#     'SN',
#     'SC',
#     'SL',
#     'SB',
#     'KN',
#     'LC',
#     'VC',
#     'SR',
#     'TL',
#     'TO',
#     'TT',
#     'TV',
#     'AZ',
#     'BN',
#     'BI',
#     'KH',
#     'CM',
#     'TD',
#     'KM',
#     'GQ',
#     'SZ',
#     'GA',
#     'GN',
#     'KG',
#     'LA',
#     'MO',
#     'MR',
#     'MN',
#     'NP',
#     'RW',
#     'TG',
#     'UZ',
#     'ZW',
#     'BJ',
#     'MG',
#     'MU',
#     'MZ',
#     'AO',
#     'CI',
#     'DJ',
#     'ZM',
#     'CD',
#     'CG',
#     'IQ',
#     'LY',
#     'TJ',
#     'VE',
#     'XK'],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/1qwlxZTNLe1jq3b0iidlue'},
#    'href': 'https://api.spotify.com/v1/albums/1qwlxZTNLe1jq3b0iidlue',
#    'id': '1qwlxZTNLe1jq3b0iidlue',
#    'images': [{'height': 640,
#      'width': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b273e691217483df8798445c82e2'},
#     {'height': 300,
#      'width': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e02e691217483df8798445c82e2'},
#     {'height': 64,
#      'width': 64,
#      'url': 'https://i.scdn.co/image/ab67616d00004851e691217483df8798445c82e2'}],
#    'is_playable': True,
#    'name': 'The Fame',
#    'release_date': '2008-01-01',
#    'release_date_precision': 'day',
#    'total_tracks': 15,
#    'type': 'album',
#    'uri': 'spotify:album:1qwlxZTNLe1jq3b0iidlue'},
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1HY2Jd0NmPuamShAr6KMms'},
#     'href': 'https://api.spotify.com/v1/artists/1HY2Jd0NmPuamShAr6KMms',
#     'id': '1HY2Jd0NmPuamShAr6KMms',
#     'name': 'Lady Gaga',
#     'type': 'artist',
#     'uri': 'spotify:artist:1HY2Jd0NmPuamShAr6KMms'}],
#   'available_markets': ['AR',
#    'AU',
#    'AT',
#    'BE',
#    'BO',
#    'BR',
#    'BG',
#    'CL',
#    'CO',
#    'CR',
#    'CY',
#    'CZ',
#    'DK',
#    'DO',
#    'DE',
#    'EC',
#    'EE',
#    'SV',
#    'FI',
#    'FR',
#    'GR',
#    'GT',
#    'HN',
#    'HK',
#    'HU',
#    'IS',
#    'IE',
#    'IT',
#    'LV',
#    'LT',
#    'LU',
#    'MY',
#    'MT',
#    'NL',
#    'NZ',
#    'NI',
#    'NO',
#    'PA',
#    'PY',
#    'PE',
#    'PH',
#    'PL',
#    'PT',
#    'SG',
#    'SK',
#    'ES',
#    'CH',
#    'TW',
#    'TR',
#    'UY',
#    'GB',
#    'AD',
#    'LI',
#    'MC',
#    'ID',
#    'JP',
#    'TH',
#    'VN',
#    'RO',
#    'IL',
#    'ZA',
#    'SA',
#    'AE',
#    'BH',
#    'QA',
#    'OM',
#    'KW',
#    'EG',
#    'MA',
#    'DZ',
#    'TN',
#    'LB',
#    'JO',
#    'PS',
#    'IN',
#    'BY',
#    'KZ',
#    'MD',
#    'UA',
#    'AL',
#    'BA',
#    'HR',
#    'ME',
#    'MK',
#    'RS',
#    'SI',
#    'KR',
#    'BD',
#    'PK',
#    'LK',
#    'GH',
#    'KE',
#    'NG',
#    'TZ',
#    'UG',
#    'AG',
#    'AM',
#    'BS',
#    'BB',
#    'BZ',
#    'BT',
#    'BW',
#    'BF',
#    'CV',
#    'CW',
#    'DM',
#    'FJ',
#    'GM',
#    'GD',
#    'GW',
#    'GY',
#    'HT',
#    'JM',
#    'KI',
#    'LS',
#    'LR',
#    'MW',
#    'MV',
#    'ML',
#    'MH',
#    'FM',
#    'NA',
#    'NR',
#    'NE',
#    'PW',
#    'PG',
#    'WS',
#    'ST',
#    'SN',
#    'SC',
#    'SL',
#    'SB',
#    'KN',
#    'LC',
#    'VC',
#    'SR',
#    'TL',
#    'TO',
#    'TT',
#    'TV',
#    'AZ',
#    'BN',
#    'BI',
#    'KH',
#    'CM',
#    'TD',
#    'KM',
#    'GQ',
#    'SZ',
#    'GA',
#    'GN',
#    'KG',
#    'LA',
#    'MO',
#    'MR',
#    'MN',
#    'NP',
#    'RW',
#    'TG',
#    'UZ',
#    'ZW',
#    'BJ',
#    'MG',
#    'MU',
#    'MZ',
#    'AO',
#    'CI',
#    'DJ',
#    'ZM',
#    'CD',
#    'CG',
#    'IQ',
#    'LY',
#    'TJ',
#    'VE',
#    'XK'],
#   'disc_number': 1,
#   'duration_ms': 237200,
#   'explicit': True,
#   'external_ids': {'isrc': 'USUM70824409'},
#   'external_urls': {'spotify': 'https://open.spotify.com/track/1QV6tiMFM6fSOKOGLMHYYg'},
#   'href': 'https://api.spotify.com/v1/tracks/1QV6tiMFM6fSOKOGLMHYYg',
#   'id': '1QV6tiMFM6fSOKOGLMHYYg',
#   'is_local': False,
#   'is_playable': True,
#   'name': 'Poker Face',
#   'popularity': 87,
#   'preview_url': None,
#   'track_number': 4,
#   'type': 'track',
#   'uri': 'spotify:track:1QV6tiMFM6fSOKOGLMHYYg'},
#  {'album': {'album_type': 'album',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1HY2Jd0NmPuamShAr6KMms'},
#      'href': 'https://api.spotify.com/v1/artists/1HY2Jd0NmPuamShAr6KMms',
#      'id': '1HY2Jd0NmPuamShAr6KMms',
#      'name': 'Lady Gaga',
#      'type': 'artist',
#      'uri': 'spotify:artist:1HY2Jd0NmPuamShAr6KMms'}],
#    'available_markets': ['AR',
#     'AU',
#     'AT',
#     'BE',
#     'BO',
#     'BR',
#     'BG',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DK',
#     'DO',
#     'DE',
#     'EC',
#     'EE',
#     'SV',
#     'FI',
#     'FR',
#     'GR',
#     'GT',
#     'HN',
#     'HK',
#     'HU',
#     'IS',
#     'IE',
#     'IT',
#     'LV',
#     'LT',
#     'LU',
#     'MY',
#     'MT',
#     'MX',
#     'NL',
#     'NZ',
#     'NI',
#     'NO',
#     'PA',
#     'PY',
#     'PE',
#     'PH',
#     'PL',
#     'PT',
#     'SG',
#     'SK',
#     'ES',
#     'SE',
#     'CH',
#     'TW',
#     'TR',
#     'UY',
#     'GB',
#     'AD',
#     'LI',
#     'MC',
#     'ID',
#     'TH',
#     'VN',
#     'RO',
#     'IL',
#     'ZA',
#     'SA',
#     'AE',
#     'BH',
#     'QA',
#     'OM',
#     'KW',
#     'EG',
#     'MA',
#     'DZ',
#     'TN',
#     'LB',
#     'JO',
#     'PS',
#     'IN',
#     'BY',
#     'KZ',
#     'MD',
#     'UA',
#     'AL',
#     'BA',
#     'HR',
#     'ME',
#     'MK',
#     'RS',
#     'SI',
#     'KR',
#     'BD',
#     'PK',
#     'LK',
#     'GH',
#     'KE',
#     'NG',
#     'TZ',
#     'UG',
#     'AG',
#     'AM',
#     'BS',
#     'BB',
#     'BZ',
#     'BT',
#     'BW',
#     'BF',
#     'CV',
#     'CW',
#     'DM',
#     'FJ',
#     'GM',
#     'GD',
#     'GW',
#     'GY',
#     'HT',
#     'JM',
#     'KI',
#     'LS',
#     'LR',
#     'MW',
#     'MV',
#     'ML',
#     'MH',
#     'FM',
#     'NA',
#     'NR',
#     'NE',
#     'PW',
#     'PG',
#     'WS',
#     'ST',
#     'SN',
#     'SC',
#     'SL',
#     'SB',
#     'KN',
#     'LC',
#     'VC',
#     'SR',
#     'TL',
#     'TO',
#     'TT',
#     'TV',
#     'AZ',
#     'BN',
#     'BI',
#     'KH',
#     'CM',
#     'TD',
#     'KM',
#     'GQ',
#     'SZ',
#     'GA',
#     'GN',
#     'KG',
#     'LA',
#     'MO',
#     'MR',
#     'MN',
#     'NP',
#     'RW',
#     'TG',
#     'UZ',
#     'ZW',
#     'BJ',
#     'MG',
#     'MU',
#     'MZ',
#     'AO',
#     'CI',
#     'DJ',
#     'ZM',
#     'CD',
#     'CG',
#     'IQ',
#     'LY',
#     'TJ',
#     'VE',
#     'XK'],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/6LY3AerY6KNGOPsNPL63Kk'},
#    'href': 'https://api.spotify.com/v1/albums/6LY3AerY6KNGOPsNPL63Kk',
#    'id': '6LY3AerY6KNGOPsNPL63Kk',
#    'images': [{'height': 640,
#      'width': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b273a5d31644260279be8d0c46c0'},
#     {'height': 300,
#      'width': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e02a5d31644260279be8d0c46c0'},
#     {'height': 64,
#      'width': 64,
#      'url': 'https://i.scdn.co/image/ab67616d00004851a5d31644260279be8d0c46c0'}],
#    'is_playable': True,
#    'name': 'Born This Way (International Special Edition Version)',
#    'release_date': '2011-05-23',
#    'release_date_precision': 'day',
#    'total_tracks': 23,
#    'type': 'album',
#    'uri': 'spotify:album:6LY3AerY6KNGOPsNPL63Kk'},
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1HY2Jd0NmPuamShAr6KMms'},
#     'href': 'https://api.spotify.com/v1/artists/1HY2Jd0NmPuamShAr6KMms',
#     'id': '1HY2Jd0NmPuamShAr6KMms',
#     'name': 'Lady Gaga',
#     'type': 'artist',
#     'uri': 'spotify:artist:1HY2Jd0NmPuamShAr6KMms'}],
#   'available_markets': ['AR',
#    'AU',
#    'AT',
#    'BE',
#    'BO',
#    'BR',
#    'BG',
#    'CL',
#    'CO',
#    'CR',
#    'CY',
#    'CZ',
#    'DK',
#    'DO',
#    'DE',
#    'EC',
#    'EE',
#    'SV',
#    'FI',
#    'FR',
#    'GR',
#    'GT',
#    'HN',
#    'HK',
#    'HU',
#    'IS',
#    'IE',
#    'IT',
#    'LV',
#    'LT',
#    'LU',
#    'MY',
#    'MT',
#    'MX',
#    'NL',
#    'NZ',
#    'NI',
#    'NO',
#    'PA',
#    'PY',
#    'PE',
#    'PH',
#    'PL',
#    'PT',
#    'SG',
#    'SK',
#    'ES',
#    'SE',
#    'CH',
#    'TW',
#    'TR',
#    'UY',
#    'GB',
#    'AD',
#    'LI',
#    'MC',
#    'ID',
#    'TH',
#    'VN',
#    'RO',
#    'IL',
#    'ZA',
#    'SA',
#    'AE',
#    'BH',
#    'QA',
#    'OM',
#    'KW',
#    'EG',
#    'MA',
#    'DZ',
#    'TN',
#    'LB',
#    'JO',
#    'PS',
#    'IN',
#    'BY',
#    'KZ',
#    'MD',
#    'UA',
#    'AL',
#    'BA',
#    'HR',
#    'ME',
#    'MK',
#    'RS',
#    'SI',
#    'KR',
#    'BD',
#    'PK',
#    'LK',
#    'GH',
#    'KE',
#    'NG',
#    'TZ',
#    'UG',
#    'AG',
#    'AM',
#    'BS',
#    'BB',
#    'BZ',
#    'BT',
#    'BW',
#    'BF',
#    'CV',
#    'CW',
#    'DM',
#    'FJ',
#    'GM',
#    'GD',
#    'GW',
#    'GY',
#    'HT',
#    'JM',
#    'KI',
#    'LS',
#    'LR',
#    'MW',
#    'MV',
#    'ML',
#    'MH',
#    'FM',
#    'NA',
#    'NR',
#    'NE',
#    'PW',
#    'PG',
#    'WS',
#    'ST',
#    'SN',
#    'SC',
#    'SL',
#    'SB',
#    'KN',
#    'LC',
#    'VC',
#    'SR',
#    'TL',
#    'TO',
#    'TT',
#    'TV',
#    'AZ',
#    'BN',
#    'BI',
#    'KH',
#    'CM',
#    'TD',
#    'KM',
#    'GQ',
#    'SZ',
#    'GA',
#    'GN',
#    'KG',
#    'LA',
#    'MO',
#    'MR',
#    'MN',
#    'NP',
#    'RW',
#    'TG',
#    'UZ',
#    'ZW',
#    'BJ',
#    'MG',
#    'MU',
#    'MZ',
#    'AO',
#    'CI',
#    'DJ',
#    'ZM',
#    'CD',
#    'CG',
#    'IQ',
#    'LY',
#    'TJ',
#    'VE',
#    'XK'],
#   'disc_number': 1,
#   'duration_ms': 264520,
#   'explicit': False,
#   'external_ids': {'isrc': 'USUM71106431'},
#   'external_urls': {'spotify': 'https://open.spotify.com/track/02d1E4NRuh7OEQO4vCb9PD'},
#   'href': 'https://api.spotify.com/v1/tracks/02d1E4NRuh7OEQO4vCb9PD',
#   'id': '02d1E4NRuh7OEQO4vCb9PD',
#   'is_local': False,
#   'is_playable': True,
#   'name': 'Marry The Night',
#   'popularity': 66,
#   'preview_url': None,
#   'track_number': 1,
#   'type': 'track',
#   'uri': 'spotify:track:02d1E4NRuh7OEQO4vCb9PD'},
#  {'album': {'album_type': 'album',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1HY2Jd0NmPuamShAr6KMms'},
#      'href': 'https://api.spotify.com/v1/artists/1HY2Jd0NmPuamShAr6KMms',
#      'id': '1HY2Jd0NmPuamShAr6KMms',
#      'name': 'Lady Gaga',
#      'type': 'artist',
#      'uri': 'spotify:artist:1HY2Jd0NmPuamShAr6KMms'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/4VIvfOurcf0vuLRxLkGnIG'},
#      'href': 'https://api.spotify.com/v1/artists/4VIvfOurcf0vuLRxLkGnIG',
#      'id': '4VIvfOurcf0vuLRxLkGnIG',
#      'name': 'Bradley Cooper',
#      'type': 'artist',
#      'uri': 'spotify:artist:4VIvfOurcf0vuLRxLkGnIG'}],
#    'available_markets': ['AR',
#     'AU',
#     'AT',
#     'BE',
#     'BO',
#     'BR',
#     'BG',
#     'CA',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DK',
#     'DO',
#     'DE',
#     'EC',
#     'EE',
#     'SV',
#     'FI',
#     'FR',
#     'GR',
#     'GT',
#     'HN',
#     'HK',
#     'HU',
#     'IS',
#     'IE',
#     'IT',
#     'LV',
#     'LT',
#     'LU',
#     'MY',
#     'MT',
#     'MX',
#     'NL',
#     'NZ',
#     'NI',
#     'NO',
#     'PA',
#     'PY',
#     'PE',
#     'PH',
#     'PL',
#     'PT',
#     'SG',
#     'SK',
#     'ES',
#     'SE',
#     'CH',
#     'TW',
#     'TR',
#     'UY',
#     'US',
#     'GB',
#     'AD',
#     'LI',
#     'MC',
#     'ID',
#     'JP',
#     'TH',
#     'VN',
#     'RO',
#     'IL',
#     'ZA',
#     'SA',
#     'AE',
#     'BH',
#     'QA',
#     'OM',
#     'KW',
#     'EG',
#     'MA',
#     'DZ',
#     'TN',
#     'LB',
#     'JO',
#     'PS',
#     'IN',
#     'BY',
#     'KZ',
#     'MD',
#     'UA',
#     'AL',
#     'BA',
#     'HR',
#     'ME',
#     'MK',
#     'RS',
#     'SI',
#     'KR',
#     'BD',
#     'PK',
#     'LK',
#     'GH',
#     'KE',
#     'NG',
#     'TZ',
#     'UG',
#     'AG',
#     'AM',
#     'BS',
#     'BB',
#     'BZ',
#     'BT',
#     'BW',
#     'BF',
#     'CV',
#     'CW',
#     'DM',
#     'FJ',
#     'GM',
#     'GE',
#     'GD',
#     'GW',
#     'GY',
#     'HT',
#     'JM',
#     'KI',
#     'LS',
#     'LR',
#     'MW',
#     'MV',
#     'ML',
#     'MH',
#     'FM',
#     'NA',
#     'NR',
#     'NE',
#     'PW',
#     'PG',
#     'WS',
#     'SM',
#     'ST',
#     'SN',
#     'SC',
#     'SL',
#     'SB',
#     'KN',
#     'LC',
#     'VC',
#     'SR',
#     'TL',
#     'TO',
#     'TT',
#     'TV',
#     'VU',
#     'AZ',
#     'BN',
#     'BI',
#     'KH',
#     'CM',
#     'TD',
#     'KM',
#     'GQ',
#     'SZ',
#     'GA',
#     'GN',
#     'KG',
#     'LA',
#     'MO',
#     'MR',
#     'MN',
#     'NP',
#     'RW',
#     'TG',
#     'UZ',
#     'ZW',
#     'BJ',
#     'MG',
#     'MU',
#     'MZ',
#     'AO',
#     'CI',
#     'DJ',
#     'ZM',
#     'CD',
#     'CG',
#     'IQ',
#     'LY',
#     'TJ',
# ...
#   'id': '17sOAutZqK3xM5O6Cc2pMj',
#   'is_local': False,
#   'is_playable': True,
#   'name': 'Abracadabra - Gesaffelstein Remix',
#   'popularity': 71,
#   'preview_url': None,
#   'track_number': 1,
#   'type': 'track',
#   'uri': 'spotify:track:17sOAutZqK3xM5O6Cc2pMj'},
#  {'album': {'album_type': 'album',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5Hsv8dUHHOdnn72q4XIVz7'},
#      'href': 'https://api.spotify.com/v1/artists/5Hsv8dUHHOdnn72q4XIVz7',
#      'id': '5Hsv8dUHHOdnn72q4XIVz7',
#      'name': 'Leiva',
#      'type': 'artist',
#      'uri': 'spotify:artist:5Hsv8dUHHOdnn72q4XIVz7'}],
#    'available_markets': ['AR',
#     'AU',
#     'AT',
#     'BE',
#     'BO',
#     'BR',
#     'BG',
#     'CA',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DK',
#     'DO',
#     'DE',
#     'EC',
#     'EE',
#     'SV',
#     'FI',
#     'FR',
#     'GR',
#     'GT',
#     'HN',
#     'HK',
#     'HU',
#     'IS',
#     'IE',
#     'IT',
#     'LV',
#     'LT',
#     'LU',
#     'MY',
#     'MT',
#     'MX',
#     'NL',
#     'NZ',
#     'NI',
#     'NO',
#     'PA',
#     'PY',
#     'PE',
#     'PH',
#     'PL',
#     'PT',
#     'SG',
#     'SK',
#     'ES',
#     'SE',
#     'CH',
#     'TW',
#     'TR',
#     'UY',
#     'US',
#     'GB',
#     'AD',
#     'LI',
#     'MC',
#     'ID',
#     'JP',
#     'TH',
#     'VN',
#     'RO',
#     'IL',
#     'ZA',
#     'SA',
#     'AE',
#     'BH',
#     'QA',
#     'OM',
#     'KW',
#     'EG',
#     'MA',
#     'DZ',
#     'TN',
#     'LB',
#     'JO',
#     'PS',
#     'IN',
#     'BY',
#     'KZ',
#     'MD',
#     'UA',
#     'AL',
#     'BA',
#     'HR',
#     'ME',
#     'MK',
#     'RS',
#     'SI',
#     'KR',
#     'BD',
#     'PK',
#     'LK',
#     'GH',
#     'KE',
#     'NG',
#     'TZ',
#     'UG',
#     'AG',
#     'AM',
#     'BS',
#     'BB',
#     'BZ',
#     'BT',
#     'BW',
#     'BF',
#     'CV',
#     'CW',
#     'DM',
#     'FJ',
#     'GM',
#     'GE',
#     'GD',
#     'GW',
#     'GY',
#     'HT',
#     'JM',
#     'KI',
#     'LS',
#     'LR',
#     'MW',
#     'MV',
#     'ML',
#     'MH',
#     'FM',
#     'NA',
#     'NR',
#     'NE',
#     'PW',
#     'PG',
#     'PR',
#     'WS',
#     'SM',
#     'ST',
#     'SN',
#     'SC',
#     'SL',
#     'SB',
#     'KN',
#     'LC',
#     'VC',
#     'SR',
#     'TL',
#     'TO',
#     'TT',
#     'TV',
#     'VU',
#     'AZ',
#     'BN',
#     'BI',
#     'KH',
#     'CM',
#     'TD',
#     'KM',
#     'GQ',
#     'SZ',
#     'GA',
#     'GN',
#     'KG',
#     'LA',
#     'MO',
#     'MR',
#     'MN',
#     'NP',
#     'RW',
#     'TG',
#     'UZ',
#     'ZW',
#     'BJ',
#     'MG',
#     'MU',
#     'MZ',
#     'AO',
#     'CI',
#     'DJ',
#     'ZM',
#     'CD',
#     'CG',
#     'IQ',
#     'LY',
#     'TJ',
#     'VE',
#     'ET',
#     'XK'],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/0nfk8ZUr3ufktOOaiIGFB9'},
#    'href': 'https://api.spotify.com/v1/albums/0nfk8ZUr3ufktOOaiIGFB9',
#    'id': '0nfk8ZUr3ufktOOaiIGFB9',
#    'images': [{'height': 640,
#      'width': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b273b8afbf7c075525002309111f'},
#     {'height': 300,
#      'width': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e02b8afbf7c075525002309111f'},
#     {'height': 64,
#      'width': 64,
#      'url': 'https://i.scdn.co/image/ab67616d00004851b8afbf7c075525002309111f'}],
#    'is_playable': True,
#    'name': 'Madrid Nuclear - En Directo',
#    'release_date': '2020-11-20',
#    'release_date_precision': 'day',
#    'total_tracks': 22,
#    'type': 'album',
#    'uri': 'spotify:album:0nfk8ZUr3ufktOOaiIGFB9'},
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5Hsv8dUHHOdnn72q4XIVz7'},
#     'href': 'https://api.spotify.com/v1/artists/5Hsv8dUHHOdnn72q4XIVz7',
#     'id': '5Hsv8dUHHOdnn72q4XIVz7',
#     'name': 'Leiva',
#     'type': 'artist',
#     'uri': 'spotify:artist:5Hsv8dUHHOdnn72q4XIVz7'}],
#   'available_markets': ['AR',
#    'AU',
#    'AT',
#    'BE',
#    'BO',
#    'BR',
#    'BG',
#    'CA',
#    'CL',
#    'CO',
#    'CR',
#    'CY',
#    'CZ',
#    'DK',
#    'DO',
#    'DE',
#    'EC',
#    'EE',
#    'SV',
#    'FI',
#    'FR',
#    'GR',
#    'GT',
#    'HN',
#    'HK',
#    'HU',
#    'IS',
#    'IE',
#    'IT',
#    'LV',
#    'LT',
#    'LU',
#    'MY',
#    'MT',
#    'MX',
#    'NL',
#    'NZ',
#    'NI',
#    'NO',
#    'PA',
#    'PY',
#    'PE',
#    'PH',
#    'PL',
#    'PT',
#    'SG',
#    'SK',
#    'ES',
#    'SE',
#    'CH',
#    'TW',
#    'TR',
#    'UY',
#    'US',
#    'GB',
#    'AD',
#    'LI',
#    'MC',
#    'ID',
#    'JP',
#    'TH',
#    'VN',
#    'RO',
#    'IL',
#    'ZA',
#    'SA',
#    'AE',
#    'BH',
#    'QA',
#    'OM',
#    'KW',
#    'EG',
#    'MA',
#    'DZ',
#    'TN',
#    'LB',
#    'JO',
#    'PS',
#    'IN',
#    'BY',
#    'KZ',
#    'MD',
#    'UA',
#    'AL',
#    'BA',
#    'HR',
#    'ME',
#    'MK',
#    'RS',
#    'SI',
#    'KR',
#    'BD',
#    'PK',
#    'LK',
#    'GH',
#    'KE',
#    'NG',
#    'TZ',
#    'UG',
#    'AG',
#    'AM',
#    'BS',
#    'BB',
#    'BZ',
#    'BT',
#    'BW',
#    'BF',
#    'CV',
#    'CW',
#    'DM',
#    'FJ',
#    'GM',
#    'GE',
#    'GD',
#    'GW',
#    'GY',
#    'HT',
#    'JM',
#    'KI',
#    'LS',
#    'LR',
#    'MW',
#    'MV',
#    'ML',
#    'MH',
#    'FM',
#    'NA',
#    'NR',
#    'NE',
#    'PW',
#    'PG',
#    'PR',
#    'WS',
#    'SM',
#    'ST',
#    'SN',
#    'SC',
#    'SL',
#    'SB',
#    'KN',
#    'LC',
#    'VC',
#    'SR',
#    'TL',
#    'TO',
#    'TT',
#    'TV',
#    'VU',
#    'AZ',
#    'BN',
#    'BI',
#    'KH',
#    'CM',
#    'TD',
#    'KM',
#    'GQ',
#    'SZ',
#    'GA',
#    'GN',
#    'KG',
#    'LA',
#    'MO',
#    'MR',
#    'MN',
#    'NP',
#    'RW',
#    'TG',
#    'UZ',
#    'ZW',
#    'BJ',
#    'MG',
#    'MU',
#    'MZ',
#    'AO',
#    'CI',
#    'DJ',
#    'ZM',
#    'CD',
#    'CG',
#    'IQ',
#    'LY',
#    'TJ',
#    'VE',
#    'ET',
#    'XK'],
#   'disc_number': 1,
#   'duration_ms': 288848,
#   'explicit': False,
#   'external_ids': {'isrc': 'ES5022000606'},
#   'external_urls': {'spotify': 'https://open.spotify.com/track/29ioGonb03ycTvJPDVJcfJ'},
#   'href': 'https://api.spotify.com/v1/tracks/29ioGonb03ycTvJPDVJcfJ',
#   'id': '29ioGonb03ycTvJPDVJcfJ',
#   'is_local': False,
#   'is_playable': True,
#   'name': 'Lady Madrid - Madrid Nuclear - En Directo',
#   'popularity': 36,
#   'preview_url': None,
#   'track_number': 22,
#   'type': 'track',
#   'uri': 'spotify:track:29ioGonb03ycTvJPDVJcfJ'},
#  {'album': {'album_type': 'album',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3xig6nxehGHX2tJVfjMdtZ'},
#      'href': 'https://api.spotify.com/v1/artists/3xig6nxehGHX2tJVfjMdtZ',
#      'id': '3xig6nxehGHX2tJVfjMdtZ',
#      'name': 'Piano Sueños',
#      'type': 'artist',
#      'uri': 'spotify:artist:3xig6nxehGHX2tJVfjMdtZ'}],
#    'available_markets': ['AR',
#     'AU',
#     'AT',
#     'BE',
#     'BO',
#     'BR',
#     'BG',
#     'CA',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DK',
#     'DO',
#     'DE',
#     'EC',
#     'EE',
#     'SV',
#     'FI',
#     'FR',
#     'GR',
#     'GT',
#     'HN',
#     'HK',
#     'HU',
#     'IS',
#     'IE',
#     'IT',
#     'LV',
#     'LT',
#     'LU',
#     'MY',
#     'MT',
#     'MX',
#     'NL',
#     'NZ',
#     'NI',
#     'NO',
#     'PA',
#     'PY',
#     'PE',
#     'PH',
#     'PL',
#     'PT',
#     'SG',
#     'SK',
#     'ES',
#     'SE',
#     'CH',
#     'TW',
#     'TR',
#     'UY',
#     'US',
#     'GB',
#     'AD',
#     'LI',
#     'MC',
#     'ID',
#     'JP',
#     'TH',
#     'VN',
#     'RO',
#     'IL',
#     'ZA',
#     'SA',
#     'AE',
#     'BH',
#     'QA',
#     'OM',
#     'KW',
#     'EG',
#     'MA',
#     'DZ',
#     'TN',
#     'LB',
#     'JO',
#     'PS',
#     'IN',
#     'BY',
#     'KZ',
#     'MD',
#     'UA',
#     'AL',
#     'BA',
#     'HR',
#     'ME',
#     'MK',
#     'RS',
#     'SI',
#     'KR',
#     'BD',
#     'PK',
#     'LK',
#     'GH',
#     'KE',
#     'NG',
#     'TZ',
#     'UG',
#     'AG',
#     'AM',
#     'BS',
#     'BB',
#     'BZ',
#     'BT',
#     'BW',
#     'BF',
#     'CV',
#     'CW',
#     'DM',
#     'FJ',
#     'GM',
#     'GE',
#     'GD',
#     'GW',
#     'GY',
#     'HT',
#     'JM',
#     'KI',
#     'LS',
#     'LR',
#     'MW',
#     'MV',
#     'ML',
#     'MH',
#     'FM',
#     'NA',
#     'NR',
#     'NE',
#     'PW',
#     'PG',
#     'PR',
#     'WS',
#     'SM',
#     'ST',
#     'SN',
#     'SC',
#     'SL',
#     'SB',
#     'KN',
#     'LC',
#     'VC',
#     'SR',
#     'TL',
#     'TO',
#     'TT',
#     'TV',
#     'VU',
#     'AZ',
#     'BN',
#     'BI',
#     'KH',
#     'CM',
#     'TD',
#     'KM',
#     'GQ',
#     'SZ',
#     'GA',
#     'GN',
#     'KG',
#     'LA',
#     'MO',
#     'MR',
#     'MN',
#     'NP',
#     'RW',
#     'TG',
#     'UZ',
#     'ZW',
#     'BJ',
#     'MG',
#     'MU',
#     'MZ',
#     'AO',
#     'CI',
#     'DJ',
#     'ZM',
#     'CD',
#     'CG',
#     'IQ',
#     'LY',
#     'TJ',
#     'VE',
#     'ET',
#     'XK'],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/1fk1eIjQwYlVNKvbbBSZxY'},
#    'href': 'https://api.spotify.com/v1/albums/1fk1eIjQwYlVNKvbbBSZxY',
#    'id': '1fk1eIjQwYlVNKvbbBSZxY',
#    'images': [{'height': 640,
#      'width': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b273b553c8b38ba75a2ecec6cfa4'},
#     {'height': 300,
#      'width': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e02b553c8b38ba75a2ecec6cfa4'},
#     {'height': 64,
#      'width': 64,
#      'url': 'https://i.scdn.co/image/ab67616d00004851b553c8b38ba75a2ecec6cfa4'}],
#    'is_playable': True,
#    'name': 'Éxitos En Versión Piano, Vol. 5',
#    'release_date': '2024-05-07',
#    'release_date_precision': 'day',
#    'total_tracks': 8,
#    'type': 'album',
#    'uri': 'spotify:album:1fk1eIjQwYlVNKvbbBSZxY'},
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3xig6nxehGHX2tJVfjMdtZ'},
#     'href': 'https://api.spotify.com/v1/artists/3xig6nxehGHX2tJVfjMdtZ',
#     'id': '3xig6nxehGHX2tJVfjMdtZ',
#     'name': 'Piano Sueños',
#     'type': 'artist',
#     'uri': 'spotify:artist:3xig6nxehGHX2tJVfjMdtZ'}],
#   'available_markets': ['AR',
#    'AU',
#    'AT',
#    'BE',
#    'BO',
#    'BR',
#    'BG',
#    'CA',
#    'CL',
#    'CO',
#    'CR',
#    'CY',
#    'CZ',
#    'DK',
#    'DO',
#    'DE',
#    'EC',
#    'EE',
#    'SV',
#    'FI',
#    'FR',
#    'GR',
#    'GT',
#    'HN',
#    'HK',
#    'HU',
#    'IS',
#    'IE',
#    'IT',
#    'LV',
#    'LT',
#    'LU',
#    'MY',
#    'MT',
#    'MX',
#    'NL',
#    'NZ',
#    'NI',
#    'NO',
#    'PA',
#    'PY',
#    'PE',
#    'PH',
#    'PL',
#    'PT',
#    'SG',
#    'SK',
#    'ES',
#    'SE',
#    'CH',
#    'TW',
#    'TR',
#    'UY',
#    'US',
#    'GB',
#    'AD',
#    'LI',
#    'MC',
#    'ID',
#    'JP',
#    'TH',
#    'VN',
#    'RO',
#    'IL',
#    'ZA',
#    'SA',
#    'AE',
#    'BH',
#    'QA',
#    'OM',
#    'KW',
#    'EG',
#    'MA',
#    'DZ',
#    'TN',
#    'LB',
#    'JO',
#    'PS',
#    'IN',
#    'BY',
#    'KZ',
#    'MD',
#    'UA',
#    'AL',
#    'BA',
#    'HR',
#    'ME',
#    'MK',
#    'RS',
#    'SI',
#    'KR',
#    'BD',
#    'PK',
#    'LK',
#    'GH',
#    'KE',
#    'NG',
#    'TZ',
#    'UG',
#    'AG',
#    'AM',
#    'BS',
#    'BB',
#    'BZ',
#    'BT',
#    'BW',
#    'BF',
#    'CV',
#    'CW',
#    'DM',
#    'FJ',
#    'GM',
#    'GE',
#    'GD',
#    'GW',
#    'GY',
#    'HT',
#    'JM',
#    'KI',
#    'LS',
#    'LR',
#    'MW',
#    'MV',
#    'ML',
#    'MH',
#    'FM',
#    'NA',
#    'NR',
#    'NE',
#    'PW',
#    'PG',
#    'PR',
#    'WS',
#    'SM',
#    'ST',
#    'SN',
#    'SC',
#    'SL',
#    'SB',
#    'KN',
#    'LC',
#    'VC',
#    'SR',
#    'TL',
#    'TO',
#    'TT',
#    'TV',
#    'VU',
#    'AZ',
#    'BN',
#    'BI',
#    'KH',
#    'CM',
#    'TD',
#    'KM',
#    'GQ',
#    'SZ',
#    'GA',
#    'GN',
#    'KG',
#    'LA',
#    'MO',
#    'MR',
#    'MN',
#    'NP',
#    'RW',
#    'TG',
#    'UZ',
#    'ZW',
#    'BJ',
#    'MG',
#    'MU',
#    'MZ',
#    'AO',
#    'CI',
#    'DJ',
#    'ZM',
#    'CD',
#    'CG',
#    'IQ',
#    'LY',
#    'TJ',
#    'VE',
#    'ET',
#    'XK'],
#   'disc_number': 1,
#   'duration_ms': 130279,
#   'explicit': False,
#   'external_ids': {'isrc': 'TCAIF2481458'},
#   'external_urls': {'spotify': 'https://open.spotify.com/track/48nIniJQUdY6on2hb3IHaP'},
#   'href': 'https://api.spotify.com/v1/tracks/48nIniJQUdY6on2hb3IHaP',
#   'id': '48nIniJQUdY6on2hb3IHaP',
#   'is_local': False,
#   'is_playable': True,
#   'name': 'Lady Gaga',
#   'popularity': 14,
#   'preview_url': None,
#   'track_number': 4,
#   'type': 'track',
#   'uri': 'spotify:track:48nIniJQUdY6on2hb3IHaP'},
#  {'album': {'album_type': 'compilation',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0LyfQWJT6nXafLPZqxe9Of'},
#      'href': 'https://api.spotify.com/v1/artists/0LyfQWJT6nXafLPZqxe9Of',
#      'id': '0LyfQWJT6nXafLPZqxe9Of',
#      'name': 'Various Artists',
#      'type': 'artist',
#      'uri': 'spotify:artist:0LyfQWJT6nXafLPZqxe9Of'}],
#    'available_markets': ['AR',
#     'AU',
#     'AT',
#     'BE',
#     'BO',
#     'BR',
#     'BG',
#     'CA',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DK',
#     'DO',
#     'DE',
#     'EC',
#     'EE',
#     'SV',
#     'FI',
#     'FR',
#     'GR',
#     'GT',
#     'HN',
#     'HK',
#     'HU',
#     'IS',
#     'IE',
#     'IT',
#     'LV',
#     'LT',
#     'LU',
#     'MY',
#     'MT',
#     'MX',
#     'NL',
#     'NZ',
#     'NI',
#     'NO',
#     'PA',
#     'PY',
#     'PE',
#     'PH',
#     'PL',
#     'PT',
#     'SG',
#     'SK',
#     'ES',
#     'SE',
#     'CH',
#     'TW',
#     'TR',
#     'UY',
#     'US',
#     'GB',
#     'ID',
#     'JP',
#     'TH',
#     'VN',
#     'RO',
#     'IL',
#     'ZA',
#     'SA',
#     'AE',
#     'BH',
#     'QA',
#     'OM',
#     'KW',
#     'EG',
#     'MA',
#     'DZ',
#     'TN',
#     'LB',
#     'JO',
#     'PS',
#     'IN',
#     'UA',
#     'AL',
#     'BA',
#     'HR',
#     'ME',
#     'MK',
#     'RS',
#     'SI',
#     'KR',
#     'LK',
#     'GH',
#     'KE',
#     'NG',
#     'TZ',
#     'UG',
#     'BW',
#     'BF',
#     'CV',
#     'CW',
#     'GM',
#     'GW',
#     'LS',
#     'LR',
#     'MW',
#     'ML',
#     'NA',
#     'NE',
#     'ST',
#     'SN',
#     'SC',
#     'SL',
#     'TT',
#     'BI',
#     'KH',
#     'CM',
#     'TD',
#     'KM',
#     'GQ',
#     'SZ',
#     'GA',
#     'GN',
#     'MR',
#     'RW',
#     'TG',
#     'ZW',
#     'BJ',
#     'MG',
#     'MU',
#     'MZ',
#     'AO',
#     'CI',
#     'DJ',
#     'ZM',
#     'CD',
#     'CG',
#     'IQ',
#     'LY',
#     'VE',
#     'ET',
#     'XK'],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/3E5hy15kBWv5bxvHyHzFiI'},
#    'href': 'https://api.spotify.com/v1/albums/3E5hy15kBWv5bxvHyHzFiI',
#    'id': '3E5hy15kBWv5bxvHyHzFiI',
#    'images': [{'height': 640,
#      'width': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b273def60d42b0408301ac14d455'},
#     {'height': 300,
#      'width': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e02def60d42b0408301ac14d455'},
#     {'height': 64,
#      'width': 64,
#      'url': 'https://i.scdn.co/image/ab67616d00004851def60d42b0408301ac14d455'}],
#    'is_playable': True,
#    'name': "Grandes Temazos de los 2000's",
#    'release_date': '2023-09-29',
#    'release_date_precision': 'day',
#    'total_tracks': 46,
#    'type': 'album',
#    'uri': 'spotify:album:3E5hy15kBWv5bxvHyHzFiI'},
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1HY2Jd0NmPuamShAr6KMms'},
#     'href': 'https://api.spotify.com/v1/artists/1HY2Jd0NmPuamShAr6KMms',
#     'id': '1HY2Jd0NmPuamShAr6KMms',
#     'name': 'Lady Gaga',
#     'type': 'artist',
#     'uri': 'spotify:artist:1HY2Jd0NmPuamShAr6KMms'}],
#   'available_markets': ['AR',
#    'AU',
#    'AT',
#    'BE',
#    'BO',
#    'BR',
#    'BG',
#    'CA',
#    'CL',
#    'CO',
#    'CR',
#    'CY',
#    'CZ',
#    'DK',
#    'DO',
#    'DE',
#    'EC',
#    'EE',
#    'SV',
#    'FI',
#    'FR',
#    'GR',
#    'GT',
#    'HN',
#    'HK',
#    'HU',
#    'IS',
#    'IE',
#    'IT',
#    'LV',
#    'LT',
#    'LU',
#    'MY',
#    'MT',
#    'MX',
#    'NL',
#    'NZ',
#    'NI',
#    'NO',
#    'PA',
#    'PY',
#    'PE',
#    'PH',
#    'PL',
#    'PT',
#    'SG',
#    'SK',
#    'ES',
#    'SE',
#    'CH',
#    'TW',
#    'TR',
#    'UY',
#    'US',
#    'GB',
#    'ID',
#    'JP',
#    'TH',
#    'VN',
#    'RO',
#    'IL',
#    'ZA',
#    'SA',
#    'AE',
#    'BH',
#    'QA',
#    'OM',
#    'KW',
#    'EG',
#    'MA',
#    'DZ',
#    'TN',
#    'LB',
#    'JO',
#    'PS',
#    'IN',
#    'UA',
#    'AL',
#    'BA',
#    'HR',
#    'ME',
#    'MK',
#    'RS',
#    'SI',
#    'KR',
#    'LK',
#    'GH',
#    'KE',
#    'NG',
#    'TZ',
#    'UG',
#    'BW',
#    'BF',
#    'CV',
#    'CW',
#    'GM',
#    'GW',
#    'LS',
#    'LR',
#    'MW',
#    'ML',
#    'NA',
#    'NE',
#    'ST',
#    'SN',
#    'SC',
#    'SL',
#    'TT',
#    'BI',
#    'KH',
#    'CM',
#    'TD',
#    'KM',
#    'GQ',
#    'SZ',
#    'GA',
#    'GN',
#    'MR',
#    'RW',
#    'TG',
#    'ZW',
#    'BJ',
#    'MG',
#    'MU',
#    'MZ',
#    'AO',
#    'CI',
#    'DJ',
#    'ZM',
#    'CD',
#    'CG',
#    'IQ',
#    'LY',
#    'VE',
#    'ET',
#    'XK'],
#   'disc_number': 1,
#   'duration_ms': 294573,
#   'explicit': True,
#   'external_ids': {'isrc': 'USUM70918596'},
#   'external_urls': {'spotify': 'https://open.spotify.com/track/29heGwGQ9GZr1KtmD68JwH'},
#   'href': 'https://api.spotify.com/v1/tracks/29heGwGQ9GZr1KtmD68JwH',
#   'id': '29heGwGQ9GZr1KtmD68JwH',
#   'is_local': False,
#   'is_playable': True,
#   'name': 'Bad Romance',
#   'popularity': 12,
#   'preview_url': None,
#   'track_number': 3,
#   'type': 'track',
#   'uri': 'spotify:track:29heGwGQ9GZr1KtmD68JwH'}]

# %%
results["tracks"]["limit"]#Limit we have chosen
# Out:
# 50

# %%
results["tracks"]["next"] #link to the next page (next 50 tracks)
# Out:
# 'https://api.spotify.com/v1/search?offset=50&limit=50&query=Lady%20Gaga&type=track'

# %%
results["tracks"]["offset"] # Actual offset (starting point)
# Out:
# 0

# %%
results["tracks"]["previous"] #Previous search

# %%
results["tracks"]["total"] # Number of matches
# Out:
# 128

# %% [markdown]
# ## Exploring the tracks

# %%
results["tracks"]["items"][0] # Explore the first song

# %%
results["tracks"]["items"][0].keys() # We will focus on album, artists, id, name, popularity, type and uri

# %%
# Track artists
results["tracks"]["items"][0]["artists"]

# %%
# Track artists names
for artist in results["tracks"]["items"][0]["artists"]:
    print(artist["name"])

# %%
# Track ID
results["tracks"]["items"][0]["id"]

# %%
# Track name
results["tracks"]["items"][0]["name"]

# %%
# Popularity index
results["tracks"]["items"][0]["popularity"]

# %% [markdown]
# Spotify songs are identified by either a "url", a "uri", or an "id".
#
# - The `id` is an alphanumeric code, and it's the nuclear part of the identifier.
#
# - The `uri` contains "spotify:track" before the id. An uri is useful because it can be searched manually in the Spotify app.
#
# - The `url` is a link to the song on the Spotify web player.

# %%
results["tracks"]["items"][0]["uri"]

# %% [markdown]
# ## Exercise 1: Discovering New Music through Your Favorite Artists
#
# **Objective:**
# Uncover new music by exploring the top tracks of your favorite artists and their related artists.
#
# **Instructions:**
#
# 1. **List Your Favorite Artists**:
#     - Make a list of your three favorite artists and store it in a variable named `artists`.
#     - Example: `artists = ["Los Fabulosos Cadillacs", "Manu Chao", "Muchachito Bombo Infierno"]`.
#
# 2. **Fetch Top Tracks**:
#     - Write a function named `get_top_tracks`.
#     - This function should accept an artist's name and return the name of the first 5 top tracks by that artist.
#     - Use the function `get_top_tracks` to get the first 5 top tracks for each artist in your `artists` list and store the results in a new list named `top_tracks_list`.
#
# 3. **Discover Related Artists**:
#     - Write a function named `find_related_artists`.
#     - This function should accept an artist's name and return the names of the first 5 artists related to the provided artist.
#     - Store the results in a list named `related_artists_list`.
#
# **Challenge:**
# Combine the above steps to create a playlist that includes the top tracks of your favorite artists and the top tracks of the artists related to them.

# %% [markdown]
# **Hint Section for 3. **Discover Related Artists**:**
#
# 1. **Getting Artist ID**:
#     - Remember that every artist on Spotify has a unique identifier: their `id`. To get the related artists, you first need to fetch the ID of the given artist.
#     - Consider using the `sp.search` method to query the artist's name. The method requires a `q` parameter, which is your query (in this case, the artist's name). It also has a `limit` parameter, which specifies the number of tracks it returns. In this case, 1 track is enough, since we just want the artist ID.
#     - Each track in the results has an associated 'artists' field. This field is a list containing details about all artists involved in that track.
#    - For most tracks, especially those by a single artist, this list will contain one artist. From this artist's details, you can extract the 'id' field, which is the unique identifier for that artist on Spotify.
#
#
# 3. **Fetching Related Artists**:
#     - Once you have the artist's ID, you can use another SpotiPy method to fetch related artists. Think about which SpotiPy method allows you to get related artists using an artist's ID. Here is the documentation link: https://spotipy.readthedocs.io/en/2.22.1/.
#     - This method will return a list of related artists. You'll need to extract the relevant details (artist names) from this list.
#
# 4. **Iterating for Multiple Artists**:
#     - Once you have a function that returns related artists names for one artist, you can use a list comprehension to apply this function to a list of artist names.
#
# 5. **Testing**:
#     - Always test your function with one artist name first. Once you're confident it works, then apply it to the entire list.
#
# Remember, the key is to break the problem down into manageable steps. Use the SpotiPy documentation as a resource to understand available methods and their return structures.

# %%
# Your answer here
artists = ["Rosalía", "C. Tangana", "Pignoise"]

# %%
# Función que busca las top 5 canciones de un artista
def get_top_tracks(artist_name):
    results = sp.search(q=artist_name, type="artist", limit=1)
    artist_id = results["artists"]["items"][0]["id"]
    
    # Ahora pedimos las top tracks del artista
    top_tracks = sp.artist_top_tracks(artist_id)
    track_names = [track["name"] for track in top_tracks["tracks"][:5]]
    return track_names

# Creamos una lista de listas con las top canciones de cada artista
top_tracks_list = [get_top_tracks(artist) for artist in artists]

# Visualizamos
top_tracks_list
# Out:
# [['New Woman (feat. ROSALÍA)',
#   'DESPECHÁ',
#   'BESO',
#   'LA NOCHE DE ANOCHE',
#   'LA FAMA'],
#  ['Demasiadas Mujeres',
#   'Antes de Morirme - feat. ROSALÍA',
#   'Tú Me Dejaste De Querer',
#   'Mala Mujer',
#   'Ingobernable'],
#  ['Te entiendo',
#   'Estoy enfermo (con Melendi)',
#   'Nada que perder',
#   'Cama Vacía',
#   'Todo Me Da Igual']]

# %%
# Función que devuelve nombres de artistas relacionados con un artista dado
def find_related_artists(artist_name):
    results = sp.search(q=artist_name, type="artist", limit=1)
    artist_id = results["artists"]["items"][0]["id"]
    
    related = sp.artist_related_artists(artist_id)
    related_names = [a["name"] for a in related["artists"][:5]]
    return related_names

# Aplicamos la función a cada artista de nuestra lista
related_artists_list = [find_related_artists(artist) for artist in artists]

# Visualizamos
related_artists_list
# Out:
# HTTP Error for GET to https://api.spotify.com/v1/artists/7ltDVBr6mKbRvohxheJ9h1/related-artists with Params: {} returned 404 due to Not Found
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# File c:\Users\andre\Documents\IRONHACK\venv\Lib\site-packages\spotipy\client.py:274, in Spotify._internal_call(self, method, url, payload, params)
#     269 response = self._session.request(
#     270     method, url, headers=headers, proxies=self.proxies,
#     271     timeout=self.requests_timeout, **args
#     272 )
# --> 274 response.raise_for_status()
#     275 results = response.json()
#
# File c:\Users\andre\Documents\IRONHACK\venv\Lib\site-packages\requests\models.py:1024, in Response.raise_for_status(self)
#    1023 if http_error_msg:
# -> 1024     raise HTTPError(http_error_msg, response=self)
#
# HTTPError: 404 Client Error: Not Found for url: https://api.spotify.com/v1/artists/7ltDVBr6mKbRvohxheJ9h1/related-artists
#
# During handling of the above exception, another exception occurred:
#
# SpotifyException                          Traceback (most recent call last)
# Cell In[26], line 11
#       8     return related_names
#      10 # Aplicamos la función a cada artista de nuestra lista
# ---> 11 related_artists_list = [find_related_artists(artist) for artist in artists]
#      13 # Visualizamos
#      14 related_artists_list
#
# Cell In[26], line 6, in find_related_artists(artist_name)
#       3 results = sp.search(q=artist_name, type="artist", limit=1)
#       4 artist_id = results["artists"]["items"][0]["id"]
# ----> 6 related = sp.artist_related_artists(artist_id)
#       7 related_names = [a["name"] for a in related["artists"][:5]]
#       8 return related_names
#
# File c:\Users\andre\Documents\IRONHACK\venv\Lib\site-packages\spotipy\client.py:464, in Spotify.artist_related_artists(self, artist_id)
#     458 warnings.warn(
#     459     "You're using `artist_related_artists(...)`, "
#     460     "which is marked as deprecated by Spotify.",
#     461     DeprecationWarning
#     462 )
#     463 trid = self._get_id("artist", artist_id)
# --> 464 return self._get("artists/" + trid + "/related-artists")
#
# File c:\Users\andre\Documents\IRONHACK\venv\Lib\site-packages\spotipy\client.py:324, in Spotify._get(self, url, args, payload, **kwargs)
#     321 if args:
#     322     kwargs.update(args)
# --> 324 return self._internal_call("GET", url, payload, kwargs)
#
# File c:\Users\andre\Documents\IRONHACK\venv\Lib\site-packages\spotipy\client.py:294, in Spotify._internal_call(self, method, url, payload, params)
#     289         reason = None
#     291     logger.error(f"HTTP Error for {method} to {url} with Params: "
#     292                  f"{args.get('params')} returned {response.status_code} due to {msg}")
# --> 294     raise SpotifyException(
#     295         response.status_code,
#     296         -1,
#     297         f"{response.url}:\n {msg}",
#     298         reason=reason,
#     299         headers=response.headers,
#     300     )
#     301 except requests.exceptions.RetryError as retry_error:
#     302     request = retry_error.request
#
# SpotifyException: http status: 404, code: -1 - https://api.spotify.com/v1/artists/7ltDVBr6mKbRvohxheJ9h1/related-artists:
#  Not Found, reason: None

# %% [markdown]
# ## Playlists
#
# The `sp.featured_playlists()` method in `spotipy` fetches a list of Spotify's featured playlists at a given moment. These are curated playlists that Spotify often highlights on the platform's homepage. The method provides a snapshot of the playlists that are being promoted or featured by Spotify at the time of the request.
#
# Once you've fetched the featured playlists, you can extract their IDs (and other details).

# %%
sp.featured_playlists() # We get a playlist id of a playlist we like
# Out:
# HTTP Error for GET to https://api.spotify.com/v1/browse/featured-playlists with Params: {'locale': None, 'country': None, 'timestamp': None, 'limit': 20, 'offset': 0} returned 404 due to Not Found
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# File c:\Users\andre\Documents\IRONHACK\venv\Lib\site-packages\spotipy\client.py:274, in Spotify._internal_call(self, method, url, payload, params)
#     269 response = self._session.request(
#     270     method, url, headers=headers, proxies=self.proxies,
#     271     timeout=self.requests_timeout, **args
#     272 )
# --> 274 response.raise_for_status()
#     275 results = response.json()
#
# File c:\Users\andre\Documents\IRONHACK\venv\Lib\site-packages\requests\models.py:1024, in Response.raise_for_status(self)
#    1023 if http_error_msg:
# -> 1024     raise HTTPError(http_error_msg, response=self)
#
# HTTPError: 404 Client Error: Not Found for url: https://api.spotify.com/v1/browse/featured-playlists?limit=20&offset=0
#
# During handling of the above exception, another exception occurred:
#
# SpotifyException                          Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 sp.featured_playlists() # We get a playlist id of a playlist we like
#
# File c:\Users\andre\Documents\IRONHACK\venv\Lib\site-packages\spotipy\client.py:1595, in Spotify.featured_playlists(self, locale, country, timestamp, limit, offset)
#    1569 """ Get a list of Spotify featured playlists
#    1570
#    1571     Parameters:
#    (...)   1588           items.
#    1589 """
#    1590 warnings.warn(
#    1591     "You're using `featured_playlists(...)`, "
#    1592     "which is marked as deprecated by Spotify.",
#    1593     DeprecationWarning,
#    1594 )
# -> 1595 return self._get(
#    1596     "browse/featured-playlists",
#    1597     locale=locale,
#    1598     country=country,
#    1599     timestamp=timestamp,
#    1600     limit=limit,
#    1601     offset=offset,
#    1602 )
#
# File c:\Users\andre\Documents\IRONHACK\venv\Lib\site-packages\spotipy\client.py:324, in Spotify._get(self, url, args, payload, **kwargs)
#     321 if args:
#     322     kwargs.update(args)
# --> 324 return self._internal_call("GET", url, payload, kwargs)
#
# File c:\Users\andre\Documents\IRONHACK\venv\Lib\site-packages\spotipy\client.py:294, in Spotify._internal_call(self, method, url, payload, params)
#     289         reason = None
#     291     logger.error(f"HTTP Error for {method} to {url} with Params: "
#     292                  f"{args.get('params')} returned {response.status_code} due to {msg}")
# --> 294     raise SpotifyException(
#     295         response.status_code,
#     296         -1,
#     297         f"{response.url}:\n {msg}",
#     298         reason=reason,
#     299         headers=response.headers,
#     300     )
#     301 except requests.exceptions.RetryError as retry_error:
#     302     request = retry_error.request
#
# SpotifyException: http status: 404, code: -1 - https://api.spotify.com/v1/browse/featured-playlists?limit=20&offset=0:
#  Not Found, reason: None

# %% [markdown]
# ### Getting a Playlist's Details
# To fetch details about a specific playlist, you can use the playlist method. You'll need the playlist's Spotify ID.

# %% [markdown]
# In this example, we will use the following playlist id: *37i9dQZF1DXd9zR7tdziuQ*

# %%
playlist_id = "37i9dQZF1DXd9zR7tdziuQ"
playlist = sp.playlist(playlist_id)
# Out:
# HTTP Error for GET to https://api.spotify.com/v1/playlists/37i9dQZF1DXd9zR7tdziuQ with Params: {'fields': None, 'market': None, 'additional_types': 'track'} returned 404 due to Resource not found
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# File c:\Users\andre\Documents\IRONHACK\venv\Lib\site-packages\spotipy\client.py:274, in Spotify._internal_call(self, method, url, payload, params)
#     269 response = self._session.request(
#     270     method, url, headers=headers, proxies=self.proxies,
#     271     timeout=self.requests_timeout, **args
#     272 )
# --> 274 response.raise_for_status()
#     275 results = response.json()
#
# File c:\Users\andre\Documents\IRONHACK\venv\Lib\site-packages\requests\models.py:1024, in Response.raise_for_status(self)
#    1023 if http_error_msg:
# -> 1024     raise HTTPError(http_error_msg, response=self)
#
# HTTPError: 404 Client Error: Not Found for url: https://api.spotify.com/v1/playlists/37i9dQZF1DXd9zR7tdziuQ?additional_types=track
#
# During handling of the above exception, another exception occurred:
#
# SpotifyException                          Traceback (most recent call last)
# Cell In[22], line 2
#       1 playlist_id = "37i9dQZF1DXd9zR7tdziuQ"
# ----> 2 playlist = sp.playlist(playlist_id)
#
# File c:\Users\andre\Documents\IRONHACK\venv\Lib\site-packages\spotipy\client.py:668, in Spotify.playlist(self, playlist_id, fields, market, additional_types)
#     657 """ Gets playlist by id.
#     658
#     659     Parameters:
#    (...)    665                              valid types are: track and episode
#     666 """
#     667 plid = self._get_id("playlist", playlist_id)
# --> 668 return self._get(
#     669     f"playlists/{plid}",
#     670     fields=fields,
#     671     market=market,
#     672     additional_types=",".join(additional_types),
#     673 )
#
# File c:\Users\andre\Documents\IRONHACK\venv\Lib\site-packages\spotipy\client.py:324, in Spotify._get(self, url, args, payload, **kwargs)
#     321 if args:
#     322     kwargs.update(args)
# --> 324 return self._internal_call("GET", url, payload, kwargs)
#
# File c:\Users\andre\Documents\IRONHACK\venv\Lib\site-packages\spotipy\client.py:294, in Spotify._internal_call(self, method, url, payload, params)
#     289         reason = None
#     291     logger.error(f"HTTP Error for {method} to {url} with Params: "
#     292                  f"{args.get('params')} returned {response.status_code} due to {msg}")
# --> 294     raise SpotifyException(
#     295         response.status_code,
#     296         -1,
#     297         f"{response.url}:\n {msg}",
#     298         reason=reason,
#     299         headers=response.headers,
#     300     )
#     301 except requests.exceptions.RetryError as retry_error:
#     302     request = retry_error.request
#
# SpotifyException: http status: 404, code: -1 - https://api.spotify.com/v1/playlists/37i9dQZF1DXd9zR7tdziuQ?additional_types=track:
#  Resource not found, reason: None

# %%
print(playlist['name'])  # Print the playlist's name
print(playlist['description'])  # Print the playlist's description

# %% [markdown]
# ### Getting Tracks from a Playlist
# If you want to get the tracks from a specific playlist, you can use the playlist_tracks method.

# %%
tracks = sp.playlist_tracks(playlist_id)
for track in tracks['items']:
    print(track['track']['name'])  # Print each track's name

# %% [markdown]
# ### Getting Artists from a Playlist
#
# To extract all the artists from the tracks in a playlist, you'd typically follow these steps:
#
# 1. Fetch the playlist's tracks.
# 2. Iterate through each track.
# 3. For each track, extract the associated artists.

# %%
# List to store unique artist names
artists_list = []

for track_item in tracks['items']:
    track = track_item['track']
    for artist in track['artists']:
        artist_name = artist['name']
        if artist_name not in artists_list:  # This ensures each artist is added only once
            artists_list.append(artist_name)

print(artists_list)

# %% [markdown]
# ## Exercise 2: Unraveling the World of Playlists
#
#
# 1. **Featured Exploration**:
#    - Fetch the list of Spotify's current featured playlists.
#    - Extract and display the names and IDs of the top 5 featured playlists.
#
# 2. **Deep Dive**:
#    - Choose any one of the top 5 featured playlists (you can choose the one you personally find most interesting or simply pick one randomly).
#    - Fetch and display its name, description, and total track count.
#
# 3. **Track-tastic**:
#    - Extract and display the names of the first 10 tracks in the chosen playlist.
#
# 4. **Artistic Flair**:
#    - Create a dictionary where the keys are the names of the first 10 tracks, and the values are lists containing the names of the artists associated with each track.
#    - For example: `{"TrackName1": ["Artist1", "Artist2"], "TrackName2": ["Artist3"]}`

# %%
# Your answer here
# Obtenemos las playlists destacadas
featured_playlists = sp.featured_playlists()
# Nos quedamos con los primeros 5
top_playlists = featured_playlists["playlists"]["items"][:5]

# Mostramos nombres e IDs
for i, playlist in enumerate(top_playlists, start=1):
    print(f"{i}. {playlist['name']} - ID: {playlist['id']}")


#LAB NO TERMINADO DEBIDO A ENDPOINTS DEPRECATED
# Out:
# HTTP Error for GET to https://api.spotify.com/v1/browse/featured-playlists with Params: {'locale': None, 'country': None, 'timestamp': None, 'limit': 20, 'offset': 0} returned 404 due to Not Found
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# File c:\Users\andre\Documents\IRONHACK\venv\Lib\site-packages\spotipy\client.py:274, in Spotify._internal_call(self, method, url, payload, params)
#     269 response = self._session.request(
#     270     method, url, headers=headers, proxies=self.proxies,
#     271     timeout=self.requests_timeout, **args
#     272 )
# --> 274 response.raise_for_status()
#     275 results = response.json()
#
# File c:\Users\andre\Documents\IRONHACK\venv\Lib\site-packages\requests\models.py:1024, in Response.raise_for_status(self)
#    1023 if http_error_msg:
# -> 1024     raise HTTPError(http_error_msg, response=self)
#
# HTTPError: 404 Client Error: Not Found for url: https://api.spotify.com/v1/browse/featured-playlists?limit=20&offset=0
#
# During handling of the above exception, another exception occurred:
#
# SpotifyException                          Traceback (most recent call last)
# Cell In[28], line 3
#       1 # Your answer here
#       2 # Obtenemos las playlists destacadas
# ----> 3 featured_playlists = sp.featured_playlists()
#       4 # Nos quedamos con los primeros 5
#       5 top_playlists = featured_playlists["playlists"]["items"][:5]
#
# File c:\Users\andre\Documents\IRONHACK\venv\Lib\site-packages\spotipy\client.py:1595, in Spotify.featured_playlists(self, locale, country, timestamp, limit, offset)
#    1569 """ Get a list of Spotify featured playlists
#    1570
#    1571     Parameters:
#    (...)   1588           items.
#    1589 """
#    1590 warnings.warn(
#    1591     "You're using `featured_playlists(...)`, "
#    1592     "which is marked as deprecated by Spotify.",
#    1593     DeprecationWarning,
#    1594 )
# -> 1595 return self._get(
#    1596     "browse/featured-playlists",
#    1597     locale=locale,
#    1598     country=country,
#    1599     timestamp=timestamp,
#    1600     limit=limit,
#    1601     offset=offset,
#    1602 )
#
# File c:\Users\andre\Documents\IRONHACK\venv\Lib\site-packages\spotipy\client.py:324, in Spotify._get(self, url, args, payload, **kwargs)
#     321 if args:
#     322     kwargs.update(args)
# --> 324 return self._internal_call("GET", url, payload, kwargs)
#
# File c:\Users\andre\Documents\IRONHACK\venv\Lib\site-packages\spotipy\client.py:294, in Spotify._internal_call(self, method, url, payload, params)
#     289         reason = None
#     291     logger.error(f"HTTP Error for {method} to {url} with Params: "
#     292                  f"{args.get('params')} returned {response.status_code} due to {msg}")
# --> 294     raise SpotifyException(
#     295         response.status_code,
#     296         -1,
#     297         f"{response.url}:\n {msg}",
#     298         reason=reason,
#     299         headers=response.headers,
#     300     )
#     301 except requests.exceptions.RetryError as retry_error:
#     302     request = retry_error.request
#
# SpotifyException: http status: 404, code: -1 - https://api.spotify.com/v1/browse/featured-playlists?limit=20&offset=0:
#  Not Found, reason: None
